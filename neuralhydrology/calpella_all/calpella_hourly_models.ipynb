# %%
import sys
import os
import pickle

library_path = os.path.join('..', '..', '..','UCB-USACE-LSTMs')
sys.path.insert(0, library_path)

from pathlib import Path
import pandas as pd

import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation.metrics import *
from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble
from neuralhydrology.UCB_training.UCB_train import UCB_trainer
from neuralhydrology.evaluation.metrics import calculate_all_metrics

# %% [markdown]
# Quick check that working directory and train basin file exists:

# %%
print("Current Working Directory:", os.getcwd())
print("Train Basin File Exists:", os.path.exists("calpella"))
# Out:
# Current Working Directory: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all
# Train Basin File Exists: True

# %% [markdown]
# Run regular LSTM:

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/11082024_data_streamflow_met_Russian_River_share_UCB/")
path_to_yaml = Path("calpella_gage_hourly.yaml")
params = {
    "epochs": 64,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 2160,
}
lstmNoPhysics = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params)

# %%
lstmNoPhysics.train()
# Out:
# 2024-12-18 11:50:27,234: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027\output.log initialized.
# 2024-12-18 11:50:27,237: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027
# 2024-12-18 11:50:27,240: ### Run configurations for testing_run
# 2024-12-18 11:50:27,243: experiment_name: testing_run
# 2024-12-18 11:50:27,245: train_basin_file: calpella
# 2024-12-18 11:50:27,247: validation_basin_file: calpella
# 2024-12-18 11:50:27,250: test_basin_file: calpella
# 2024-12-18 11:50:27,252: train_start_date: 1994-10-01 00:00:00
# 2024-12-18 11:50:27,254: train_end_date: 2002-09-30 00:00:00
# 2024-12-18 11:50:27,255: validation_start_date: 2002-10-01 00:00:00
# 2024-12-18 11:50:27,256: validation_end_date: 2005-09-30 00:00:00
# 2024-12-18 11:50:27,258: test_start_date: 2005-10-01 00:00:00
# 2024-12-18 11:50:27,259: test_end_date: 2009-09-30 00:00:00
# 2024-12-18 11:50:27,261: device: cpu
# 2024-12-18 11:50:27,262: physics_informed: False
# 2024-12-18 11:50:27,263: physics_data_file: None
# 2024-12-18 11:50:27,265: validate_every: 5
# 2024-12-18 11:50:27,266: validate_n_random_basins: 1
# 2024-12-18 11:50:27,268: metrics: ['NSE', 'MSE']
# 2024-12-18 11:50:27,270: model: cudalstm
# 2024-12-18 11:50:27,271: head: regression
# 2024-12-18 11:50:27,273: output_activation: linear
# 2024-12-18 11:50:27,275: hidden_size: 128
# 2024-12-18 11:50:27,276: initial_forget_bias: 3
# 2024-12-18 11:50:27,278: output_dropout: 0.4
# 2024-12-18 11:50:27,279: optimizer: Adam
# 2024-12-18 11:50:27,280: loss: NSE
# 2024-12-18 11:50:27,281: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-12-18 11:50:27,282: batch_size: 256
# 2024-12-18 11:50:27,283: epochs: 64
# 2024-12-18 11:50:27,286: clip_gradient_norm: 1
# 2024-12-18 11:50:27,287: predict_last_n: 1
# 2024-12-18 11:50:27,325: seq_length: 2160
# 2024-12-18 11:50:27,330: log_interval: 16
# 2024-12-18 11:50:27,332: log_tensorboard: True
# 2024-12-18 11:50:27,333: log_n_figures: 1
# 2024-12-18 11:50:27,335: save_weights_every: 64
# 2024-12-18 11:50:27,339: dataset: russian_river
# 2024-12-18 11:50:27,341: data_dir: F:\Dino\UCB-USACE-LSTMs\data\11082024_data_streamflow_met_Russian_River_share_UCB
# 2024-12-18 11:50:27,343: dynamic_inputs: ['EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'POTTER VALLEY CA FLOW USGS_ADJUSTED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA']
# 2024-12-18 11:50:27,345: target_variables: ['NR CALPELLA FLOW COE CPL']
# 2024-12-18 11:50:27,346: clip_targets_to_zero: ['NR CALPELLA FLOW COE CPL']
# 2024-12-18 11:50:27,348: number_of_basins: 1
# 2024-12-18 11:50:27,350: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027
# 2024-12-18 11:50:27,352: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027\train_data
# 2024-12-18 11:50:27,353: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027\img_log
# 2024-12-18 11:50:27,359: ### Device cpu will be used for training
# 2024-12-18 11:50:27,361: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  6.05it/s]
# 2024-12-18 11:50:27,536: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 167.42it/s]
# 2024-12-18 11:50:27,566: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  6.12it/s]
# # Epoch 1: 100%|██████████| 3/3 [00:15<00:00,  5.17s/it, Loss: 0.0000]
# 2024-12-18 11:50:43,754: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 3/3 [00:16<00:00,  5.37s/it, Loss: 0.0000]
# 2024-12-18 11:50:59,926: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 3/3 [00:15<00:00,  5.06s/it, Loss: 0.0000]
# 2024-12-18 11:51:15,181: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 3/3 [00:16<00:00,  5.38s/it, Loss: 0.0000]
# 2024-12-18 11:51:31,378: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 3/3 [00:15<00:00,  5.12s/it, Loss: 0.0000]
# 2024-12-18 11:51:46,809: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.44s/it]
# 2024-12-18 11:51:50,749: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.28692, MSE: 122160.03125
# # Epoch 6: 100%|██████████| 3/3 [00:15<00:00,  5.11s/it, Loss: 0.0000]
# 2024-12-18 11:52:06,169: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 3/3 [00:15<00:00,  5.15s/it, Loss: 0.0000]
# 2024-12-18 11:52:21,675: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 3/3 [00:15<00:00,  5.22s/it, Loss: 0.0000]
# 2024-12-18 11:52:37,381: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 3/3 [00:15<00:00,  5.24s/it, Loss: 0.0000]
# 2024-12-18 11:52:53,162: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 3/3 [00:15<00:00,  5.13s/it, Loss: 0.0000]
# 2024-12-18 11:53:08,596: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.31s/it]
# 2024-12-18 11:53:12,416: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.34566, MSE: 112096.52344
# # Epoch 11: 100%|██████████| 3/3 [00:15<00:00,  5.08s/it, Loss: 0.0000]
# 2024-12-18 11:53:27,732: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 3/3 [00:16<00:00,  5.46s/it, Loss: 0.0000]
# 2024-12-18 11:53:44,161: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 3/3 [00:15<00:00,  5.23s/it, Loss: 0.0000]
# 2024-12-18 11:53:59,919: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 3/3 [00:15<00:00,  5.06s/it, Loss: 0.0000]
# 2024-12-18 11:54:15,142: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 3/3 [00:15<00:00,  5.04s/it, Loss: 0.0000]
# 2024-12-18 11:54:30,309: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.19s/it]
# 2024-12-18 11:54:33,992: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.42293, MSE: 98859.07812
# # Epoch 16: 100%|██████████| 3/3 [00:15<00:00,  5.29s/it, Loss: 0.0000]
# 2024-12-18 11:54:49,925: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 17: 100%|██████████| 3/3 [00:15<00:00,  5.08s/it, Loss: 0.0000]
# 2024-12-18 11:55:05,216: Epoch 17 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 18: 100%|██████████| 3/3 [00:15<00:00,  5.17s/it, Loss: 0.0000]
# 2024-12-18 11:55:20,777: Epoch 18 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 19: 100%|██████████| 3/3 [00:16<00:00,  5.43s/it, Loss: 0.0000]
# 2024-12-18 11:55:37,116: Epoch 19 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 20: 100%|██████████| 3/3 [00:18<00:00,  6.17s/it, Loss: 0.0000]
# 2024-12-18 11:55:55,688: Epoch 20 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.27s/it]
# 2024-12-18 11:55:59,467: Epoch 20 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.43509, MSE: 96776.17188
# # Epoch 21: 100%|██████████| 3/3 [00:18<00:00,  6.07s/it, Loss: 0.0000]
# 2024-12-18 11:56:17,750: Epoch 21 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 22: 100%|██████████| 3/3 [00:18<00:00,  6.01s/it, Loss: 0.0000]
# 2024-12-18 11:56:35,822: Epoch 22 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 23: 100%|██████████| 3/3 [00:18<00:00,  6.00s/it, Loss: 0.0000]
# 2024-12-18 11:56:53,899: Epoch 23 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 24: 100%|██████████| 3/3 [00:17<00:00,  5.98s/it, Loss: 0.0000]
# 2024-12-18 11:57:11,899: Epoch 24 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 25: 100%|██████████| 3/3 [00:16<00:00,  5.55s/it, Loss: 0.0000]
# 2024-12-18 11:57:28,617: Epoch 25 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
# 2024-12-18 11:57:32,298: Epoch 25 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.48633, MSE: 87998.76562
# # Epoch 26: 100%|██████████| 3/3 [00:15<00:00,  5.14s/it, Loss: 0.0000]
# 2024-12-18 11:57:47,779: Epoch 26 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 27: 100%|██████████| 3/3 [00:17<00:00,  5.97s/it, Loss: 0.0000]
# 2024-12-18 11:58:05,742: Epoch 27 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 28: 100%|██████████| 3/3 [00:18<00:00,  6.06s/it, Loss: 0.0000]
# 2024-12-18 11:58:23,980: Epoch 28 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 29: 100%|██████████| 3/3 [00:18<00:00,  6.05s/it, Loss: 0.0000]
# 2024-12-18 11:58:42,181: Epoch 29 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2024-12-18 11:58:42,183: Setting learning rate to 0.005
# # Epoch 30: 100%|██████████| 3/3 [00:18<00:00,  6.03s/it, Loss: 0.0000]
# 2024-12-18 11:59:00,346: Epoch 30 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.29s/it]
# 2024-12-18 11:59:04,148: Epoch 30 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.50595, MSE: 84636.39844
# # Epoch 31: 100%|██████████| 3/3 [00:18<00:00,  6.19s/it, Loss: 0.0000]
# 2024-12-18 11:59:22,791: Epoch 31 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 32: 100%|██████████| 3/3 [00:18<00:00,  6.15s/it, Loss: 0.0000]
# 2024-12-18 11:59:41,295: Epoch 32 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 33: 100%|██████████| 3/3 [00:18<00:00,  6.22s/it, Loss: 0.0000]
# 2024-12-18 12:00:00,017: Epoch 33 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 34: 100%|██████████| 3/3 [00:19<00:00,  6.52s/it, Loss: 0.0000]
# 2024-12-18 12:00:19,640: Epoch 34 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 35: 100%|██████████| 3/3 [00:19<00:00,  6.53s/it, Loss: 0.0000]
# 2024-12-18 12:00:39,293: Epoch 35 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.25s/it]
# 2024-12-18 12:00:43,017: Epoch 35 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.52001, MSE: 82227.51562
# # Epoch 36: 100%|██████████| 3/3 [00:19<00:00,  6.43s/it, Loss: 0.0000]
# 2024-12-18 12:01:02,369: Epoch 36 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 37: 100%|██████████| 3/3 [00:18<00:00,  6.06s/it, Loss: 0.0000]
# 2024-12-18 12:01:20,614: Epoch 37 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 38: 100%|██████████| 3/3 [00:18<00:00,  6.06s/it, Loss: 0.0000]
# 2024-12-18 12:01:38,838: Epoch 38 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 39: 100%|██████████| 3/3 [00:17<00:00,  5.87s/it, Loss: 0.0000]
# 2024-12-18 12:01:56,494: Epoch 39 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2024-12-18 12:01:56,497: Setting learning rate to 0.001
# # Epoch 40: 100%|██████████| 3/3 [00:17<00:00,  5.81s/it, Loss: 0.0000]
# 2024-12-18 12:02:13,998: Epoch 40 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.27s/it]
# 2024-12-18 12:02:17,709: Epoch 40 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.54263, MSE: 78352.29688
# # Epoch 41: 100%|██████████| 3/3 [00:17<00:00,  5.74s/it, Loss: 0.0000]
# 2024-12-18 12:02:34,976: Epoch 41 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 42: 100%|██████████| 3/3 [00:17<00:00,  5.72s/it, Loss: 0.0000]
# 2024-12-18 12:02:52,180: Epoch 42 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 43: 100%|██████████| 3/3 [00:17<00:00,  5.69s/it, Loss: 0.0000]
# 2024-12-18 12:03:09,299: Epoch 43 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 44: 100%|██████████| 3/3 [00:17<00:00,  5.76s/it, Loss: 0.0000]
# 2024-12-18 12:03:26,638: Epoch 44 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 45: 100%|██████████| 3/3 [00:17<00:00,  5.80s/it, Loss: 0.0000]
# 2024-12-18 12:03:44,104: Epoch 45 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.31s/it]
# 2024-12-18 12:03:47,968: Epoch 45 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.54806, MSE: 77423.63281
# # Epoch 46: 100%|██████████| 3/3 [00:17<00:00,  5.79s/it, Loss: 0.0000]
# 2024-12-18 12:04:05,411: Epoch 46 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 47: 100%|██████████| 3/3 [00:16<00:00,  5.55s/it, Loss: 0.0000]
# 2024-12-18 12:04:22,108: Epoch 47 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 48: 100%|██████████| 3/3 [00:16<00:00,  5.39s/it, Loss: 0.0000]
# 2024-12-18 12:04:38,343: Epoch 48 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 49: 100%|██████████| 3/3 [00:16<00:00,  5.43s/it, Loss: 0.0000]
# 2024-12-18 12:04:54,695: Epoch 49 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 50: 100%|██████████| 3/3 [00:16<00:00,  5.60s/it, Loss: 0.0000]
# 2024-12-18 12:05:11,559: Epoch 50 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.42s/it]
# 2024-12-18 12:05:15,414: Epoch 50 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.55410, MSE: 76388.13281
# # Epoch 51: 100%|██████████| 3/3 [00:16<00:00,  5.52s/it, Loss: 0.0000]
# 2024-12-18 12:05:32,029: Epoch 51 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 52: 100%|██████████| 3/3 [00:16<00:00,  5.41s/it, Loss: 0.0000]
# 2024-12-18 12:05:48,311: Epoch 52 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 53: 100%|██████████| 3/3 [00:16<00:00,  5.41s/it, Loss: 0.0000]
# 2024-12-18 12:06:04,603: Epoch 53 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 54: 100%|██████████| 3/3 [00:15<00:00,  5.31s/it, Loss: 0.0000]
# 2024-12-18 12:06:20,602: Epoch 54 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 55: 100%|██████████| 3/3 [00:16<00:00,  5.34s/it, Loss: 0.0000]
# 2024-12-18 12:06:36,666: Epoch 55 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.38s/it]
# 2024-12-18 12:06:40,521: Epoch 55 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.55479, MSE: 76269.58594
# # Epoch 56: 100%|██████████| 3/3 [00:17<00:00,  5.74s/it, Loss: 0.0000]
# 2024-12-18 12:06:57,804: Epoch 56 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 57: 100%|██████████| 3/3 [00:17<00:00,  5.73s/it, Loss: 0.0000]
# 2024-12-18 12:07:15,056: Epoch 57 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 58: 100%|██████████| 3/3 [00:17<00:00,  5.75s/it, Loss: 0.0000]
# 2024-12-18 12:07:32,363: Epoch 58 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 59: 100%|██████████| 3/3 [00:17<00:00,  5.80s/it, Loss: 0.0000]
# 2024-12-18 12:07:49,823: Epoch 59 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 60: 100%|██████████| 3/3 [00:17<00:00,  5.78s/it, Loss: 0.0000]
# 2024-12-18 12:08:07,238: Epoch 60 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.25s/it]
# 2024-12-18 12:08:10,986: Epoch 60 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.55988, MSE: 75398.70312
# # Epoch 61: 100%|██████████| 3/3 [00:17<00:00,  5.81s/it, Loss: 0.0000]
# 2024-12-18 12:08:28,471: Epoch 61 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 62: 100%|██████████| 3/3 [00:17<00:00,  5.73s/it, Loss: 0.0000]
# 2024-12-18 12:08:45,701: Epoch 62 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 63: 100%|██████████| 3/3 [00:15<00:00,  5.30s/it, Loss: 0.0000]
# 2024-12-18 12:09:01,641: Epoch 63 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 64: 100%|██████████| 3/3 [00:15<00:00,  5.27s/it, Loss: 0.0000]
# 2024-12-18 12:09:17,499: Epoch 64 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2024-12-18 12:09:17,593: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027\model_epoch064.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:04<00:00,  4.54s/it]
# 2024-12-18 12:09:22,170: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027\test\model_epoch064\test_metrics.csv
# 2024-12-18 12:09:22,174: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027\test\model_epoch064\test_results.p

# %%
lstmNoPhysics.results()
# Out:
# Using basin: Calpella
# Using target variable: NR CALPELLA FLOW COE CPL
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_115027\results_output.csv
# {'NSE': 0.4446282982826233,
#  'MSE': 141441.9375,
#  'RMSE': 376.08767262434964,
#  'KGE': 0.3167857893025606,
#  'Alpha-NSE': 0.3857360918382508,
#  'Beta-KGE': 0.7876307368278503,
#  'Beta-NSE': -0.12475669935105918,
#  'Pearson-r': 0.7893799513614681,
#  'FHV': -67.77576208114624,
#  'FMS': -13.928864754247902,
#  'FLV': 77.984479344168,
#  'Peak-Timing': 0.5,
#  'Peak-MAPE': 61.181721687316895}

# %% [markdown]
# Now run physics informed lstm with HMS data:

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/11082024_data_streamflow_met_Russian_River_share_UCB")
path_to_yaml = Path("calpella_gage_hourly.yaml")
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/HMS_outputs_for_UCB/Calpella_hourly.csv")
params = {
    "epochs":32,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 2160,
}
features_with_physics = [
    #from hourly
    "EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "EF RUSSIAN 20 PRECIP-INC SCREENED",
    "POTTER VALLEY CA FLOW USGS_ADJUSTED",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    #from new capella_hourly.csv
    'Capella Gage FLOW',
    'EF Russian 20 ET-POTENTIAL',
    'EF Russian 20 FLOW',
    'EF Russian 20 FLOW-BASE',
    'EF Russian 20 INFILTRATION',
    'EF Russian 20 PERC-SOIL',
    'EF Russian 20 SATURATION FRACTION',
#    'Lake Mendocino Storage',
]
lstmPhysics = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data)

# %%
lstmPhysics.train()
# Out:
# 2024-12-18 11:41:20,308: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_114120\output.log initialized.
# 2024-12-18 11:41:20,311: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_114120
# 2024-12-18 11:41:20,315: ### Run configurations for testing_run
# 2024-12-18 11:41:20,317: experiment_name: testing_run
# 2024-12-18 11:41:20,319: train_basin_file: calpella
# 2024-12-18 11:41:20,322: validation_basin_file: calpella
# 2024-12-18 11:41:20,324: test_basin_file: calpella
# 2024-12-18 11:41:20,325: train_start_date: 1994-10-01 00:00:00
# 2024-12-18 11:41:20,327: train_end_date: 2002-09-30 00:00:00
# 2024-12-18 11:41:20,328: validation_start_date: 2002-10-01 00:00:00
# 2024-12-18 11:41:20,329: validation_end_date: 2005-09-30 00:00:00
# 2024-12-18 11:41:20,330: test_start_date: 2005-10-01 00:00:00
# 2024-12-18 11:41:20,333: test_end_date: 2009-09-30 00:00:00
# 2024-12-18 11:41:20,335: device: cpu
# 2024-12-18 11:41:20,337: physics_informed: True
# 2024-12-18 11:41:20,340: physics_data_file: F:\Dino\UCB-USACE-LSTMs\data\HMS_outputs_for_UCB\Calpella_hourly.csv
# 2024-12-18 11:41:20,342: validate_every: 5
# 2024-12-18 11:41:20,343: validate_n_random_basins: 1
# 2024-12-18 11:41:20,345: metrics: ['NSE', 'MSE']
# 2024-12-18 11:41:20,347: model: cudalstm
# 2024-12-18 11:41:20,348: head: regression
# 2024-12-18 11:41:20,350: output_activation: linear
# 2024-12-18 11:41:20,351: hidden_size: 128
# 2024-12-18 11:41:20,370: initial_forget_bias: 3
# 2024-12-18 11:41:20,393: output_dropout: 0.4
# 2024-12-18 11:41:20,397: optimizer: Adam
# 2024-12-18 11:41:20,400: loss: NSE
# 2024-12-18 11:41:20,402: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-12-18 11:41:20,405: batch_size: 256
# 2024-12-18 11:41:20,407: epochs: 32
# 2024-12-18 11:41:20,410: clip_gradient_norm: 1
# 2024-12-18 11:41:20,412: predict_last_n: 1
# 2024-12-18 11:41:20,413: seq_length: 2160
# 2024-12-18 11:41:20,414: log_interval: 16
# 2024-12-18 11:41:20,416: log_tensorboard: True
# 2024-12-18 11:41:20,417: log_n_figures: 1
# 2024-12-18 11:41:20,418: save_weights_every: 32
# 2024-12-18 11:41:20,419: dataset: russian_river
# 2024-12-18 11:41:20,420: data_dir: F:\Dino\UCB-USACE-LSTMs\data\11082024_data_streamflow_met_Russian_River_share_UCB
# 2024-12-18 11:41:20,421: dynamic_inputs: ['EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'POTTER VALLEY CA FLOW USGS_ADJUSTED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'Capella Gage FLOW', 'EF Russian 20 ET-POTENTIAL', 'EF Russian 20 FLOW', 'EF Russian 20 FLOW-BASE', 'EF Russian 20 INFILTRATION', 'EF Russian 20 PERC-SOIL', 'EF Russian 20 SATURATION FRACTION']
# 2024-12-18 11:41:20,422: target_variables: ['NR CALPELLA FLOW COE CPL']
# 2024-12-18 11:41:20,423: clip_targets_to_zero: ['NR CALPELLA FLOW COE CPL']
# 2024-12-18 11:41:20,424: number_of_basins: 1
# 2024-12-18 11:41:20,425: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_114120
# 2024-12-18 11:41:20,426: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_114120\train_data
# 2024-12-18 11:41:20,427: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1812_114120\img_log
# 2024-12-18 11:41:20,435: ### Device cpu will be used for training
# 2024-12-18 11:41:20,436: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\russianriver.py:100: DtypeWarning: Columns (0,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(physics_data_file)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 lstmPhysics.train()
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\UCB_training\UCB_train.py:69, in UCB_trainer.train(self)
#      65 """
#      66 Public method to handle the training and evaluating process for individual models or ensembles. Sets self.model.
#      67 """
#      68 if self._num_ensemble_members == 1:
# ---> 69     self._model = self._train_model()  # returns run directory of single model
#      70     self._eval_model(self._model)
#      71 else:
#      72     # returns dict with predictions on test set and metrics
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\UCB_training\UCB_train.py:128, in UCB_trainer._train_model(self)
#     125 if self._gpu is not None and self._gpu < 0:
#     126     self._config.device = "cpu"
# --> 128 start_training(self._config)
#     129 path = self._config.run_dir
#     130 return path
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\training\train.py:19, in start_training(cfg)
#      17 else:
#      18     raise ValueError(f"Unknown head {cfg.head}.")
# ---> 19 trainer.initialize_training()
#      20 trainer.train_and_validate()
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\training\basetrainer.py:147, in BaseTrainer.initialize_training(self)
#     144     self._scaler = load_scaler(self.cfg.base_run_dir)
#     146 # Initialize dataset before the model is loaded.
# --> 147 ds = self._get_dataset()
#     148 if len(ds) == 0:
#     149     raise ValueError("Dataset contains no samples.")
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\training\basetrainer.py:80, in BaseTrainer._get_dataset(self)
#      79 def _get_dataset(self) -> BaseDataset:
# ---> 80     return get_dataset(cfg=self.cfg, period="train", is_train=True, scaler=self._scaler)
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\__init__.py:89, in get_dataset(cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      86 else:
#      87     raise NotImplementedError(f"No dataset class implemented for dataset {cfg.dataset}")
# ---> 89 ds = Dataset(cfg=cfg,
#      90              is_train=is_train,
#      91              period=period,
#      92              basin=basin,
#      93              additional_features=additional_features,
#      94              id_to_int=id_to_int,
#      95              scaler=scaler)
#      96 return ds
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\russianriver.py:51, in RussianRiver.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      42 def __init__(self,
#      43              cfg: Config,
#      44              is_train: bool,
#    (...)
#      49              scaler: Dict[str, Union[pd.Series, xarray.DataArray]] = {}):
#      50     # initialize parent class
# ---> 51     super(RussianRiver, self).__init__(cfg=cfg,
#      52                                           is_train=is_train,
#      53                                           period=period,
#      54                                           basin=basin,
#      55                                           additional_features=additional_features,
#      56                                           id_to_int=id_to_int,
#      57                                           scaler=scaler)
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\basedataset.py:146, in BaseDataset.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#     143         self._create_id_to_int()
#     145 # load and preprocess data
# --> 146 self._load_data()
#     148 if self.is_train:
#     149     self._dump_scaler()
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\basedataset.py:720, in BaseDataset._load_data(self)
#     716 def _load_data(self):
#     717     # load attributes first to sanity-check those features before doing the compute expensive time series loading
#     718     self._load_combined_attributes()
# --> 720     xr = self._load_or_create_xarray_dataset()
#     722     if self.cfg.loss.lower() in ['nse', 'weightednse']:
#     723         # get the std of the discharge for each basin, which is needed for the (weighted) NSE loss.
#     724         self._calculate_per_basin_std(xr)
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\basedataset.py:336, in BaseDataset._load_or_create_xarray_dataset(self)
#     334     LOGGER.info("Loading basin data into xarray data set.")
#     335 for basin in tqdm(self.basins, disable=self._disable_pbar, file=sys.stdout):
# --> 336     df = self._load_basin_data(basin)
#     338     # add columns from dataframes passed as additional data files
#     339     df = pd.concat([df, *[d[basin] for d in self.additional_features]], axis=1)
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\russianriver.py:79, in RussianRiver._load_basin_data(self, basin)
#      77 physics_file = self.cfg.physics_data_file
#      78 if Path(physics_file).exists():
# ---> 79     physics_df = load_hms_basin_data(physics_file)
#      80     df = pd.merge(df, physics_df, left_index=True, right_index=True, how='outer') #add physics columns if physics informed
#      81 else: raise FileNotFoundError(f"Physics data file not found: {physics_file}")
#
# File F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datasetzoo\russianriver.py:105, in load_hms_basin_data(physics_data_file)
#     103 df = df.drop(columns=['Ordinate'])
#     104 df = df.rename(columns={'Date / Time': 'date'})
# --> 105 df['date'] = pd.to_datetime(df['date'], format='%d-%b-%y')
#     106 df.set_index('date', inplace=True)
#     107 return df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
lstmPhysics.results()

# %% [markdown]
# Now, combine the results for the normal lstm, physics informed lstm and the hms results on one graph over a specified time period (the test period).

# %%
import xarray as xr

# %%
def combinedPlot(lstm_results: Path, lstmPhysics_results: Path, HMS_results: Path, title: str, 
                 test_start_date="01/10/2005", test_end_date="30/09/2009"):
    model1_df = pd.read_csv(lstm_results) #colums: Date, Observed, Predicted
    model2_df = pd.read_csv(lstmPhysics_results) #colums: Date, Observed, Predicted
    model1_df = model1_df.rename(columns={
        'Date': 'date',
        'Observed': 'Observed_Model1',
        'Predicted': 'Predicted_Model1'
    })
    model1_df['date'] = pd.to_datetime(model1_df['date'])

    # Set all negative values in the Predicted_Model1 column to zero
    model1_df.loc[model1_df['Predicted_Model1'] < 0, 'Predicted_Model1'] = 0

    model2_df = model2_df.rename(columns={
        'Date': 'date',
        'Observed': 'Observed_Model2',
        'Predicted': 'Predicted_Model2'
    })
    model2_df['date'] = pd.to_datetime(model2_df['date'])

    # Set all negative values in the Predicted_Model2 column to zero
    model2_df.loc[model2_df['Predicted_Model2'] < 0, 'Predicted_Model2'] = 0
    
    #This just gets the HMS prediceted values from the physics csv
    hms_df = pd.read_csv(HMS_results)
    hms_df = hms_df[3:]
    hms_df.columns = hms_df.columns.str.strip()
    hms_df = hms_df.drop(columns=['Ordinate'])
    hms_df = hms_df.rename(columns={'Date / Time': 'date'})
    hms_df['date'] = pd.to_datetime(hms_df['date'], format='%d-%b-%y')
    hms_df = hms_df.reset_index(drop=True)
    hms_df = hms_df.iloc[:, [0,1]] #Date, HMS predicted
    hms_df = hms_df.rename(columns={hms_df.columns[1]: "HMS_predicted"})
    hms_df["HMS_predicted"] = pd.to_numeric(hms_df["HMS_predicted"], errors="coerce")

    df = model1_df.merge(model2_df, how='right', on='date').merge(hms_df, how='right', on='date')

    # Filter for the test period
    test_start_date = pd.to_datetime("2005-10-01")
    test_end_date = pd.to_datetime("2009-09-30")
    df = df[(df['date'] >= test_start_date) & (df['date'] <= test_end_date)]

    # Convert pandas Series to xarray DataArray with a datetime coordinate
    obs_da = xr.DataArray(df['Observed_Model1'].values, dims=["date"], coords={"date": df['date']})
    sim_da_hms = xr.DataArray(df['HMS_predicted'].values, dims=["date"], coords={"date": df['date']})
    sim_da_lstm = xr.DataArray(df['Predicted_Model1'].values, dims=["date"], coords={"date": df['date']})
    sim_da_physics = xr.DataArray(df['Predicted_Model2'].values, dims=["date"], coords={"date": df['date']})

    # Collect metrics into a dictionary
    metrics = {
        "HMS": calculate_all_metrics(obs_da, sim_da_hms),
        "LSTM": calculate_all_metrics(obs_da, sim_da_lstm),
        "Physics_Informed_LSTM": calculate_all_metrics(obs_da, sim_da_physics),
    }

    metrics_df = pd.DataFrame(metrics)
    output_csv_path = "calpella_hourly_metrics.csv"
    metrics_df.to_csv(output_csv_path)

    # Plot all columns against the "date_col" (x-axis)
    plt.figure(figsize=(30, 10))
    
    plt.plot(df["date"], df["Observed_Model1"], label='Observed', linewidth=2)
    plt.plot(df["date"], df["HMS_predicted"], label='HMS Prediction',  linewidth=2, alpha=0.7)
    plt.plot(df["date"], df["Predicted_Model1"], label='LSTM Prediction', linewidth=2, alpha=0.8)
    plt.plot(df["date"], df["Predicted_Model2"], label='Physics Informed LSTM Prediction', linewidth=2, alpha=0.7)
    
    # Customize the plot
    plt.tick_params(axis='x', labelsize=15)  # For x-axis tick labels
    plt.tick_params(axis='y', labelsize=15) 
    plt.xlabel("Date", fontsize=20)
    plt.ylabel("Inflow (cubic feet per second)", fontsize=20)
    plt.title(title, fontsize=30)
    plt.legend(fontsize=25, loc="upper right")
    plt.grid(True, alpha=0.4)

    plt.xlim(test_start_date, test_end_date)

    #plt.gcf.autofmt_xdate()
    plt.tight_layout()
    plt.show()

    return plt

# %%
#change the paths to the respective ouptut csvs from running the result method
lstm_result_path = Path("F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_1212_160120/results_output.csv")
physics_informed_result_path = Path("F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_1212_162509/results_output.csv")
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/HMS_outputs_for_UCB/Calpella_daily.csv")
myplot = combinedPlot(lstm_results=lstm_result_path, lstmPhysics_results= physics_informed_result_path, HMS_results=path_to_physics_data, title='Guerneville Basin Model Comparison')

# %% [markdown]
# Old notebook: Comparison to results from physicsLSTM : The following cells test the physics informed for the validation period, the way evan did in the testing_notebook

# %%
run_dir = Path('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_3011_134216')
eval_run(run_dir=run_dir, period="test")

# %%
with open(run_dir / "test" / "model_epoch032" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)
    
results['Calpella']['1D']['xr']

# %%
# extract observations and LSTM simulations
qobs = results['Calpella']['1D']['xr']['NR CALPELLA FLOW COE CPL_obs']
qsim = results['Calpella']['1D']['xr']['NR CALPELLA FLOW COE CPL_sim']

fig, ax = plt.subplots(figsize=(16,10))
ax.plot(qobs["date"], qobs, label="Obs")
ax.plot(qsim["date"], qsim, label="Sim")
ax.set_ylabel("NR Calpella Flow")
ax.legend()
ax.set_title(f"Calpella Gage Validation period - NSE {results['Calpella']['1D']['NSE']:.3f}")

# %% [markdown]
# The following function combines the the results for the normal lstm, physics informed lstm and the hms results on one graph over a specified time period. (Also computes NSE for HMS model and recomputes NSE for LSTMS including setting all negative values to 0.)

# %%
import xarray as xr

# %%
def combinedPlot(lstm_results: Path, lstmPhysics_results: Path, HMS_results: Path, title: str, 
                 test_start_date="01/10/2005", test_end_date="30/09/2009"):
    model1_df = pd.read_csv(lstm_results) #colums: Date, Observed, Predicted
    model2_df = pd.read_csv(lstmPhysics_results) #colums: Date, Observed, Predicted
    model1_df = model1_df.rename(columns={
        'Date': 'date',
        'Observed': 'Observed_Model1',
        'Predicted': 'Predicted_Model1'
    })
    model1_df['date'] = pd.to_datetime(model1_df['date'])

    # Set all negative values in the Predicted_Model1 column to zero
    model1_df.loc[model1_df['Predicted_Model1'] < 0, 'Predicted_Model1'] = 0

    model2_df = model2_df.rename(columns={
        'Date': 'date',
        'Observed': 'Observed_Model2',
        'Predicted': 'Predicted_Model2'
    })
    model2_df['date'] = pd.to_datetime(model2_df['date'])

    # Set all negative values in the Predicted_Model2 column to zero
    model2_df.loc[model2_df['Predicted_Model2'] < 0, 'Predicted_Model2'] = 0
    
    #This just gets the HMS prediceted values from the capella.csv thy gave us
    hms_df = pd.read_csv(HMS_results)
    hms_df = hms_df[2:]
    hms_df.columns = hms_df.columns.str.strip()
    hms_df = hms_df.drop(columns=['Ordinate'])
    hms_df = hms_df.rename(columns={'Date / Time': 'date'})
    hms_df['date'] = pd.to_datetime(hms_df['date'], format='%d-%b-%y')
    hms_df = hms_df.reset_index(drop=True)
    hms_df = hms_df.iloc[:, [0,1]] #Date, HMS predicted
    hms_df = hms_df.rename(columns={hms_df.columns[1]: "HMS_predicted"})
    hms_df["HMS_predicted"] = pd.to_numeric(hms_df["HMS_predicted"], errors="coerce")

    df = model1_df.merge(model2_df, how='right', on='date').merge(hms_df, how='right', on='date')

    # Filter for the test period
    test_start_date = pd.to_datetime("2005-10-01")
    test_end_date = pd.to_datetime("2009-09-30")
    df = df[(df['date'] >= test_start_date) & (df['date'] <= test_end_date)]

    # # print nse for each model
    # print("The metrics for HMS is:", calculate_all_metrics(xr.DataArray(df['Observed_Model1'], dims=["time"]), xr.DataArray(df['HMS_predicted'], dims=["time"])))
    # print("The metrics for pure LSTM is:", calculate_all_metrics(df['Observed_Model1'], df['Predicted_Model1']))
    # print("The metrics for Physics Informed LSTM is:", calculate_all_metrics(df['Observed_Model2'], df['Predicted_Model2']))
    # Convert pandas Series to xarray DataArray with a datetime coordinate
    obs_da = xr.DataArray(df['Observed_Model1'].values, dims=["date"], coords={"date": df['date']})
    sim_da_hms = xr.DataArray(df['HMS_predicted'].values, dims=["date"], coords={"date": df['date']})
    sim_da_lstm = xr.DataArray(df['Predicted_Model1'].values, dims=["date"], coords={"date": df['date']})
    sim_da_physics = xr.DataArray(df['Predicted_Model2'].values, dims=["date"], coords={"date": df['date']})

    # Collect metrics into a dictionary
    metrics = {
        "HMS": calculate_all_metrics(obs_da, sim_da_hms),
        "LSTM": calculate_all_metrics(obs_da, sim_da_lstm),
        "Physics_Informed_LSTM": calculate_all_metrics(obs_da, sim_da_physics),
    }

    metrics_df = pd.DataFrame(metrics)
    output_csv_path = "calpella_hourly_metrics.csv"
    metrics_df.to_csv(output_csv_path)

    # Pass xarray DataArrays with coordinates to calculate_all_metrics
    print("The metrics for HMS is:", calculate_all_metrics(obs_da, sim_da_hms))
    print("The metrics for pure LSTM is:", calculate_all_metrics(obs_da, sim_da_lstm))
    print("The metrics for Physics Informed LSTM is:", calculate_all_metrics(obs_da, sim_da_physics))

    # Plot all columns against the "date_col" (x-axis)
    plt.figure(figsize=(30, 10))
    
    plt.plot(df["date"], df["Observed_Model1"], label='Observed', linewidth=2) #color="blue",
    plt.plot(df["date"], df["Predicted_Model1"], label='LSTM Prediction', linewidth=2, alpha=0.8) #color="purple",
    plt.plot(df["date"], df["Predicted_Model2"], label='Physics Informed LSTM Prediction', linewidth=2, alpha=0.7) #color="orange",
    plt.plot(df["date"], df["HMS_predicted"], label='HMS Prediction',  linewidth=2, alpha=0.7) #color="lightblue",

    # Customize the plot
    plt.tick_params(axis='x', labelsize=15)  # For x-axis tick labels
    plt.tick_params(axis='y', labelsize=15) 
    plt.xlabel("Date", fontsize=20)
    plt.ylabel("Inflow (cubic feet per second)", fontsize=20)
    plt.title(title, fontsize=30)
    plt.legend(fontsize=25, loc="upper right")
    plt.grid(True, alpha=0.4)

    plt.xlim(test_start_date, test_end_date)

    #plt.gcf.autofmt_xdate()
    plt.tight_layout()
    plt.show()

# %%
lstm_result_path = Path('F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_1212_160120\results_output.csv')
physics_informed_result_path = Path('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_1212_161102/results_output.csv')
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/HMS_outputs_for_UCB/Calpella_hourly.csv")
combinedPlot(lstm_results=lstm_result_path, lstmPhysics_results= physics_informed_result_path, HMS_results=path_to_physics_data, title='Calpella Hourly Model Comparison')

# %%
import plotly.graph_objects as go

def combinedPlotFancy(lstm_results: Path, lstmPhysics_results: Path, HMS_results: Path, title: str, 
                 test_start_date="01/10/2005", test_end_date="30/09/2009"):
    # Load and preprocess Model 1 (LSTM)
    model1_df = pd.read_csv(lstm_results)  # Columns: Date, Observed, Predicted
    model1_df = model1_df.rename(columns={
        'Date': 'date',
        'Observed': 'Observed_Model1',
        'Predicted': 'Predicted_Model1'
    })
    model1_df['date'] = pd.to_datetime(model1_df['date'])

    # Load and preprocess Model 2 (Physics-Informed LSTM)
    model2_df = pd.read_csv(lstmPhysics_results)  # Columns: Date, Observed, Predicted
    model2_df = model2_df.rename(columns={
        'Date': 'date',
        'Observed': 'Observed_Model2',
        'Predicted': 'Predicted_Model2'
    })
    model2_df['date'] = pd.to_datetime(model2_df['date'])

    # Load and preprocess HMS results
    hms_df = pd.read_csv(HMS_results)
    hms_df = hms_df[2:]
    hms_df.columns = hms_df.columns.str.strip()
    hms_df = hms_df.drop(columns=['Ordinate'])
    hms_df = hms_df.rename(columns={'Date / Time': 'date'})
    hms_df['date'] = pd.to_datetime(hms_df['date'], format='%d-%b-%y')
    hms_df = hms_df.reset_index(drop=True)
    hms_df = hms_df.iloc[:, [0, 1]]  # Keep only Date and HMS_predicted columns
    hms_df = hms_df.rename(columns={hms_df.columns[1]: "HMS_predicted"})
    hms_df["HMS_predicted"] = pd.to_numeric(hms_df["HMS_predicted"], errors="coerce")

    # Merge dataframes
    df = model1_df.merge(model2_df, how='right', on='date').merge(hms_df, how='right', on='date')

    # Filter for the test period
    test_start_date = pd.to_datetime(test_start_date, format='%d/%m/%Y')
    test_end_date = pd.to_datetime(test_end_date, format='%d/%m/%Y')
    df = df[(df['date'] >= test_start_date) & (df['date'] <= test_end_date)]

    # Create Plotly figure
    fig = go.Figure()

    # Add traces for each model
    fig.add_trace(go.Scatter(x=df["date"], y=df["Observed_Model1"], mode='lines',
                             name='Observed', line=dict(width=1.5)))
    fig.add_trace(go.Scatter(x=df["date"], y=df["Predicted_Model1"], mode='lines',
                             name='LSTM Prediction', line=dict(width=1.5)))
    fig.add_trace(go.Scatter(x=df["date"], y=df["Predicted_Model2"], mode='lines',
                             name='Physics-Informed LSTM Prediction', line=dict(width=1.5)))
    fig.add_trace(go.Scatter(x=df["date"], y=df["HMS_predicted"], mode='lines',
                             name='HMS Prediction', line=dict(width=1.2)))

    # Customize layout
    fig.update_layout(
        title=title,
        xaxis_title="Date",
        yaxis_title="Inflow (cubic feet per second)",
        template="seaborn",
        hovermode="x unified",
        xaxis=dict(
            rangeslider=dict(visible=True),  # Add range slider for zooming
            rangeselector=dict(
                buttons=[
                    dict(count=1, label="1m", step="month", stepmode="backward"),
                    dict(count=6, label="6m", step="month", stepmode="backward"),
                    dict(count=1, label="1y", step="year", stepmode="backward"),
                    dict(step="all")
                ]
            )
        )
    )

    # Zoom label formatting based on zoom level
    fig.update_xaxes(
        tickformatstops=[
            dict(dtickrange=[None, 1000], value="%Y-%m-%d"),
            dict(dtickrange=[1000, 86400000], value="%b %d, %Y"),
            dict(dtickrange=[86400000, "M1"], value="%b %Y"),
            dict(dtickrange=["M1", None], value="%Y"),
        ]
    )

    # Show plot
    fig.show()

# %%
combinedPlotFancy(lstm_results=lstm_result_path, lstmPhysics_results= physics_informed_result_path, HMS_results=path_to_physics_data, title='Calpella Basin Model Comparison')
