# %%
import sys
import os 

library_path = os.path.join('..', '..', '..', 'UCB-USACE-LSTMs')
sys.path.insert(0, library_path)

from UCB_train import UCB_trainer
from pathlib import Path
import matplotlib.pyplot as plt
from neuralhydrology.evaluation.metrics import calculate_all_metrics

# %%
path_to_csv = Path('/Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 1, 'validate_every': 1, 'save_weights_every': 1}
num_ensemble_members = 1
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members, physics_informed=True)

# %%
trainer.train()
# Out:
# 2024-10-30 17:23:00,661: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300/output.log initialized.
# 2024-10-30 17:23:00,662: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300
# 2024-10-30 17:23:00,662: ### Run configurations for testing_run
# 2024-10-30 17:23:00,663: experiment_name: testing_run
# 2024-10-30 17:23:00,663: train_basin_file: train_basin_file_template
# 2024-10-30 17:23:00,663: validation_basin_file: train_basin_file_template
# 2024-10-30 17:23:00,664: test_basin_file: train_basin_file_template
# 2024-10-30 17:23:00,664: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 17:23:00,664: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 17:23:00,664: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 17:23:00,665: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 17:23:00,665: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 17:23:00,665: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 17:23:00,666: device: cpu
# 2024-10-30 17:23:00,666: physics_informed: True
# 2024-10-30 17:23:00,666: validate_every: 1
# 2024-10-30 17:23:00,666: validate_n_random_basins: 1
# 2024-10-30 17:23:00,667: metrics: ['NSE', 'MSE']
# 2024-10-30 17:23:00,667: model: cudalstm
# 2024-10-30 17:23:00,667: head: regression
# 2024-10-30 17:23:00,668: output_activation: linear
# 2024-10-30 17:23:00,668: hidden_size: 64
# 2024-10-30 17:23:00,668: initial_forget_bias: 3
# 2024-10-30 17:23:00,668: output_dropout: 0.5
# 2024-10-30 17:23:00,669: optimizer: Adam
# 2024-10-30 17:23:00,669: loss: MSE
# 2024-10-30 17:23:00,669: learning_rate: 0.001
# 2024-10-30 17:23:00,669: batch_size: 256
# 2024-10-30 17:23:00,670: epochs: 1
# 2024-10-30 17:23:00,670: clip_gradient_norm: 1
# 2024-10-30 17:23:00,670: predict_last_n: 1
# 2024-10-30 17:23:00,671: seq_length: 365
# 2024-10-30 17:23:00,671: num_workers: 8
# 2024-10-30 17:23:00,671: log_interval: 4
# 2024-10-30 17:23:00,672: log_tensorboard: True
# 2024-10-30 17:23:00,672: log_n_figures: 1
# 2024-10-30 17:23:00,672: save_weights_every: 1
# 2024-10-30 17:23:00,672: dataset: tuler
# 2024-10-30 17:23:00,673: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 17:23:00,673: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-30 17:23:00,673: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 17:23:00,673: number_of_basins: 1
# 2024-10-30 17:23:00,674: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300
# 2024-10-30 17:23:00,674: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300/train_data
# 2024-10-30 17:23:00,674: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300/img_log
# 2024-10-30 17:23:00,682: ### Device cpu will be used for training
# 2024-10-30 17:23:00,683: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 16.00it/s]
# 2024-10-30 17:23:01,018: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# # Epoch 1: 100%|██████████| 22/22 [00:17<00:00,  1.29it/s, Loss: 0.1217]
# 2024-10-30 17:23:19,929: Epoch 1 average loss: avg_loss: 0.32104, avg_total_loss: 0.32104
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# 2024-10-30 17:23:20,980: Epoch 1 average validation loss: 0.11247 -- Median validation metrics: avg_loss: 0.11247, NSE: 0.74287, MSE: 53327.48047
# 2024-10-30 17:23:20,999: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300/model_epoch001.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# 2024-10-30 17:23:21,932: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300/test/model_epoch001/test_metrics.csv
# 2024-10-30 17:23:21,932: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300/test/model_epoch001/test_results.p

# %%
trainer.results()
# Out:
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172300/results_output.csv
# {'NSE': 0.3585938811302185,
#  'MSE': 32890.1875,
#  'RMSE': 181.35652042317088,
#  'KGE': 0.4398847382380481,
#  'Alpha-NSE': 0.6124923932506309,
#  'Beta-KGE': 0.9399155378341675,
#  'Beta-NSE': -0.03627871116211589,
#  'Pearson-r': 0.6000539804220089,
#  'FHV': -49.52971041202545,
#  'FMS': -7.11786947874243,
#  'FLV': -649.764722226122,
#  'Peak-Timing': 0.7142857142857143,
#  'Peak-MAPE': 58.03033283778599}

# %%
trainer._plot_day_of_year_average()

# %%
trainer._plot_month_of_year_average()

# %%
# .311

# %%
path_to_csv = Path('/Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 1, 'validate_every': 1, 'save_weights_every': 1}
num_ensemble_members = 2
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members)

# %%
trainer.train()
# Out:
# 2024-10-30 17:23:22,425: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/output.log initialized.
# 2024-10-30 17:23:22,425: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322
# 2024-10-30 17:23:22,425: ### Run configurations for testing_run
# 2024-10-30 17:23:22,426: experiment_name: testing_run
# 2024-10-30 17:23:22,426: train_basin_file: train_basin_file_template
# 2024-10-30 17:23:22,427: validation_basin_file: train_basin_file_template
# 2024-10-30 17:23:22,427: test_basin_file: train_basin_file_template
# 2024-10-30 17:23:22,427: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 17:23:22,428: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 17:23:22,428: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 17:23:22,429: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 17:23:22,429: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 17:23:22,429: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 17:23:22,429: device: cpu
# 2024-10-30 17:23:22,430: physics_informed: True
# 2024-10-30 17:23:22,430: validate_every: 1
# 2024-10-30 17:23:22,431: validate_n_random_basins: 1
# 2024-10-30 17:23:22,431: metrics: ['NSE', 'MSE']
# 2024-10-30 17:23:22,431: model: cudalstm
# 2024-10-30 17:23:22,432: head: regression
# 2024-10-30 17:23:22,432: output_activation: linear
# 2024-10-30 17:23:22,432: hidden_size: 64
# 2024-10-30 17:23:22,433: initial_forget_bias: 3
# 2024-10-30 17:23:22,433: output_dropout: 0.5
# 2024-10-30 17:23:22,433: optimizer: Adam
# 2024-10-30 17:23:22,433: loss: MSE
# 2024-10-30 17:23:22,434: learning_rate: 0.001
# 2024-10-30 17:23:22,434: batch_size: 256
# 2024-10-30 17:23:22,434: epochs: 1
# 2024-10-30 17:23:22,435: clip_gradient_norm: 1
# 2024-10-30 17:23:22,435: predict_last_n: 1
# 2024-10-30 17:23:22,435: seq_length: 365
# 2024-10-30 17:23:22,436: num_workers: 8
# 2024-10-30 17:23:22,436: log_interval: 4
# 2024-10-30 17:23:22,436: log_tensorboard: True
# 2024-10-30 17:23:22,437: log_n_figures: 1
# 2024-10-30 17:23:22,437: save_weights_every: 1
# 2024-10-30 17:23:22,437: dataset: tuler
# 2024-10-30 17:23:22,438: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 17:23:22,438: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-30 17:23:22,438: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 17:23:22,439: number_of_basins: 1
# 2024-10-30 17:23:22,439: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322
# 2024-10-30 17:23:22,440: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/train_data
# 2024-10-30 17:23:22,440: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/img_log
# 2024-10-30 17:23:22,446: ### Device cpu will be used for training
# 2024-10-30 17:23:22,447: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 20.15it/s]
# 2024-10-30 17:23:22,510: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  6.74it/s]
# # Epoch 1: 100%|██████████| 22/22 [00:16<00:00,  1.37it/s, Loss: 0.1212]
# 2024-10-30 17:23:38,802: Epoch 1 average loss: avg_loss: 0.32968, avg_total_loss: 0.32968
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.64it/s]
# 2024-10-30 17:23:39,619: Epoch 1 average validation loss: 0.13714 -- Median validation metrics: avg_loss: 0.13714, NSE: 0.68634, MSE: 65051.53906
# 2024-10-30 17:23:39,623: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/output.log initialized.
# 2024-10-30 17:23:39,623: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339
# 2024-10-30 17:23:39,624: ### Run configurations for testing_run
# 2024-10-30 17:23:39,624: experiment_name: testing_run
# 2024-10-30 17:23:39,625: train_basin_file: train_basin_file_template
# 2024-10-30 17:23:39,625: validation_basin_file: train_basin_file_template
# 2024-10-30 17:23:39,626: test_basin_file: train_basin_file_template
# 2024-10-30 17:23:39,626: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 17:23:39,626: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 17:23:39,627: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 17:23:39,627: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 17:23:39,627: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 17:23:39,628: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 17:23:39,628: device: cpu
# 2024-10-30 17:23:39,629: physics_informed: True
# 2024-10-30 17:23:39,629: validate_every: 1
# 2024-10-30 17:23:39,630: validate_n_random_basins: 1
# 2024-10-30 17:23:39,630: metrics: ['NSE', 'MSE']
# 2024-10-30 17:23:39,630: model: cudalstm
# 2024-10-30 17:23:39,631: head: regression
# 2024-10-30 17:23:39,631: output_activation: linear
# 2024-10-30 17:23:39,631: hidden_size: 64
# 2024-10-30 17:23:39,631: initial_forget_bias: 3
# 2024-10-30 17:23:39,632: output_dropout: 0.5
# 2024-10-30 17:23:39,632: optimizer: Adam
# 2024-10-30 17:23:39,632: loss: MSE
# 2024-10-30 17:23:39,633: learning_rate: 0.001
# 2024-10-30 17:23:39,633: batch_size: 256
# 2024-10-30 17:23:39,634: epochs: 1
# 2024-10-30 17:23:39,634: clip_gradient_norm: 1
# 2024-10-30 17:23:39,634: predict_last_n: 1
# 2024-10-30 17:23:39,635: seq_length: 365
# 2024-10-30 17:23:39,635: num_workers: 8
# 2024-10-30 17:23:39,635: log_interval: 4
# 2024-10-30 17:23:39,636: log_tensorboard: True
# 2024-10-30 17:23:39,636: log_n_figures: 1
# 2024-10-30 17:23:39,636: save_weights_every: 1
# 2024-10-30 17:23:39,637: dataset: tuler
# 2024-10-30 17:23:39,637: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 17:23:39,637: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-30 17:23:39,637: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 17:23:39,638: number_of_basins: 1
# 2024-10-30 17:23:39,638: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339
# 2024-10-30 17:23:39,638: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/train_data
# 2024-10-30 17:23:39,639: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/img_log
# 2024-10-30 17:23:39,639: seed: 969378
# 2024-10-30 17:23:39,639: commit_hash: 0514d7f
# 2024-10-30 17:23:39,640: package_version: 1.11.0
# 2024-10-30 17:23:39,646: ### Device cpu will be used for training
# 2024-10-30 17:23:39,647: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 19.90it/s]
# 2024-10-30 17:23:39,707: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  6.92it/s]
# # Epoch 1: 100%|██████████| 22/22 [00:16<00:00,  1.33it/s, Loss: 0.1212]
# 2024-10-30 17:23:56,558: Epoch 1 average loss: avg_loss: 0.32968, avg_total_loss: 0.32968
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]
# 2024-10-30 17:23:57,488: Epoch 1 average validation loss: 0.13714 -- Median validation metrics: avg_loss: 0.13714, NSE: 0.68634, MSE: 65051.53906
# 2024-10-30 17:23:57,509: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/model_epoch001.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# 2024-10-30 17:23:58,718: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/test/model_epoch001/test_metrics.csv
# 2024-10-30 17:23:58,719: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/test/model_epoch001/test_results.p
# 2024-10-30 17:23:58,736: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/model_epoch001.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# 2024-10-30 17:23:59,648: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/test/model_epoch001/test_metrics.csv
# 2024-10-30 17:23:59,649: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/test/model_epoch001/test_results.p
# Loading results for each run.
# 100%|██████████| 2/2 [00:00<00:00, 1539.76it/s]
# Combining results and calculating metrics.
# 100%|██████████| 1/1 [00:00<00:00, 138.51it/s]

# %%
trainer.results()
# Out:
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/results_output.csv
# {'NSE': 0.32648801803588867,
#  'MSE': 34536.51953125,
#  'RMSE': 185.84003748183542,
#  'KGE': 0.46593204804198785,
#  'Alpha-NSE': 0.7249248489212482,
#  'Beta-KGE': 1.2228786945343018,
#  'Beta-NSE': 0.13457310797881383,
#  'Pearson-r': 0.600140867191566,
#  'FHV': -47.75761663913727,
#  'FMS': 18.482442630389077,
#  'FLV': -738.1989728263519,
#  'Peak-Timing': 0.5714285714285714,
#  'Peak-MAPE': 55.72514874594552}

# %%
trainer._plot_day_of_year_average()

# %%
trainer._plot_month_of_year_average()

# %%
new_dynamic_inputs = [
    "MF_TuleR_S10ET-POTENTIAL",
    "MF_TuleR_S10FLOW",
    "MF_TuleR_S10PRECIP-INC"
]

# %%
trainer._config.update_config(yml_path_or_dict=params, new_dynamic_inputs=new_dynamic_inputs)

# %%
trainer.train()
# Out:
# 2024-10-30 17:24:00,249: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/output.log initialized.
# 2024-10-30 17:24:00,249: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400
# 2024-10-30 17:24:00,249: ### Run configurations for testing_run
# 2024-10-30 17:24:00,250: experiment_name: testing_run
# 2024-10-30 17:24:00,250: train_basin_file: train_basin_file_template
# 2024-10-30 17:24:00,250: validation_basin_file: train_basin_file_template
# 2024-10-30 17:24:00,251: test_basin_file: train_basin_file_template
# 2024-10-30 17:24:00,251: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 17:24:00,251: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 17:24:00,252: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 17:24:00,252: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 17:24:00,252: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 17:24:00,253: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 17:24:00,253: device: cpu
# 2024-10-30 17:24:00,253: physics_informed: True
# 2024-10-30 17:24:00,254: validate_every: 1
# 2024-10-30 17:24:00,254: validate_n_random_basins: 1
# 2024-10-30 17:24:00,254: metrics: ['NSE', 'MSE']
# 2024-10-30 17:24:00,255: model: cudalstm
# 2024-10-30 17:24:00,255: head: regression
# 2024-10-30 17:24:00,256: output_activation: linear
# 2024-10-30 17:24:00,256: hidden_size: 64
# 2024-10-30 17:24:00,256: initial_forget_bias: 3
# 2024-10-30 17:24:00,257: output_dropout: 0.5
# 2024-10-30 17:24:00,257: optimizer: Adam
# 2024-10-30 17:24:00,257: loss: MSE
# 2024-10-30 17:24:00,257: learning_rate: 0.001
# 2024-10-30 17:24:00,258: batch_size: 256
# 2024-10-30 17:24:00,258: epochs: 1
# 2024-10-30 17:24:00,258: clip_gradient_norm: 1
# 2024-10-30 17:24:00,258: predict_last_n: 1
# 2024-10-30 17:24:00,259: seq_length: 365
# 2024-10-30 17:24:00,259: num_workers: 8
# 2024-10-30 17:24:00,259: log_interval: 4
# 2024-10-30 17:24:00,259: log_tensorboard: True
# 2024-10-30 17:24:00,260: log_n_figures: 1
# 2024-10-30 17:24:00,260: save_weights_every: 1
# 2024-10-30 17:24:00,260: dataset: tuler
# 2024-10-30 17:24:00,261: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 17:24:00,261: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC']
# 2024-10-30 17:24:00,261: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 17:24:00,262: number_of_basins: 1
# 2024-10-30 17:24:00,262: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400
# 2024-10-30 17:24:00,262: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/train_data
# 2024-10-30 17:24:00,262: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/img_log
# 2024-10-30 17:24:00,263: seed: 969378
# 2024-10-30 17:24:00,263: commit_hash: 0514d7f
# 2024-10-30 17:24:00,263: package_version: 1.11.0
# 2024-10-30 17:24:00,267: ### Device cpu will be used for training
# 2024-10-30 17:24:00,268: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 25.59it/s]
# 2024-10-30 17:24:00,311: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 42.34it/s]
# # Epoch 1: 100%|██████████| 22/22 [00:15<00:00,  1.40it/s, Loss: 0.3213]
# 2024-10-30 17:24:16,142: Epoch 1 average loss: avg_loss: 0.36177, avg_total_loss: 0.36177
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]
# 2024-10-30 17:24:16,946: Epoch 1 average validation loss: 0.14953 -- Median validation metrics: avg_loss: 0.14953, NSE: 0.65873, MSE: 70777.53906
# 2024-10-30 17:24:16,951: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416/output.log initialized.
# 2024-10-30 17:24:16,951: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416
# 2024-10-30 17:24:16,952: ### Run configurations for testing_run
# 2024-10-30 17:24:16,952: experiment_name: testing_run
# 2024-10-30 17:24:16,953: train_basin_file: train_basin_file_template
# 2024-10-30 17:24:16,953: validation_basin_file: train_basin_file_template
# 2024-10-30 17:24:16,954: test_basin_file: train_basin_file_template
# 2024-10-30 17:24:16,954: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 17:24:16,955: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 17:24:16,956: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 17:24:16,956: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 17:24:16,957: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 17:24:16,957: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 17:24:16,958: device: cpu
# 2024-10-30 17:24:16,958: physics_informed: True
# 2024-10-30 17:24:16,959: validate_every: 1
# 2024-10-30 17:24:16,959: validate_n_random_basins: 1
# 2024-10-30 17:24:16,960: metrics: ['NSE', 'MSE']
# 2024-10-30 17:24:16,960: model: cudalstm
# 2024-10-30 17:24:16,961: head: regression
# 2024-10-30 17:24:16,961: output_activation: linear
# 2024-10-30 17:24:16,962: hidden_size: 64
# 2024-10-30 17:24:16,962: initial_forget_bias: 3
# 2024-10-30 17:24:16,963: output_dropout: 0.5
# 2024-10-30 17:24:16,963: optimizer: Adam
# 2024-10-30 17:24:16,963: loss: MSE
# 2024-10-30 17:24:16,964: learning_rate: 0.001
# 2024-10-30 17:24:16,964: batch_size: 256
# 2024-10-30 17:24:16,964: epochs: 1
# 2024-10-30 17:24:16,965: clip_gradient_norm: 1
# 2024-10-30 17:24:16,965: predict_last_n: 1
# 2024-10-30 17:24:16,965: seq_length: 365
# 2024-10-30 17:24:16,966: num_workers: 8
# 2024-10-30 17:24:16,966: log_interval: 4
# 2024-10-30 17:24:16,966: log_tensorboard: True
# 2024-10-30 17:24:16,967: log_n_figures: 1
# 2024-10-30 17:24:16,967: save_weights_every: 1
# 2024-10-30 17:24:16,967: dataset: tuler
# 2024-10-30 17:24:16,968: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 17:24:16,968: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC']
# 2024-10-30 17:24:16,968: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 17:24:16,969: number_of_basins: 1
# 2024-10-30 17:24:16,969: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416
# 2024-10-30 17:24:16,969: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416/train_data
# 2024-10-30 17:24:16,970: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416/img_log
# 2024-10-30 17:24:16,970: seed: 969378
# 2024-10-30 17:24:16,970: commit_hash: 0514d7f
# 2024-10-30 17:24:16,971: package_version: 1.11.0
# 2024-10-30 17:24:16,975: ### Device cpu will be used for training
# 2024-10-30 17:24:16,976: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 14.76it/s]
# 2024-10-30 17:24:17,048: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 39.49it/s]
# # Epoch 1: 100%|██████████| 22/22 [00:21<00:00,  1.04it/s, Loss: 0.3213]
# 2024-10-30 17:24:38,321: Epoch 1 average loss: avg_loss: 0.36177, avg_total_loss: 0.36177
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# 2024-10-30 17:24:39,100: Epoch 1 average validation loss: 0.14953 -- Median validation metrics: avg_loss: 0.14953, NSE: 0.65873, MSE: 70777.53906
# 2024-10-30 17:24:39,109: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/model_epoch001.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# 2024-10-30 17:24:40,045: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/test/model_epoch001/test_metrics.csv
# 2024-10-30 17:24:40,046: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/test/model_epoch001/test_results.p
# 2024-10-30 17:24:40,055: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416/model_epoch001.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# 2024-10-30 17:24:41,027: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416/test/model_epoch001/test_metrics.csv
# 2024-10-30 17:24:41,028: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416/test/model_epoch001/test_results.p
# Loading results for each run.
# 100%|██████████| 2/2 [00:00<00:00, 1346.92it/s]
# Combining results and calculating metrics.
# 100%|██████████| 1/1 [00:00<00:00, 136.32it/s]

# %%
trainer.results()
# Out:
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_172322/testing_run_3010_172339/testing_run_3010_172400/testing_run_3010_172416/results_output.csv
# {'NSE': 0.29708534479141235,
#  'MSE': 36044.23828125,
#  'RMSE': 189.853201925198,
#  'KGE': 0.4166040945952372,
#  'Alpha-NSE': 0.7208218031825069,
#  'Beta-KGE': 1.3076627254486084,
#  'Beta-NSE': 0.18576532675347407,
#  'Pearson-r': 0.5904222122303137,
#  'FHV': -43.9242422580719,
#  'FMS': -13.639416981861945,
#  'FLV': -469.2557232959855,
#  'Peak-Timing': 1.4285714285714286,
#  'Peak-MAPE': 61.3358770098005}

# %%
print("Dynamic Inputs used for training:", trainer._config.as_dict().get("dynamic_inputs"))
# Out:
# Dynamic Inputs used for training: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC']
