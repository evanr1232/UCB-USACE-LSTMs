# %%
import sys
import os 

library_path = os.path.join('..', '..', '..', 'UCB-USACE-LSTMs')
sys.path.insert(0, library_path)

from UCB_train import UCB_trainer
from pathlib import Path
import matplotlib.pyplot as plt
from neuralhydrology.evaluation.metrics import calculate_all_metrics

# %%
path_to_csv = Path('/Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 1, 'validate_every': 1, 'save_weights_every': 1}
num_ensemble_members = 1
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members, physics_informed=True)

# %%
trainer.train()
# Out:
# 2024-10-30 11:35:52,094: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_113552/output.log initialized.
# 2024-10-30 11:35:52,095: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_113552
# 2024-10-30 11:35:52,095: ### Run configurations for testing_run
# 2024-10-30 11:35:52,096: experiment_name: testing_run
# 2024-10-30 11:35:52,096: train_basin_file: train_basin_file_template
# 2024-10-30 11:35:52,097: validation_basin_file: train_basin_file_template
# 2024-10-30 11:35:52,097: test_basin_file: train_basin_file_template
# 2024-10-30 11:35:52,098: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 11:35:52,098: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 11:35:52,099: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 11:35:52,099: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 11:35:52,100: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 11:35:52,100: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 11:35:52,101: device: cpu
# 2024-10-30 11:35:52,102: physics_informed: True
# 2024-10-30 11:35:52,102: validate_every: 1
# 2024-10-30 11:35:52,103: validate_n_random_basins: 1
# 2024-10-30 11:35:52,103: metrics: ['NSE', 'MSE']
# 2024-10-30 11:35:52,104: model: cudalstm
# 2024-10-30 11:35:52,104: head: regression
# 2024-10-30 11:35:52,105: output_activation: linear
# 2024-10-30 11:35:52,105: hidden_size: 64
# 2024-10-30 11:35:52,106: initial_forget_bias: 3
# 2024-10-30 11:35:52,106: output_dropout: 0.5
# 2024-10-30 11:35:52,106: optimizer: Adam
# 2024-10-30 11:35:52,107: loss: MSE
# 2024-10-30 11:35:52,107: learning_rate: 0.001
# 2024-10-30 11:35:52,107: batch_size: 256
# 2024-10-30 11:35:52,108: epochs: 1
# 2024-10-30 11:35:52,108: clip_gradient_norm: 1
# 2024-10-30 11:35:52,109: predict_last_n: 1
# 2024-10-30 11:35:52,109: seq_length: 365
# 2024-10-30 11:35:52,109: num_workers: 8
# 2024-10-30 11:35:52,110: log_interval: 4
# 2024-10-30 11:35:52,110: log_tensorboard: True
# 2024-10-30 11:35:52,110: log_n_figures: 1
# 2024-10-30 11:35:52,111: save_weights_every: 1
# 2024-10-30 11:35:52,111: dataset: tuler
# 2024-10-30 11:35:52,111: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 11:35:52,112: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-30 11:35:52,112: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 11:35:52,112: number_of_basins: 1
# 2024-10-30 11:35:52,113: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_113552
# 2024-10-30 11:35:52,113: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_113552/train_data
# 2024-10-30 11:35:52,113: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_113552/img_log
# 2024-10-30 11:35:52,122: ### Device cpu will be used for training
# 2024-10-30 11:35:52,123: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 17.77it/s]
# 2024-10-30 11:35:52,268: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# # Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]

# %%
trainer.results()
# Out:
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102002/results_output.csv
# {'NSE': 0.3485864996910095,
#  'MSE': 33403.34765625,
#  'RMSE': 182.76582737549708,
#  'KGE': 0.4092517546931379,
#  'Alpha-NSE': 0.5746896031849192,
#  'Beta-KGE': 0.9737921357154846,
#  'Beta-NSE': -0.01582419495811411,
#  'Pearson-r': 0.5908451350114734,
#  'FHV': -55.922931432724,
#  'FMS': 0.717408101618082,
#  'FLV': -724.7325684013679,
#  'Peak-Timing': 0.42857142857142855,
#  'Peak-MAPE': 63.435016359601704}

# %%
trainer._plot_day_of_year_average()

# %%
trainer._plot_month_of_year_average()

# %%
# .311

# %%
path_to_csv = Path('/Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 1, 'validate_every': 1, 'save_weights_every': 1}
num_ensemble_members = 2
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members)

# %%
trainer.train()
# Out:
# 2024-10-30 10:21:01,040: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/output.log initialized.
# 2024-10-30 10:21:01,041: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101
# 2024-10-30 10:21:01,041: ### Run configurations for testing_run
# 2024-10-30 10:21:01,041: experiment_name: testing_run
# 2024-10-30 10:21:01,042: train_basin_file: train_basin_file_template
# 2024-10-30 10:21:01,042: validation_basin_file: train_basin_file_template
# 2024-10-30 10:21:01,042: test_basin_file: train_basin_file_template
# 2024-10-30 10:21:01,043: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 10:21:01,043: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 10:21:01,043: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 10:21:01,043: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 10:21:01,044: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 10:21:01,044: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 10:21:01,044: device: cpu
# 2024-10-30 10:21:01,044: physics_informed: True
# 2024-10-30 10:21:01,045: validate_every: 1
# 2024-10-30 10:21:01,045: validate_n_random_basins: 1
# 2024-10-30 10:21:01,045: metrics: ['NSE', 'MSE']
# 2024-10-30 10:21:01,045: model: cudalstm
# 2024-10-30 10:21:01,046: head: regression
# 2024-10-30 10:21:01,046: output_activation: linear
# 2024-10-30 10:21:01,046: hidden_size: 64
# 2024-10-30 10:21:01,046: initial_forget_bias: 3
# 2024-10-30 10:21:01,047: output_dropout: 0.5
# 2024-10-30 10:21:01,047: optimizer: Adam
# 2024-10-30 10:21:01,047: loss: MSE
# 2024-10-30 10:21:01,047: learning_rate: 0.001
# 2024-10-30 10:21:01,048: batch_size: 256
# 2024-10-30 10:21:01,048: epochs: 1
# 2024-10-30 10:21:01,048: clip_gradient_norm: 1
# 2024-10-30 10:21:01,048: predict_last_n: 1
# 2024-10-30 10:21:01,049: seq_length: 365
# 2024-10-30 10:21:01,049: num_workers: 8
# 2024-10-30 10:21:01,049: log_interval: 4
# 2024-10-30 10:21:01,049: log_tensorboard: True
# 2024-10-30 10:21:01,050: log_n_figures: 1
# 2024-10-30 10:21:01,050: save_weights_every: 1
# 2024-10-30 10:21:01,050: dataset: tuler
# 2024-10-30 10:21:01,050: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 10:21:01,051: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-30 10:21:01,051: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 10:21:01,051: number_of_basins: 1
# 2024-10-30 10:21:01,051: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101
# 2024-10-30 10:21:01,052: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/train_data
# 2024-10-30 10:21:01,052: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/img_log
# 2024-10-30 10:21:01,057: ### Device cpu will be used for training
# 2024-10-30 10:21:01,058: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 21.10it/s]
# 2024-10-30 10:21:01,116: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  6.92it/s]
# # Epoch 1: 100%|██████████| 22/22 [00:15<00:00,  1.39it/s, Loss: 0.1319]
# 2024-10-30 10:21:17,250: Epoch 1 average loss: avg_loss: 0.35239, avg_total_loss: 0.35239
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
# 2024-10-30 10:21:18,046: Epoch 1 average validation loss: 0.13666 -- Median validation metrics: avg_loss: 0.13666, NSE: 0.68780, MSE: 64749.81641
# 2024-10-30 10:21:18,050: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118/output.log initialized.
# 2024-10-30 10:21:18,050: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118
# 2024-10-30 10:21:18,051: ### Run configurations for testing_run
# 2024-10-30 10:21:18,051: experiment_name: testing_run
# 2024-10-30 10:21:18,051: train_basin_file: train_basin_file_template
# 2024-10-30 10:21:18,052: validation_basin_file: train_basin_file_template
# 2024-10-30 10:21:18,052: test_basin_file: train_basin_file_template
# 2024-10-30 10:21:18,053: train_start_date: 1981-10-01 00:00:00
# 2024-10-30 10:21:18,053: train_end_date: 1997-09-30 00:00:00
# 2024-10-30 10:21:18,053: validation_start_date: 1997-10-01 00:00:00
# 2024-10-30 10:21:18,054: validation_end_date: 2000-09-30 00:00:00
# 2024-10-30 10:21:18,054: test_start_date: 2000-10-01 00:00:00
# 2024-10-30 10:21:18,055: test_end_date: 2005-09-30 00:00:00
# 2024-10-30 10:21:18,055: device: cpu
# 2024-10-30 10:21:18,055: physics_informed: True
# 2024-10-30 10:21:18,056: validate_every: 1
# 2024-10-30 10:21:18,056: validate_n_random_basins: 1
# 2024-10-30 10:21:18,056: metrics: ['NSE', 'MSE']
# 2024-10-30 10:21:18,057: model: cudalstm
# 2024-10-30 10:21:18,057: head: regression
# 2024-10-30 10:21:18,057: output_activation: linear
# 2024-10-30 10:21:18,058: hidden_size: 64
# 2024-10-30 10:21:18,058: initial_forget_bias: 3
# 2024-10-30 10:21:18,058: output_dropout: 0.5
# 2024-10-30 10:21:18,059: optimizer: Adam
# 2024-10-30 10:21:18,059: loss: MSE
# 2024-10-30 10:21:18,059: learning_rate: 0.001
# 2024-10-30 10:21:18,060: batch_size: 256
# 2024-10-30 10:21:18,060: epochs: 1
# 2024-10-30 10:21:18,060: clip_gradient_norm: 1
# 2024-10-30 10:21:18,061: predict_last_n: 1
# 2024-10-30 10:21:18,061: seq_length: 365
# 2024-10-30 10:21:18,061: num_workers: 8
# 2024-10-30 10:21:18,062: log_interval: 4
# 2024-10-30 10:21:18,062: log_tensorboard: True
# 2024-10-30 10:21:18,062: log_n_figures: 1
# 2024-10-30 10:21:18,063: save_weights_every: 1
# 2024-10-30 10:21:18,063: dataset: tuler
# 2024-10-30 10:21:18,063: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-30 10:21:18,064: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-30 10:21:18,064: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-30 10:21:18,064: number_of_basins: 1
# 2024-10-30 10:21:18,065: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118
# 2024-10-30 10:21:18,065: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118/train_data
# 2024-10-30 10:21:18,065: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118/img_log
# 2024-10-30 10:21:18,066: seed: 131715
# 2024-10-30 10:21:18,066: commit_hash: 3435bd0
# 2024-10-30 10:21:18,067: package_version: 1.11.0
# 2024-10-30 10:21:18,071: ### Device cpu will be used for training
# 2024-10-30 10:21:18,072: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 20.48it/s]
# 2024-10-30 10:21:18,131: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  6.99it/s]
# # Epoch 1: 100%|██████████| 22/22 [00:15<00:00,  1.43it/s, Loss: 0.1319]
# 2024-10-30 10:21:33,826: Epoch 1 average loss: avg_loss: 0.35239, avg_total_loss: 0.35239
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
# 2024-10-30 10:21:34,624: Epoch 1 average validation loss: 0.13666 -- Median validation metrics: avg_loss: 0.13666, NSE: 0.68780, MSE: 64749.81641
# 2024-10-30 10:21:34,643: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/model_epoch001.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# 2024-10-30 10:21:35,532: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/test/model_epoch001/test_metrics.csv
# 2024-10-30 10:21:35,533: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/test/model_epoch001/test_results.p
# 2024-10-30 10:21:35,550: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118/model_epoch001.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# 2024-10-30 10:21:36,485: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118/test/model_epoch001/test_metrics.csv
# 2024-10-30 10:21:36,486: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118/test/model_epoch001/test_results.p
# Loading results for each run.
# 100%|██████████| 2/2 [00:00<00:00, 1733.18it/s]
# Combining results and calculating metrics.
# 100%|██████████| 1/1 [00:00<00:00, 128.16it/s]

# %%
trainer.results()
# Out:
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_3010_102101/testing_run_3010_102118/results_output.csv
# {'NSE': 0.3739966154098511,
#  'MSE': 32100.361328125,
#  'RMSE': 179.16573703731694,
#  'KGE': 0.5122848313604262,
#  'Alpha-NSE': 0.7162533399449976,
#  'Beta-KGE': 1.1236908435821533,
#  'Beta-NSE': 0.07468397666672799,
#  'Pearson-r': 0.623098827485647,
#  'FHV': -40.30425846576691,
#  'FMS': 17.841783132930285,
#  'FLV': -751.7340688266734,
#  'Peak-Timing': 1.4285714285714286,
#  'Peak-MAPE': 55.64513547079903}

# %%
trainer._plot_day_of_year_average()

# %%
trainer._plot_month_of_year_average()
