# %% [markdown]
# ## Imports

# %%
import sys
import os
import pickle

library_path = os.path.join('..', '..', '..','UCB-USACE-LSTMs')
sys.path.insert(0, library_path)

from pathlib import Path
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation.metrics import *
from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble
from neuralhydrology.UCB_training.UCB_train import UCB_trainer
from neuralhydrology.UCB_training.UCB_train import clean_daily
from neuralhydrology.UCB_training.UCB_train import combinedPlot
from neuralhydrology.evaluation.metrics import calculate_all_metrics

# %% [markdown]
# ## Working directory

# %%
print("Current Working Directory:", os.getcwd())
print("Train Basin File Exists:", os.path.exists("warm springs"))
# Out:
# Current Working Directory: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all
# Train Basin File Exists: True

# %% [markdown]
# ## Standard daily LSTM, train on training subset, evaluate on evaluation period (for hyperparameter search)

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("warm_springs_dam.yaml")
params = {
    "epochs":5,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
#defaults to daily so no need to specify hourly
lstmNoPhysicsDaily = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params)

# %%
lstmNoPhysicsDaily.train()
# Out:
# 2025-01-16 13:33:36,058: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336\output.log initialized.
# 2025-01-16 13:33:36,060: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336
# 2025-01-16 13:33:36,063: ### Run configurations for testing_run
# 2025-01-16 13:33:36,065: experiment_name: testing_run
# 2025-01-16 13:33:36,068: train_basin_file: warm springs
# 2025-01-16 13:33:36,071: validation_basin_file: warm springs
# 2025-01-16 13:33:36,074: test_basin_file: warm springs
# 2025-01-16 13:33:36,076: train_start_date: 1994-10-01 00:00:00
# 2025-01-16 13:33:36,079: train_end_date: 2002-09-30 00:00:00
# 2025-01-16 13:33:36,082: validation_start_date: 2002-10-01 00:00:00
# 2025-01-16 13:33:36,084: validation_end_date: 2005-09-30 00:00:00
# 2025-01-16 13:33:36,086: test_start_date: 2005-10-01 00:00:00
# 2025-01-16 13:33:36,087: test_end_date: 2009-09-30 00:00:00
# 2025-01-16 13:33:36,089: device: cpu
# 2025-01-16 13:33:36,091: physics_informed: False
# 2025-01-16 13:33:36,092: physics_data_file: None
# 2025-01-16 13:33:36,093: validate_every: 5
# 2025-01-16 13:33:36,095: validate_n_random_basins: 1
# 2025-01-16 13:33:36,096: metrics: ['NSE', 'MSE']
# 2025-01-16 13:33:36,097: model: cudalstm
# 2025-01-16 13:33:36,099: head: regression
# 2025-01-16 13:33:36,100: output_activation: linear
# 2025-01-16 13:33:36,102: hidden_size: 128
# 2025-01-16 13:33:36,103: initial_forget_bias: 3
# 2025-01-16 13:33:36,104: output_dropout: 0.4
# 2025-01-16 13:33:36,106: optimizer: Adam
# 2025-01-16 13:33:36,107: loss: NSE
# 2025-01-16 13:33:36,109: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-16 13:33:36,110: batch_size: 256
# 2025-01-16 13:33:36,112: epochs: 5
# 2025-01-16 13:33:36,113: clip_gradient_norm: 1
# 2025-01-16 13:33:36,113: predict_last_n: 1
# 2025-01-16 13:33:36,114: seq_length: 90
# 2025-01-16 13:33:36,116: log_interval: 16
# 2025-01-16 13:33:36,117: log_tensorboard: True
# 2025-01-16 13:33:36,118: log_n_figures: 1
# 2025-01-16 13:33:36,119: save_weights_every: 5
# 2025-01-16 13:33:36,120: dataset: russian_river
# 2025-01-16 13:33:36,121: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-16 13:33:36,122: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA']
# 2025-01-16 13:33:36,123: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-16 13:33:36,124: hourly: False
# 2025-01-16 13:33:36,125: number_of_basins: 1
# 2025-01-16 13:33:36,126: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336
# 2025-01-16 13:33:36,127: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336\train_data
# 2025-01-16 13:33:36,128: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336\img_log
# 2025-01-16 13:33:36,137: ### Device cpu will be used for training
# 2025-01-16 13:33:36,139: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# 2025-01-16 13:33:36,341: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 251.37it/s]
# 2025-01-16 13:33:36,365: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:02<00:00,  2.67s/it]
# # Epoch 1: 100%|██████████| 12/12 [00:01<00:00,  8.44it/s, Loss: 0.0000]
# 2025-01-16 13:33:42,195: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 12/12 [00:01<00:00, 11.27it/s, Loss: 0.0000]
# 2025-01-16 13:33:43,267: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 12/12 [00:01<00:00, 11.17it/s, Loss: 0.0000]
# 2025-01-16 13:33:44,348: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 12/12 [00:01<00:00, 11.31it/s, Loss: 0.0000]
# 2025-01-16 13:33:45,417: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 12/12 [00:01<00:00, 11.19it/s, Loss: 0.0000]
# 2025-01-16 13:33:46,497: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# 2025-01-16 13:33:47,876: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.81341, MSE: 91481.49219
# 2025-01-16 13:33:47,946: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336\model_epoch005.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.54it/s]
# 2025-01-16 13:33:48,427: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336\validation\model_epoch005\validation_metrics.csv
# 2025-01-16 13:33:48,430: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336\validation\model_epoch005\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_1601_133336')

# %%
lstmNoPhysicsDaily.results()
# Out:
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133336\results_output_validation.csv
# ({'NSE': 0.8134148865938187,
#   'MSE': 91481.4921875,
#   'RMSE': 302.45907522754214,
#   'KGE': 0.7168662882188309,
#   'Alpha-NSE': 0.9116059773880155,
#   'Beta-KGE': 1.253319501876831,
#   'Beta-NSE': 0.11777046931134169,
#   'Pearson-r': 0.909554295390393,
#   'FHV': -8.119980990886688,
#   'FMS': -37.90319424113295,
#   'FLV': -2390.834908167396,
#   'Peak-Timing': 0.2,
#   'Peak-MAPE': 32.92501211166382},
#  WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_1601_133336/results_output_validation.csv'))

# %% [markdown]
# ## Physics-informed LSTM, train on training subset, evaluate on evaluation period (for hyperparameter search)

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("warm_springs_dam.yaml")
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv")
params = {
    "epochs":5,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
features_with_physics = [
    #from daily.csv
    "DRY CREEK 20 PRECIP-INC SCREENED",
    "DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "DRY CREEK 30 PRECIP-INC SCREENED",
    "DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    "SANTA ROSA CA HUMIDITY USAF-NOAA",
    "SANTA ROSA CA SOLAR RADIATION USAF-NOAA",
    "SANTA ROSA CA TEMPERATURE USAF-NOAA",
    "SANTA ROSA CA WINDSPEED USAF-NOAA",
    #from Warm_Spring_Inflow.csv
    'Dry Creek 20 ET-POTENTIAL', 
    'Dry Creek 20 FLOW',
    'Dry Creek 20 FLOW-BASE', 
    'Dry Creek 20 INFILTRATION',
    'Dry Creek 20 PERC-SOIL',
    'Dry Creek 20 SATURATION FRACTION',
    'Dry Creek 30 ET-POTENTIAL', 
    'Dry Creek 30 FLOW',
    'Dry Creek 30 FLOW-BASE', 
    'Dry Creek 30 INFILTRATION',
    'Dry Creek 30 PERC-SOIL',
    'Dry Creek 30 SATURATION FRACTION',
    'Warm Springs Dam Inflow FLOW',
    ]
lstmPhysicsDaily = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data, hourly=False)

# %%
lstmPhysicsDaily.train()
# Out:
# 2025-01-16 13:33:49,304: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349\output.log initialized.
# 2025-01-16 13:33:49,306: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349
# 2025-01-16 13:33:49,307: ### Run configurations for testing_run
# 2025-01-16 13:33:49,309: experiment_name: testing_run
# 2025-01-16 13:33:49,310: train_basin_file: warm springs
# 2025-01-16 13:33:49,312: validation_basin_file: warm springs
# 2025-01-16 13:33:49,314: test_basin_file: warm springs
# 2025-01-16 13:33:49,317: train_start_date: 1994-10-01 00:00:00
# 2025-01-16 13:33:49,318: train_end_date: 2002-09-30 00:00:00
# 2025-01-16 13:33:49,320: validation_start_date: 2002-10-01 00:00:00
# 2025-01-16 13:33:49,322: validation_end_date: 2005-09-30 00:00:00
# 2025-01-16 13:33:49,323: test_start_date: 2005-10-01 00:00:00
# 2025-01-16 13:33:49,325: test_end_date: 2009-09-30 00:00:00
# 2025-01-16 13:33:49,327: device: cpu
# 2025-01-16 13:33:49,328: physics_informed: True
# 2025-01-16 13:33:49,330: physics_data_file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv
# 2025-01-16 13:33:49,332: validate_every: 5
# 2025-01-16 13:33:49,334: validate_n_random_basins: 1
# 2025-01-16 13:33:49,335: metrics: ['NSE', 'MSE']
# 2025-01-16 13:33:49,337: model: cudalstm
# 2025-01-16 13:33:49,338: head: regression
# 2025-01-16 13:33:49,340: output_activation: linear
# 2025-01-16 13:33:49,342: hidden_size: 128
# 2025-01-16 13:33:49,343: initial_forget_bias: 3
# 2025-01-16 13:33:49,344: output_dropout: 0.4
# 2025-01-16 13:33:49,345: optimizer: Adam
# 2025-01-16 13:33:49,347: loss: NSE
# 2025-01-16 13:33:49,348: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-16 13:33:49,350: batch_size: 256
# 2025-01-16 13:33:49,352: epochs: 5
# 2025-01-16 13:33:49,353: clip_gradient_norm: 1
# 2025-01-16 13:33:49,354: predict_last_n: 1
# 2025-01-16 13:33:49,356: seq_length: 90
# 2025-01-16 13:33:49,357: log_interval: 16
# 2025-01-16 13:33:49,358: log_tensorboard: True
# 2025-01-16 13:33:49,359: log_n_figures: 1
# 2025-01-16 13:33:49,360: save_weights_every: 5
# 2025-01-16 13:33:49,361: dataset: russian_river
# 2025-01-16 13:33:49,362: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-16 13:33:49,363: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'Dry Creek 20 ET-POTENTIAL', 'Dry Creek 20 FLOW', 'Dry Creek 20 FLOW-BASE', 'Dry Creek 20 INFILTRATION', 'Dry Creek 20 PERC-SOIL', 'Dry Creek 20 SATURATION FRACTION', 'Dry Creek 30 ET-POTENTIAL', 'Dry Creek 30 FLOW', 'Dry Creek 30 FLOW-BASE', 'Dry Creek 30 INFILTRATION', 'Dry Creek 30 PERC-SOIL', 'Dry Creek 30 SATURATION FRACTION', 'Warm Springs Dam Inflow FLOW']
# 2025-01-16 13:33:49,365: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-16 13:33:49,366: hourly: False
# 2025-01-16 13:33:49,366: number_of_basins: 1
# 2025-01-16 13:33:49,367: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349
# 2025-01-16 13:33:49,367: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349\train_data
# 2025-01-16 13:33:49,368: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349\img_log
# 2025-01-16 13:33:49,381: ### Device cpu will be used for training
# 2025-01-16 13:33:49,383: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-16 13:33:49,518: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv, hourly: False
# 100%|██████████| 1/1 [00:00<00:00,  3.84it/s]
# 2025-01-16 13:33:49,661: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 251.35it/s]
# 2025-01-16 13:33:49,686: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  6.65it/s]
# # Epoch 1: 100%|██████████| 12/12 [00:01<00:00,  6.60it/s, Loss: 0.0000]
# 2025-01-16 13:33:51,910: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 12/12 [00:01<00:00,  9.54it/s, Loss: 0.0000]
# 2025-01-16 13:33:53,176: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 12/12 [00:01<00:00,  9.84it/s, Loss: 0.0000]
# 2025-01-16 13:33:54,403: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 12/12 [00:01<00:00,  9.74it/s, Loss: 0.0000]
# 2025-01-16 13:33:55,643: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 12/12 [00:01<00:00,  9.86it/s, Loss: 0.0000]
# 2025-01-16 13:33:56,866: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-16 13:33:57,057: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# 2025-01-16 13:33:57,803: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.81471, MSE: 90846.44531
# 2025-01-16 13:33:57,926: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349\model_epoch005.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-16 13:33:58,171: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]
# 2025-01-16 13:33:58,477: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349\validation\model_epoch005\validation_metrics.csv
# 2025-01-16 13:33:58,480: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349\validation\model_epoch005\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_1601_133349')

# %%
lstmPhysicsDaily.results()
# Out:
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133349\results_output_validation.csv
# ({'NSE': 0.8147101104259491,
#   'MSE': 90846.4453125,
#   'RMSE': 301.4074407052686,
#   'KGE': 0.7751620214518395,
#   'Alpha-NSE': 1.0486318489814757,
#   'Beta-KGE': 0.7967660427093506,
#   'Beta-NSE': -0.0944852506943939,
#   'Pearson-r': 0.9170360411609444,
#   'FHV': 4.39116545021534,
#   'FMS': 107.00956583112446,
#   'FLV': -370.04166035854564,
#   'Peak-Timing': 0.0,
#   'Peak-MAPE': 18.594191074371338},
#  WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_1601_133349/results_output_validation.csv'))

# %% [markdown]
# ## Retrain LSTM on entire test period using best hyperparameters, evaluate on test period

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("warm_springs_dam.yaml")
params = {
    "epochs":16,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
#defaults to daily so no need to specify hourly
lstmNoPhysicsDailyExtended = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, hourly=False, extend_train_period=True)

# %%
lstmNoPhysicsDailyExtended.train()
# Out:
# 2025-01-16 13:33:59,344: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\output.log initialized.
# 2025-01-16 13:33:59,347: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359
# 2025-01-16 13:33:59,349: ### Run configurations for testing_run
# 2025-01-16 13:33:59,352: experiment_name: testing_run
# 2025-01-16 13:33:59,353: train_basin_file: warm springs
# 2025-01-16 13:33:59,355: validation_basin_file: warm springs
# 2025-01-16 13:33:59,356: test_basin_file: warm springs
# 2025-01-16 13:33:59,358: train_start_date: 1994-10-01 00:00:00
# 2025-01-16 13:33:59,359: train_end_date: 2005-09-30 00:00:00
# 2025-01-16 13:33:59,361: validation_start_date: 2002-10-01 00:00:00
# 2025-01-16 13:33:59,362: validation_end_date: 2005-09-30 00:00:00
# 2025-01-16 13:33:59,363: test_start_date: 2005-10-01 00:00:00
# 2025-01-16 13:33:59,364: test_end_date: 2009-09-30 00:00:00
# 2025-01-16 13:33:59,365: device: cpu
# 2025-01-16 13:33:59,366: physics_informed: False
# 2025-01-16 13:33:59,367: physics_data_file: None
# 2025-01-16 13:33:59,368: validate_every: 5
# 2025-01-16 13:33:59,369: validate_n_random_basins: 1
# 2025-01-16 13:33:59,370: metrics: ['NSE', 'MSE']
# 2025-01-16 13:33:59,371: model: cudalstm
# 2025-01-16 13:33:59,373: head: regression
# 2025-01-16 13:33:59,374: output_activation: linear
# 2025-01-16 13:33:59,376: hidden_size: 128
# 2025-01-16 13:33:59,377: initial_forget_bias: 3
# 2025-01-16 13:33:59,379: output_dropout: 0.4
# 2025-01-16 13:33:59,382: optimizer: Adam
# 2025-01-16 13:33:59,384: loss: NSE
# 2025-01-16 13:33:59,385: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-16 13:33:59,387: batch_size: 256
# 2025-01-16 13:33:59,391: epochs: 16
# 2025-01-16 13:33:59,393: clip_gradient_norm: 1
# 2025-01-16 13:33:59,395: predict_last_n: 1
# 2025-01-16 13:33:59,398: seq_length: 90
# 2025-01-16 13:33:59,401: log_interval: 16
# 2025-01-16 13:33:59,403: log_tensorboard: True
# 2025-01-16 13:33:59,405: log_n_figures: 1
# 2025-01-16 13:33:59,406: save_weights_every: 16
# 2025-01-16 13:33:59,407: dataset: russian_river
# 2025-01-16 13:33:59,408: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-16 13:33:59,410: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA']
# 2025-01-16 13:33:59,410: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-16 13:33:59,412: hourly: False
# 2025-01-16 13:33:59,412: number_of_basins: 1
# 2025-01-16 13:33:59,413: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359
# 2025-01-16 13:33:59,414: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\train_data
# 2025-01-16 13:33:59,415: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\img_log
# 2025-01-16 13:33:59,421: ### Device cpu will be used for training
# 2025-01-16 13:33:59,423: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  5.74it/s]
# 2025-01-16 13:33:59,606: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 502.13it/s]
# 2025-01-16 13:33:59,622: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.62it/s]
# # Epoch 1: 100%|██████████| 16/16 [00:01<00:00,  9.17it/s, Loss: 0.0000]
# 2025-01-16 13:34:01,735: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 16/16 [00:01<00:00, 10.19it/s, Loss: 0.0000]
# 2025-01-16 13:34:03,316: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 16/16 [00:01<00:00, 10.11it/s, Loss: 0.0000]
# 2025-01-16 13:34:04,907: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 16/16 [00:01<00:00, 10.14it/s, Loss: 0.0000]
# 2025-01-16 13:34:06,492: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 16/16 [00:01<00:00, 10.07it/s, Loss: 0.0000]
# 2025-01-16 13:34:08,089: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.63it/s]
# 2025-01-16 13:34:08,904: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.82637, MSE: 85132.03906
# # Epoch 6: 100%|██████████| 16/16 [00:01<00:00,  9.42it/s, Loss: 0.0000]
# 2025-01-16 13:34:10,613: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 16/16 [00:01<00:00, 10.01it/s, Loss: 0.0000]
# 2025-01-16 13:34:12,219: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 16/16 [00:01<00:00, 10.07it/s, Loss: 0.0000]
# 2025-01-16 13:34:13,816: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 16/16 [00:01<00:00, 10.16it/s, Loss: 0.0000]
# 2025-01-16 13:34:15,399: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 16/16 [00:01<00:00, 10.24it/s, Loss: 0.0000]
# 2025-01-16 13:34:16,970: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  7.00it/s]
# 2025-01-16 13:34:17,587: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.87091, MSE: 63294.20312
# # Epoch 11: 100%|██████████| 16/16 [00:01<00:00,  9.88it/s, Loss: 0.0000]
# 2025-01-16 13:34:19,215: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 16/16 [00:01<00:00, 10.38it/s, Loss: 0.0000]
# 2025-01-16 13:34:20,763: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 16/16 [00:01<00:00, 10.42it/s, Loss: 0.0000]
# 2025-01-16 13:34:22,306: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 16/16 [00:01<00:00, 10.47it/s, Loss: 0.0000]
# 2025-01-16 13:34:23,842: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 16/16 [00:01<00:00, 10.46it/s, Loss: 0.0000]
# 2025-01-16 13:34:25,380: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  7.05it/s]
# 2025-01-16 13:34:25,982: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.87861, MSE: 59515.64844
# # Epoch 16: 100%|██████████| 16/16 [00:01<00:00, 10.04it/s, Loss: 0.0000]
# 2025-01-16 13:34:27,585: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-16 13:34:27,688: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\model_epoch016.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# 2025-01-16 13:34:28,226: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\validation\model_epoch016\validation_metrics.csv
# 2025-01-16 13:34:28,228: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\validation\model_epoch016\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_1601_133359')

# %%
lstm_result_metrics, lstm_result_path = lstmNoPhysicsDailyExtended.results('test')
# Out:
# 2025-01-16 13:34:28,305: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\model_epoch016.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# 2025-01-16 13:34:28,885: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\test\model_epoch016\test_metrics.csv
# 2025-01-16 13:34:28,888: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\test\model_epoch016\test_results.p
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133359\results_output_test.csv

# %%
lstm_result_metrics
# Out:
# {'NSE': 0.793963149189949,
#  'MSE': 110261.5546875,
#  'RMSE': 332.05655344760174,
#  'KGE': 0.8536346883134671,
#  'Alpha-NSE': 1.0847134965886978,
#  'Beta-KGE': 1.0769846439361572,
#  'Beta-NSE': 0.031308614613253787,
#  'Pearson-r': 0.9087871031112611,
#  'FHV': 14.756712317466736,
#  'FMS': 31.370194550051583,
#  'FLV': -2214.5474566442927,
#  'Peak-Timing': 0.5,
#  'Peak-MAPE': 54.15686766306559}

# %% [markdown]
# ## Retrain PI-LSTM on entire train period using best hyperparameters, evaluate on test period

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("warm_springs_dam.yaml")
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv")
params = {
    "epochs":16,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
features_with_physics = [
    #from daily.csv
    "DRY CREEK 20 PRECIP-INC SCREENED",
    "DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "DRY CREEK 30 PRECIP-INC SCREENED",
    "DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    "SANTA ROSA CA HUMIDITY USAF-NOAA",
    "SANTA ROSA CA SOLAR RADIATION USAF-NOAA",
    "SANTA ROSA CA TEMPERATURE USAF-NOAA",
    "SANTA ROSA CA WINDSPEED USAF-NOAA",
    #from Warm_Spring_Inflow.csv
    'Dry Creek 20 ET-POTENTIAL', 
    'Dry Creek 20 FLOW',
    'Dry Creek 20 FLOW-BASE', 
    'Dry Creek 20 INFILTRATION',
    'Dry Creek 20 PERC-SOIL',
    'Dry Creek 20 SATURATION FRACTION',
    'Dry Creek 30 ET-POTENTIAL', 
    'Dry Creek 30 FLOW',
    'Dry Creek 30 FLOW-BASE', 
    'Dry Creek 30 INFILTRATION',
    'Dry Creek 30 PERC-SOIL',
    'Dry Creek 30 SATURATION FRACTION',
    'Warm Springs Dam Inflow FLOW',
    ]
#extend train period set to true
lstmPhysicsDailyExtended = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data, hourly=False, extend_train_period=True)

# %%
lstmPhysicsDailyExtended.train()
# Out:
# 2025-01-16 13:34:29,755: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\output.log initialized.
# 2025-01-16 13:34:29,757: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429
# 2025-01-16 13:34:29,760: ### Run configurations for testing_run
# 2025-01-16 13:34:29,762: experiment_name: testing_run
# 2025-01-16 13:34:29,763: train_basin_file: warm springs
# 2025-01-16 13:34:29,765: validation_basin_file: warm springs
# 2025-01-16 13:34:29,766: test_basin_file: warm springs
# 2025-01-16 13:34:29,768: train_start_date: 1994-10-01 00:00:00
# 2025-01-16 13:34:29,770: train_end_date: 2005-09-30 00:00:00
# 2025-01-16 13:34:29,770: validation_start_date: 2002-10-01 00:00:00
# 2025-01-16 13:34:29,771: validation_end_date: 2005-09-30 00:00:00
# 2025-01-16 13:34:29,772: test_start_date: 2005-10-01 00:00:00
# 2025-01-16 13:34:29,772: test_end_date: 2009-09-30 00:00:00
# 2025-01-16 13:34:29,774: device: cpu
# 2025-01-16 13:34:29,774: physics_informed: True
# 2025-01-16 13:34:29,775: physics_data_file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv
# 2025-01-16 13:34:29,776: validate_every: 5
# 2025-01-16 13:34:29,777: validate_n_random_basins: 1
# 2025-01-16 13:34:29,778: metrics: ['NSE', 'MSE']
# 2025-01-16 13:34:29,779: model: cudalstm
# 2025-01-16 13:34:29,781: head: regression
# 2025-01-16 13:34:29,783: output_activation: linear
# 2025-01-16 13:34:29,785: hidden_size: 128
# 2025-01-16 13:34:29,786: initial_forget_bias: 3
# 2025-01-16 13:34:29,789: output_dropout: 0.4
# 2025-01-16 13:34:29,791: optimizer: Adam
# 2025-01-16 13:34:29,794: loss: NSE
# 2025-01-16 13:34:29,796: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-16 13:34:29,798: batch_size: 256
# 2025-01-16 13:34:29,799: epochs: 16
# 2025-01-16 13:34:29,800: clip_gradient_norm: 1
# 2025-01-16 13:34:29,803: predict_last_n: 1
# 2025-01-16 13:34:29,805: seq_length: 90
# 2025-01-16 13:34:29,808: log_interval: 16
# 2025-01-16 13:34:29,810: log_tensorboard: True
# 2025-01-16 13:34:29,812: log_n_figures: 1
# 2025-01-16 13:34:29,813: save_weights_every: 16
# 2025-01-16 13:34:29,815: dataset: russian_river
# 2025-01-16 13:34:29,817: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-16 13:34:29,819: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'Dry Creek 20 ET-POTENTIAL', 'Dry Creek 20 FLOW', 'Dry Creek 20 FLOW-BASE', 'Dry Creek 20 INFILTRATION', 'Dry Creek 20 PERC-SOIL', 'Dry Creek 20 SATURATION FRACTION', 'Dry Creek 30 ET-POTENTIAL', 'Dry Creek 30 FLOW', 'Dry Creek 30 FLOW-BASE', 'Dry Creek 30 INFILTRATION', 'Dry Creek 30 PERC-SOIL', 'Dry Creek 30 SATURATION FRACTION', 'Warm Springs Dam Inflow FLOW']
# 2025-01-16 13:34:29,820: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-16 13:34:29,822: hourly: False
# 2025-01-16 13:34:29,824: number_of_basins: 1
# 2025-01-16 13:34:29,826: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429
# 2025-01-16 13:34:29,827: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\train_data
# 2025-01-16 13:34:29,830: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\img_log
# 2025-01-16 13:34:29,838: ### Device cpu will be used for training
# 2025-01-16 13:34:29,840: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-16 13:34:30,019: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv, hourly: False
# 100%|██████████| 1/1 [00:00<00:00,  2.82it/s]
# 2025-01-16 13:34:30,223: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 125.56it/s]
# 2025-01-16 13:34:30,255: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  9.61it/s]
# # Epoch 1: 100%|██████████| 16/16 [00:01<00:00,  9.43it/s, Loss: 0.0000]
# 2025-01-16 13:34:32,322: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 16/16 [00:01<00:00, 10.10it/s, Loss: 0.0000]
# 2025-01-16 13:34:33,914: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 16/16 [00:01<00:00, 10.10it/s, Loss: 0.0000]
# 2025-01-16 13:34:35,505: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 16/16 [00:01<00:00, 10.19it/s, Loss: 0.0000]
# 2025-01-16 13:34:37,085: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 16/16 [00:01<00:00, 10.00it/s, Loss: 0.0000]
# 2025-01-16 13:34:38,692: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-16 13:34:38,879: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.00it/s]
# 2025-01-16 13:34:39,662: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.89995, MSE: 49052.27734
# # Epoch 6: 100%|██████████| 16/16 [00:01<00:00,  9.98it/s, Loss: 0.0000]
# 2025-01-16 13:34:41,277: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 16/16 [00:01<00:00,  9.98it/s, Loss: 0.0000]
# 2025-01-16 13:34:42,890: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 16/16 [00:01<00:00, 10.09it/s, Loss: 0.0000]
# 2025-01-16 13:34:44,483: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 16/16 [00:01<00:00, 10.30it/s, Loss: 0.0000]
# 2025-01-16 13:34:46,046: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 16/16 [00:01<00:00, 10.24it/s, Loss: 0.0000]
# 2025-01-16 13:34:47,616: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.46it/s]
# 2025-01-16 13:34:48,186: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.92022, MSE: 39114.08984
# # Epoch 11: 100%|██████████| 16/16 [00:01<00:00,  9.39it/s, Loss: 0.0000]
# 2025-01-16 13:34:49,902: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 16/16 [00:01<00:00, 10.14it/s, Loss: 0.0000]
# 2025-01-16 13:34:51,489: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 16/16 [00:01<00:00, 10.08it/s, Loss: 0.0000]
# 2025-01-16 13:34:53,083: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 16/16 [00:01<00:00, 10.16it/s, Loss: 0.0000]
# 2025-01-16 13:34:54,665: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 16/16 [00:01<00:00, 10.17it/s, Loss: 0.0000]
# 2025-01-16 13:34:56,247: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.79it/s]
# 2025-01-16 13:34:56,810: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.94793, MSE: 25529.45898
# # Epoch 16: 100%|██████████| 16/16 [00:01<00:00,  9.95it/s, Loss: 0.0000]
# 2025-01-16 13:34:58,432: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-16 13:34:58,583: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\model_epoch016.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-16 13:34:58,792: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]
# 2025-01-16 13:34:59,259: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\validation\model_epoch016\validation_metrics.csv
# 2025-01-16 13:34:59,261: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\validation\model_epoch016\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_1601_133429')

# %%
physics_informed_result_metrics, physics_informed_result_path = lstmPhysicsDailyExtended.results('test')
# Out:
# 2025-01-16 13:34:59,373: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\model_epoch016.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-16 13:34:59,573: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\WarmSprings_Inflow_daily.csv, hourly: False
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.78it/s]
# 2025-01-16 13:34:59,948: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\test\model_epoch016\test_metrics.csv
# 2025-01-16 13:34:59,950: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\test\model_epoch016\test_results.p
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\runs\testing_run_1601_133429\results_output_test.csv

# %%
physics_informed_result_metrics
# Out:
# {'NSE': 0.8450540006160736,
#  'MSE': 82920.046875,
#  'RMSE': 287.95841171078854,
#  'KGE': 0.8079353891360195,
#  'Alpha-NSE': 0.9140463484553422,
#  'Beta-KGE': 1.1527146100997925,
#  'Beta-NSE': 0.06210695018246481,
#  'Pearson-r': 0.9213931784477953,
#  'FHV': -1.5119624324142933,
#  'FMS': -49.8556390050543,
#  'FLV': -127.3214330315092,
#  'Peak-Timing': 0.5,
#  'Peak-MAPE': 45.81507047017415}

# %% [markdown]
# ## Inspect results

# %%
    model1_df = pd.read_csv(lstm_result_path) #colums: Date, Observed, Predicted
    model1_df.head()
# Out:
#          Date  Observed  Predicted
# 0  2005-10-01      82.0   87.00110
# 1  2005-10-02      69.0   97.47638
# 2  2005-10-03      86.0   95.07382
# 3  2005-10-04      73.0   90.75018
# 4  2005-10-05      65.0   89.54361

# %%
    model2_df = pd.read_csv(physics_informed_result_path) #colums: Date, Observed, Predicted
    model1_df.head()
# Out:
#          Date  Observed  Predicted
# 0  2005-10-01      82.0   87.00110
# 1  2005-10-02      69.0   97.47638
# 2  2005-10-03      86.0   95.07382
# 3  2005-10-04      73.0   90.75018
# 4  2005-10-05      65.0   89.54361

# %%
    hms_df = clean_daily(pd.read_csv(path_to_physics_data))
    hms_df.head()
# Out:
# 0                Day      Time Warm Springs Dam Inflow FLOW  \
# date
# 1994-10-01  1-Oct-94  00:00:00                    64.825996
# 1994-10-02  2-Oct-94  00:00:00                    64.825996
# 1994-10-03  3-Oct-94  00:00:00                    64.825981
# 1994-10-04  4-Oct-94  00:00:00                    88.568268
# 1994-10-05  5-Oct-94  00:00:00                    70.077744
#
# 0          Dry Creek 20 ET-POTENTIAL Dry Creek 20 FLOW Dry Creek 20 FLOW-BASE  \
# date
# 1994-10-01                  0.033286            21.107                 21.107
# 1994-10-02                  0.047009         21.106998              21.106998
# 1994-10-03                  0.040214         21.106993              21.106993
# 1994-10-04                  0.011207         31.838606              21.106983
# 1994-10-05                  0.033213          21.41761              21.106964
#
# 0          Dry Creek 20 INFILTRATION Dry Creek 20 PERC-SOIL  \
# date
# 1994-10-01                         0                      0
# 1994-10-02                         0                      0
# 1994-10-03                         0                      0
# 1994-10-04                  0.324271                      0
# 1994-10-05                         0                      0
#
# 0          Dry Creek 20 SATURATION FRACTION Dry Creek 30 ET-POTENTIAL  \
# date
# 1994-10-01                                0                  0.028383
# 1994-10-02                                0                  0.047485
# 1994-10-03                                0                  0.041777
# 1994-10-04                         0.021365                  0.011193
# 1994-10-05                         0.046324                  0.022912
#
# 0          Dry Creek 30 FLOW Dry Creek 30 FLOW-BASE Dry Creek 30 INFILTRATION  \
# date
# 1994-10-01         43.718998              43.718998                         0
# 1994-10-02         43.718998              43.718998                         0
# 1994-10-03         43.718987              43.718987                         0
# 1994-10-04         56.884308              43.718964                   0.25479
# 1994-10-05         48.507267              43.718925                         0
#
# 0          Dry Creek 30 PERC-SOIL Dry Creek 30 SATURATION FRACTION
# date
# 1994-10-01                      0                                0
# 1994-10-02                      0                                0
# 1994-10-03                      0                                0
# 1994-10-04                      0                         0.017624
# 1994-10-05                      0                         0.036399

# %% [markdown]
#  ## Plot combined results

# %%
myplot, metrics_df = combinedPlot(lstm_results=lstm_result_path, lstmPhysics_results= physics_informed_result_path, HMS_results=path_to_physics_data, title='Warm Springs Basin Model Comparison', fName = "warm_springs_metrics.csv")
# Out:
#            date  Observed_Model1  Predicted_Model1  Observed_Model2  \
# 4018 2005-10-01             82.0          87.00110             82.0
# 4019 2005-10-02             69.0          97.47638             69.0
# 4020 2005-10-03             86.0          95.07382             86.0
# 4021 2005-10-04             73.0          90.75018             73.0
# 4022 2005-10-05             65.0          89.54361             65.0
#
#       Predicted_Model2  HMS_predicted
# 4018         134.32837      64.825996
# 4019         139.49931      64.825996
# 4020         146.74898      64.825981
# 4021         149.44254      64.825951
# 4022         157.56165      64.825890
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\warm_springs_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)

# %%
metrics_df
# Out:
#                        HMS           LSTM  Physics_Informed_LSTM
# NSE               0.732378       0.794029               0.845054
# MSE          143219.107939  110226.375487           82920.052417
# RMSE            378.443005     332.003578             287.958421
# KGE               0.791193       0.853475               0.807936
# Alpha-NSE         1.179502       1.084638               0.914047
# Beta-KGE          1.037973       1.077398               1.152715
# Beta-NSE          0.015443       0.031477               0.062107
# Pearson-r         0.900313       0.908810               0.921393
# FHV              24.454837      14.756710              -1.511963
# FMS              25.356069      31.370211             -49.855603
# FLV              79.444018   -2214.547105            -127.321425
# Peak-Timing       0.833333       0.500000               0.500000
# Peak-MAPE        44.995233      54.156867              45.815075
