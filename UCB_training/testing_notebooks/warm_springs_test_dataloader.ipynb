# %%
import sys
import os
import pickle

library_path = os.path.join('..', '..', '..','UCB-USACE-LSTMs')
sys.path.insert(0, library_path)

from pathlib import Path
import pandas as pd

import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation.metrics import *
from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble
from neuralhydrology.UCB_training.UCB_train import UCB_trainer
from neuralhydrology.evaluation.metrics import calculate_all_metrics

# %% [markdown]
# Quick check that working directory and train basin file exists:

# %%
os.chdir('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all')
print("Current Working Directory:", os.getcwd())
print("Train Basin File Exists:", os.path.exists("warm springs"))
# Out:
# Current Working Directory: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all
# Train Basin File Exists: True

# %% [markdown]
# check that daily no phyiscs still runs correctly:

# %%
path_to_csv = Path(library_path+"/data/updated_russian_river_folder")
path_to_yaml = Path("warm_springs_dam.yaml")
params = {
    "epochs":5,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
#defaults to daily so no need to specify hourly
lstmNoPhysicsDaily = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params)

# %%
lstmNoPhysicsDaily.train()
# Out:
# 2025-01-30 14:05:19,414: Logging to /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/output.log initialized.
# 2025-01-30 14:05:19,415: ### Folder structure created at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519
# 2025-01-30 14:05:19,415: ### Run configurations for testing_run
# 2025-01-30 14:05:19,415: experiment_name: testing_run
# 2025-01-30 14:05:19,416: train_basin_file: warm springs
# 2025-01-30 14:05:19,416: validation_basin_file: warm springs
# 2025-01-30 14:05:19,417: test_basin_file: warm springs
# 2025-01-30 14:05:19,417: train_start_date: 1994-10-01 00:00:00
# 2025-01-30 14:05:19,418: train_end_date: 2002-09-30 00:00:00
# 2025-01-30 14:05:19,418: validation_start_date: 2002-10-01 00:00:00
# 2025-01-30 14:05:19,419: validation_end_date: 2005-09-30 00:00:00
# 2025-01-30 14:05:19,419: test_start_date: 2005-10-01 00:00:00
# 2025-01-30 14:05:19,419: test_end_date: 2009-09-30 00:00:00
# 2025-01-30 14:05:19,420: device: cpu
# 2025-01-30 14:05:19,420: physics_informed: False
# 2025-01-30 14:05:19,420: physics_data_file: None
# 2025-01-30 14:05:19,421: validate_every: 5
# 2025-01-30 14:05:19,421: validate_n_random_basins: 1
# 2025-01-30 14:05:19,422: metrics: ['NSE', 'MSE']
# 2025-01-30 14:05:19,422: model: cudalstm
# 2025-01-30 14:05:19,423: head: regression
# 2025-01-30 14:05:19,423: output_activation: linear
# 2025-01-30 14:05:19,424: hidden_size: 128
# 2025-01-30 14:05:19,424: initial_forget_bias: 3
# 2025-01-30 14:05:19,425: output_dropout: 0.4
# 2025-01-30 14:05:19,425: optimizer: Adam
# 2025-01-30 14:05:19,426: loss: NSE
# 2025-01-30 14:05:19,426: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-30 14:05:19,426: batch_size: 256
# 2025-01-30 14:05:19,427: epochs: 5
# 2025-01-30 14:05:19,427: clip_gradient_norm: 1
# 2025-01-30 14:05:19,427: predict_last_n: 1
# 2025-01-30 14:05:19,428: seq_length: 90
# 2025-01-30 14:05:19,428: log_interval: 16
# 2025-01-30 14:05:19,428: log_tensorboard: True
# 2025-01-30 14:05:19,429: log_n_figures: 1
# 2025-01-30 14:05:19,429: save_weights_every: 5
# 2025-01-30 14:05:19,430: dataset: russian_river
# 2025-01-30 14:05:19,430: data_dir: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder
# 2025-01-30 14:05:19,431: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA']
# 2025-01-30 14:05:19,431: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-30 14:05:19,431: hourly: False
# 2025-01-30 14:05:19,432: number_of_basins: 1
# 2025-01-30 14:05:19,432: run_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519
# 2025-01-30 14:05:19,432: train_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/train_data
# 2025-01-30 14:05:19,433: img_log_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/img_log
# 2025-01-30 14:05:19,443: ### Device cpu will be used for training
# 2025-01-30 14:05:19,447: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 13.84it/s]
# 2025-01-30 14:05:19,552: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 791.08it/s]
# 2025-01-30 14:05:19,559: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
# # Epoch 1: 100%|██████████| 12/12 [00:06<00:00,  1.89it/s, Loss: 0.0000]
# 2025-01-30 14:05:26,997: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 12/12 [00:07<00:00,  1.53it/s, Loss: 0.0000]
# 2025-01-30 14:05:34,853: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 12/12 [00:07<00:00,  1.71it/s, Loss: 0.0000]
# 2025-01-30 14:05:41,880: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 12/12 [00:07<00:00,  1.70it/s, Loss: 0.0000]
# 2025-01-30 14:05:48,959: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 12/12 [00:07<00:00,  1.69it/s, Loss: 0.0000]
# 2025-01-30 14:05:56,055: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]
# 2025-01-30 14:05:57,839: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.76887, MSE: 113325.14062
# 2025-01-30 14:05:57,845: Using the model weights from /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/model_epoch005.pt
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# 2025-01-30 14:05:59,192: Stored metrics at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/validation/model_epoch005/validation_metrics.csv
# 2025-01-30 14:05:59,193: Stored results at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/validation/model_epoch005/validation_results.p
# PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519')

# %%
lstmNoPhysicsDaily.results()
# Out:
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/results_output_validation.csv
# ({'NSE': 0.7688744813203812,
#   'MSE': 113325.140625,
#   'RMSE': 336.6379964071198,
#   'KGE': 0.8332948818757512,
#   'Alpha-NSE': 1.075323060852581,
#   'Beta-KGE': 1.1066105365753174,
#   'Beta-NSE': 0.04955454895777557,
#   'Pearson-r': 0.89631187915802,
#   'FHV': 1.8459498882293701,
#   'FMS': 86.69350935686964,
#   'FLV': -471.65251569407405,
#   'Peak-Timing': 0.4,
#   'Peak-MAPE': 21.64339780807495},
#  PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_140519/results_output_validation.csv'))

# %% [markdown]
# check if no physics hourly works:

# %%
# set path to folder, ensure that daily.csv and hourly.csv are present
# path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
#path_to_yaml = Path("warm_springs_dam.yaml")
params = {
    "epochs":2,
    "hidden_size": 8,
    "output_dropout": 0.4,
    "seq_length": 90,
}
#if using hourly data , set hourly = True
lstmNoPhysicsHourly = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, hourly=True)

# %%
lstmNoPhysicsHourly.train()
# Out:
# 2025-01-30 11:29:58,405: Logging to /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/output.log initialized.
# 2025-01-30 11:29:58,405: ### Folder structure created at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958
# 2025-01-30 11:29:58,406: ### Run configurations for testing_run
# 2025-01-30 11:29:58,406: experiment_name: testing_run
# 2025-01-30 11:29:58,407: train_basin_file: warm springs
# 2025-01-30 11:29:58,407: validation_basin_file: warm springs
# 2025-01-30 11:29:58,407: test_basin_file: warm springs
# 2025-01-30 11:29:58,408: train_start_date: 1994-10-01 00:00:00
# 2025-01-30 11:29:58,408: train_end_date: 2002-09-30 00:00:00
# 2025-01-30 11:29:58,408: validation_start_date: 2002-10-01 00:00:00
# 2025-01-30 11:29:58,409: validation_end_date: 2005-09-30 00:00:00
# 2025-01-30 11:29:58,409: test_start_date: 2005-10-01 00:00:00
# 2025-01-30 11:29:58,410: test_end_date: 2009-09-30 00:00:00
# 2025-01-30 11:29:58,411: device: cpu
# 2025-01-30 11:29:58,411: physics_informed: False
# 2025-01-30 11:29:58,412: physics_data_file: None
# 2025-01-30 11:29:58,412: validate_every: 5
# 2025-01-30 11:29:58,413: validate_n_random_basins: 1
# 2025-01-30 11:29:58,414: metrics: ['NSE', 'MSE']
# 2025-01-30 11:29:58,415: model: cudalstm
# 2025-01-30 11:29:58,415: head: regression
# 2025-01-30 11:29:58,416: output_activation: linear
# 2025-01-30 11:29:58,417: hidden_size: 8
# 2025-01-30 11:29:58,417: initial_forget_bias: 3
# 2025-01-30 11:29:58,418: output_dropout: 0.4
# 2025-01-30 11:29:58,418: optimizer: Adam
# 2025-01-30 11:29:58,419: loss: NSE
# 2025-01-30 11:29:58,420: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-30 11:29:58,421: batch_size: 256
# 2025-01-30 11:29:58,421: epochs: 2
# 2025-01-30 11:29:58,422: clip_gradient_norm: 1
# 2025-01-30 11:29:58,422: predict_last_n: 1
# 2025-01-30 11:29:58,423: seq_length: 90
# 2025-01-30 11:29:58,424: log_interval: 16
# 2025-01-30 11:29:58,424: log_tensorboard: True
# 2025-01-30 11:29:58,425: log_n_figures: 1
# 2025-01-30 11:29:58,426: save_weights_every: 2
# 2025-01-30 11:29:58,427: dataset: russian_river
# 2025-01-30 11:29:58,427: data_dir: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder
# 2025-01-30 11:29:58,428: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA']
# 2025-01-30 11:29:58,428: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-30 11:29:58,429: hourly: True
# 2025-01-30 11:29:58,430: number_of_basins: 1
# 2025-01-30 11:29:58,430: run_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958
# 2025-01-30 11:29:58,430: train_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/train_data
# 2025-01-30 11:29:58,431: img_log_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/img_log
# 2025-01-30 11:29:58,437: ### Device cpu will be used for training
# 2025-01-30 11:29:58,438: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]
# 2025-01-30 11:29:59,102: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 825.81it/s]
# 2025-01-30 11:29:59,110: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  4.50it/s]
# # Epoch 1: 100%|██████████| 266/266 [00:11<00:00, 22.89it/s, Loss: 0.0000]
# 2025-01-30 11:30:11,124: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 266/266 [00:12<00:00, 21.67it/s, Loss: 0.0000]
# 2025-01-30 11:30:23,404: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-30 11:30:23,413: Using the model weights from /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/model_epoch002.pt
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
# 2025-01-30 11:30:26,515: Stored metrics at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/validation/model_epoch002/validation_metrics.csv
# 2025-01-30 11:30:26,517: Stored results at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/validation/model_epoch002/validation_results.p
# PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958')

# %%
lstmNoPhysicsHourly.results()
# Out:
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# [INFO] CSV output saved at: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/results_output_validation.csv
# ({'NSE': 0.5858323574066162,
#   'MSE': 262825.40625,
#   'RMSE': 512.6650039255654,
#   'KGE': 0.6778061913192011,
#   'Alpha-NSE': 0.8029169553585049,
#   'Beta-KGE': 1.1042402982711792,
#   'Beta-NSE': 0.04259819666279258,
#   'Pearson-r': 0.7674036026000977,
#   'FHV': -11.586233973503113,
#   'FMS': -45.950269900459105,
#   'FLV': -2756.561239194956,
#   'Peak-Timing': nan,
#   'Peak-MAPE': 64.8157420911287},
#  PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_112958/results_output_validation.csv'))

# %% [markdown]
# check if physics daily still works:

# %%
# path_to_csv = Path("/Users/mia/research/UCB-USACE-LSTMs/data/updated_russian_river_folder")
# path_to_yaml = Path("warm_springs_dam.yaml")
path_to_physics_data = Path(library_path+"/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv")
params = {
    "epochs":5,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
features_with_physics = [
    #from daily.csv
    "DRY CREEK 20 PRECIP-INC SCREENED",
    "DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "DRY CREEK 30 PRECIP-INC SCREENED",
    "DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    "SANTA ROSA CA HUMIDITY USAF-NOAA",
    "SANTA ROSA CA SOLAR RADIATION USAF-NOAA",
    "SANTA ROSA CA TEMPERATURE USAF-NOAA",
    "SANTA ROSA CA WINDSPEED USAF-NOAA",
    #from Warm_Spring_Inflow.csv
    'Dry Creek 20 ET-POTENTIAL', 
    'Dry Creek 20 FLOW',
    'Dry Creek 20 FLOW-BASE', 
    'Dry Creek 20 INFILTRATION',
    'Dry Creek 20 PERC-SOIL',
    'Dry Creek 20 SATURATION FRACTION',
    'Dry Creek 30 ET-POTENTIAL', 
    'Dry Creek 30 FLOW',
    'Dry Creek 30 FLOW-BASE', 
    'Dry Creek 30 INFILTRATION',
    'Dry Creek 30 PERC-SOIL',
    'Dry Creek 30 SATURATION FRACTION',
    'Warm Springs Dam Inflow FLOW',
    ]
lstmPhysicsDaily = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data, hourly=False)

# %%
lstmPhysicsDaily.train()
# Out:
# 2025-01-30 11:30:26,880: Logging to /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/output.log initialized.
# 2025-01-30 11:30:26,880: ### Folder structure created at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026
# 2025-01-30 11:30:26,881: ### Run configurations for testing_run
# 2025-01-30 11:30:26,881: experiment_name: testing_run
# 2025-01-30 11:30:26,882: train_basin_file: warm springs
# 2025-01-30 11:30:26,882: validation_basin_file: warm springs
# 2025-01-30 11:30:26,882: test_basin_file: warm springs
# 2025-01-30 11:30:26,883: train_start_date: 1994-10-01 00:00:00
# 2025-01-30 11:30:26,883: train_end_date: 2002-09-30 00:00:00
# 2025-01-30 11:30:26,883: validation_start_date: 2002-10-01 00:00:00
# 2025-01-30 11:30:26,884: validation_end_date: 2005-09-30 00:00:00
# 2025-01-30 11:30:26,884: test_start_date: 2005-10-01 00:00:00
# 2025-01-30 11:30:26,885: test_end_date: 2009-09-30 00:00:00
# 2025-01-30 11:30:26,885: device: cpu
# 2025-01-30 11:30:26,889: physics_informed: True
# 2025-01-30 11:30:26,889: physics_data_file: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv
# 2025-01-30 11:30:26,890: validate_every: 5
# 2025-01-30 11:30:26,890: validate_n_random_basins: 1
# 2025-01-30 11:30:26,896: metrics: ['NSE', 'MSE']
# 2025-01-30 11:30:26,903: model: cudalstm
# 2025-01-30 11:30:26,908: head: regression
# 2025-01-30 11:30:26,908: output_activation: linear
# 2025-01-30 11:30:26,909: hidden_size: 128
# 2025-01-30 11:30:26,909: initial_forget_bias: 3
# 2025-01-30 11:30:26,910: output_dropout: 0.4
# 2025-01-30 11:30:26,910: optimizer: Adam
# 2025-01-30 11:30:26,912: loss: NSE
# 2025-01-30 11:30:26,915: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-30 11:30:26,915: batch_size: 256
# 2025-01-30 11:30:26,915: epochs: 5
# 2025-01-30 11:30:26,916: clip_gradient_norm: 1
# 2025-01-30 11:30:26,916: predict_last_n: 1
# 2025-01-30 11:30:26,917: seq_length: 90
# 2025-01-30 11:30:26,917: log_interval: 16
# 2025-01-30 11:30:26,917: log_tensorboard: True
# 2025-01-30 11:30:26,917: log_n_figures: 1
# 2025-01-30 11:30:26,918: save_weights_every: 5
# 2025-01-30 11:30:26,918: dataset: russian_river
# 2025-01-30 11:30:26,918: data_dir: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder
# 2025-01-30 11:30:26,919: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'Dry Creek 20 ET-POTENTIAL', 'Dry Creek 20 FLOW', 'Dry Creek 20 FLOW-BASE', 'Dry Creek 20 INFILTRATION', 'Dry Creek 20 PERC-SOIL', 'Dry Creek 20 SATURATION FRACTION', 'Dry Creek 30 ET-POTENTIAL', 'Dry Creek 30 FLOW', 'Dry Creek 30 FLOW-BASE', 'Dry Creek 30 INFILTRATION', 'Dry Creek 30 PERC-SOIL', 'Dry Creek 30 SATURATION FRACTION', 'Warm Springs Dam Inflow FLOW']
# 2025-01-30 11:30:26,919: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-30 11:30:26,920: hourly: False
# 2025-01-30 11:30:26,920: number_of_basins: 1
# 2025-01-30 11:30:26,920: run_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026
# 2025-01-30 11:30:26,921: train_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/train_data
# 2025-01-30 11:30:26,921: img_log_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/img_log
# 2025-01-30 11:30:26,924: ### Device cpu will be used for training
# 2025-01-30 11:30:26,925: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-30 11:30:26,985: Loading data from file: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv, hourly: False
# 100%|██████████| 1/1 [00:00<00:00,  9.07it/s]
# 2025-01-30 11:30:27,039: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 1346.05it/s]
# 2025-01-30 11:30:27,044: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 62.70it/s]
# # Epoch 1: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it, Loss: 0.0000]
# 2025-01-30 11:30:40,447: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 12/12 [00:14<00:00,  1.22s/it, Loss: 0.0000]
# 2025-01-30 11:30:55,081: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 12/12 [00:13<00:00,  1.16s/it, Loss: 0.0000]
# 2025-01-30 11:31:09,055: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 12/12 [00:15<00:00,  1.29s/it, Loss: 0.0000]
# 2025-01-30 11:31:24,570: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 12/12 [00:14<00:00,  1.21s/it, Loss: 0.0000]
# 2025-01-30 11:31:39,122: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-30 11:31:39,256: Loading data from file: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:02<00:00,  2.32s/it]
# 2025-01-30 11:31:41,685: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.76630, MSE: 114585.05469
# 2025-01-30 11:31:41,700: Using the model weights from /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/model_epoch005.pt
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-30 11:31:41,789: Loading data from file: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# 2025-01-30 11:31:43,931: Stored metrics at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/validation/model_epoch005/validation_metrics.csv
# 2025-01-30 11:31:43,932: Stored results at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/validation/model_epoch005/validation_results.p
# PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026')

# %%
lstmPhysicsDaily.results()
# Out:
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# [INFO] CSV output saved at: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/results_output_validation.csv
# ({'NSE': 0.7663049101829529,
#   'MSE': 114585.0546875,
#   'RMSE': 338.5041427922264,
#   'KGE': 0.7089565273665439,
#   'Alpha-NSE': 1.186707046022721,
#   'Beta-KGE': 1.2085084915161133,
#   'Beta-NSE': 0.09691864801562061,
#   'Pearson-r': 0.9201815128326416,
#   'FHV': 15.781553089618683,
#   'FMS': 115.6850967120117,
#   'FLV': -946.8897879635717,
#   'Peak-Timing': 0.0,
#   'Peak-MAPE': 22.387545108795166},
#  PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113026/results_output_validation.csv'))

# %% [markdown]
# test if hourly physics informed works:

# %%
# path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("warm_springs_dam.yaml")
path_to_physics_data = Path("/Users/mia/research/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_hourly.csv")
params = {
    "epochs":1,
    "hidden_size": 8,
    "output_dropout": 0.4,
    "seq_length": 90,
}
features_with_physics = [
    #from daily.csv
    "DRY CREEK 20 PRECIP-INC SCREENED",
    "DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "DRY CREEK 30 PRECIP-INC SCREENED",
    "DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    "SANTA ROSA CA HUMIDITY USAF-NOAA",
    "SANTA ROSA CA SOLAR RADIATION USAF-NOAA",
    "SANTA ROSA CA TEMPERATURE USAF-NOAA",
    "SANTA ROSA CA WINDSPEED USAF-NOAA",
    #from Warm_Spring_Inflow.csv
    'Dry Creek 20 ET-POTENTIAL', 
    'Dry Creek 20 FLOW',
    'Dry Creek 20 FLOW-BASE', 
    'Dry Creek 20 INFILTRATION',
    'Dry Creek 20 PERC-SOIL',
    'Dry Creek 20 SATURATION FRACTION',
    'Dry Creek 30 ET-POTENTIAL', 
    'Dry Creek 30 FLOW',
    'Dry Creek 30 FLOW-BASE', 
    'Dry Creek 30 INFILTRATION',
    'Dry Creek 30 PERC-SOIL',
    'Dry Creek 30 SATURATION FRACTION',
    'Warm Springs Dam Inflow FLOW',
    ]
lstmPhysicsHourly = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data, hourly=True)

# %%
lstmPhysicsHourly.train()
# Out:
# 2025-01-30 11:31:44,291: Logging to /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/output.log initialized.
# 2025-01-30 11:31:44,293: ### Folder structure created at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144
# 2025-01-30 11:31:44,293: ### Run configurations for testing_run
# 2025-01-30 11:31:44,294: experiment_name: testing_run
# 2025-01-30 11:31:44,294: train_basin_file: warm springs
# 2025-01-30 11:31:44,295: validation_basin_file: warm springs
# 2025-01-30 11:31:44,296: test_basin_file: warm springs
# 2025-01-30 11:31:44,296: train_start_date: 1994-10-01 00:00:00
# 2025-01-30 11:31:44,296: train_end_date: 2002-09-30 00:00:00
# 2025-01-30 11:31:44,297: validation_start_date: 2002-10-01 00:00:00
# 2025-01-30 11:31:44,297: validation_end_date: 2005-09-30 00:00:00
# 2025-01-30 11:31:44,303: test_start_date: 2005-10-01 00:00:00
# 2025-01-30 11:31:44,304: test_end_date: 2009-09-30 00:00:00
# 2025-01-30 11:31:44,304: device: cpu
# 2025-01-30 11:31:44,304: physics_informed: True
# 2025-01-30 11:31:44,305: physics_data_file: /Users/mia/research/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_hourly.csv
# 2025-01-30 11:31:44,305: validate_every: 5
# 2025-01-30 11:31:44,306: validate_n_random_basins: 1
# 2025-01-30 11:31:44,306: metrics: ['NSE', 'MSE']
# 2025-01-30 11:31:44,306: model: cudalstm
# 2025-01-30 11:31:44,307: head: regression
# 2025-01-30 11:31:44,307: output_activation: linear
# 2025-01-30 11:31:44,308: hidden_size: 8
# 2025-01-30 11:31:44,309: initial_forget_bias: 3
# 2025-01-30 11:31:44,309: output_dropout: 0.4
# 2025-01-30 11:31:44,310: optimizer: Adam
# 2025-01-30 11:31:44,310: loss: NSE
# 2025-01-30 11:31:44,310: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-30 11:31:44,310: batch_size: 256
# 2025-01-30 11:31:44,311: epochs: 1
# 2025-01-30 11:31:44,311: clip_gradient_norm: 1
# 2025-01-30 11:31:44,311: predict_last_n: 1
# 2025-01-30 11:31:44,311: seq_length: 90
# 2025-01-30 11:31:44,312: log_interval: 16
# 2025-01-30 11:31:44,312: log_tensorboard: True
# 2025-01-30 11:31:44,313: log_n_figures: 1
# 2025-01-30 11:31:44,313: save_weights_every: 1
# 2025-01-30 11:31:44,313: dataset: russian_river
# 2025-01-30 11:31:44,314: data_dir: ../../../UCB-USACE-LSTMs/data/updated_russian_river_folder
# 2025-01-30 11:31:44,314: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'Dry Creek 20 ET-POTENTIAL', 'Dry Creek 20 FLOW', 'Dry Creek 20 FLOW-BASE', 'Dry Creek 20 INFILTRATION', 'Dry Creek 20 PERC-SOIL', 'Dry Creek 20 SATURATION FRACTION', 'Dry Creek 30 ET-POTENTIAL', 'Dry Creek 30 FLOW', 'Dry Creek 30 FLOW-BASE', 'Dry Creek 30 INFILTRATION', 'Dry Creek 30 PERC-SOIL', 'Dry Creek 30 SATURATION FRACTION', 'Warm Springs Dam Inflow FLOW']
# 2025-01-30 11:31:44,314: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-30 11:31:44,314: hourly: True
# 2025-01-30 11:31:44,315: number_of_basins: 1
# 2025-01-30 11:31:44,315: run_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144
# 2025-01-30 11:31:44,316: train_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/train_data
# 2025-01-30 11:31:44,316: img_log_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/img_log
# 2025-01-30 11:31:44,320: ### Device cpu will be used for training
# 2025-01-30 11:31:44,321: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-30 11:31:44,873: Loading data from file: /Users/mia/research/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_hourly.csv, hourly: True
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# 2025-01-30 11:31:45,371: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 772.29it/s]
# 2025-01-30 11:31:45,385: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# # Epoch 1: 100%|██████████| 266/266 [00:13<00:00, 19.40it/s, Loss: 0.0000]
# 2025-01-30 11:31:59,582: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-30 11:31:59,602: Using the model weights from /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/model_epoch001.pt
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-30 11:32:00,392: Loading data from file: /Users/mia/research/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_hourly.csv, hourly: True
# # Validation: 100%|██████████| 1/1 [00:03<00:00,  3.47s/it]
# 2025-01-30 11:32:03,101: Stored metrics at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/validation/model_epoch001/validation_metrics.csv
# 2025-01-30 11:32:03,105: Stored results at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/validation/model_epoch001/validation_results.p
# PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144')

# %%
lstmPhysicsHourly.results()
# Out:
# Using basin: Warm Springs
# Using target variable: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH
# Observed_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_obs
# Simulated_key: LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH_sim
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# [INFO] CSV output saved at: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/results_output_validation.csv
# ({'NSE': 0.5405028164386749,
#   'MSE': 291590.96875,
#   'RMSE': 539.9916376667328,
#   'KGE': 0.6598511799176773,
#   'Alpha-NSE': 0.8223860034688225,
#   'Beta-KGE': 1.1318001747131348,
#   'Beta-NSE': 0.05386064533706782,
#   'Pearson-r': 0.7415755391120911,
#   'FHV': -14.596298336982727,
#   'FMS': -22.8165007295205,
#   'FLV': -2736.552830197621,
#   'Peak-Timing': nan,
#   'Peak-MAPE': 67.20342134174547},
#  PosixPath('/Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113144/results_output_validation.csv'))

# %% [markdown]
# TEST OF THE EXTENDED TRAINING PERIOD

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("warm_springs_dam.yaml")
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv")
params = {
    "epochs":5,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
features_with_physics = [
    #from daily.csv
    "DRY CREEK 20 PRECIP-INC SCREENED",
    "DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "DRY CREEK 30 PRECIP-INC SCREENED",
    "DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    "SANTA ROSA CA HUMIDITY USAF-NOAA",
    "SANTA ROSA CA SOLAR RADIATION USAF-NOAA",
    "SANTA ROSA CA TEMPERATURE USAF-NOAA",
    "SANTA ROSA CA WINDSPEED USAF-NOAA",
    #from Warm_Spring_Inflow.csv
    'Dry Creek 20 ET-POTENTIAL', 
    'Dry Creek 20 FLOW',
    'Dry Creek 20 FLOW-BASE', 
    'Dry Creek 20 INFILTRATION',
    'Dry Creek 20 PERC-SOIL',
    'Dry Creek 20 SATURATION FRACTION',
    'Dry Creek 30 ET-POTENTIAL', 
    'Dry Creek 30 FLOW',
    'Dry Creek 30 FLOW-BASE', 
    'Dry Creek 30 INFILTRATION',
    'Dry Creek 30 PERC-SOIL',
    'Dry Creek 30 SATURATION FRACTION',
    'Warm Springs Dam Inflow FLOW',
    ]
#extend train period set to true
lstmPhysicsDailyExtended = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data, hourly=False, extend_train_period=True)

# %%
lstmPhysicsDailyExtended.train()
# Out:
# 2025-01-30 11:32:03,468: Logging to /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113203/output.log initialized.
# 2025-01-30 11:32:03,469: ### Folder structure created at /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113203
# 2025-01-30 11:32:03,469: ### Run configurations for testing_run
# 2025-01-30 11:32:03,470: experiment_name: testing_run
# 2025-01-30 11:32:03,470: train_basin_file: warm springs
# 2025-01-30 11:32:03,471: validation_basin_file: warm springs
# 2025-01-30 11:32:03,471: test_basin_file: warm springs
# 2025-01-30 11:32:03,472: train_start_date: 1994-10-01 00:00:00
# 2025-01-30 11:32:03,474: train_end_date: 2005-09-30 00:00:00
# 2025-01-30 11:32:03,476: validation_start_date: 2002-10-01 00:00:00
# 2025-01-30 11:32:03,478: validation_end_date: 2005-09-30 00:00:00
# 2025-01-30 11:32:03,481: test_start_date: 2005-10-01 00:00:00
# 2025-01-30 11:32:03,482: test_end_date: 2009-09-30 00:00:00
# 2025-01-30 11:32:03,483: device: cpu
# 2025-01-30 11:32:03,484: physics_informed: True
# 2025-01-30 11:32:03,486: physics_data_file: F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/WarmSprings_Inflow_daily.csv
# 2025-01-30 11:32:03,486: validate_every: 5
# 2025-01-30 11:32:03,488: validate_n_random_basins: 1
# 2025-01-30 11:32:03,489: metrics: ['NSE', 'MSE']
# 2025-01-30 11:32:03,490: model: cudalstm
# 2025-01-30 11:32:03,490: head: regression
# 2025-01-30 11:32:03,491: output_activation: linear
# 2025-01-30 11:32:03,491: hidden_size: 128
# 2025-01-30 11:32:03,492: initial_forget_bias: 3
# 2025-01-30 11:32:03,494: output_dropout: 0.4
# 2025-01-30 11:32:03,495: optimizer: Adam
# 2025-01-30 11:32:03,496: loss: NSE
# 2025-01-30 11:32:03,497: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-30 11:32:03,497: batch_size: 256
# 2025-01-30 11:32:03,497: epochs: 5
# 2025-01-30 11:32:03,498: clip_gradient_norm: 1
# 2025-01-30 11:32:03,498: predict_last_n: 1
# 2025-01-30 11:32:03,498: seq_length: 90
# 2025-01-30 11:32:03,498: log_interval: 16
# 2025-01-30 11:32:03,499: log_tensorboard: True
# 2025-01-30 11:32:03,499: log_n_figures: 1
# 2025-01-30 11:32:03,500: save_weights_every: 5
# 2025-01-30 11:32:03,500: dataset: russian_river
# 2025-01-30 11:32:03,500: data_dir: F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder
# 2025-01-30 11:32:03,501: dynamic_inputs: ['DRY CREEK 20 PRECIP-INC SCREENED', 'DRY CREEK 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 30 PRECIP-INC SCREENED', 'DRY CREEK 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'Dry Creek 20 ET-POTENTIAL', 'Dry Creek 20 FLOW', 'Dry Creek 20 FLOW-BASE', 'Dry Creek 20 INFILTRATION', 'Dry Creek 20 PERC-SOIL', 'Dry Creek 20 SATURATION FRACTION', 'Dry Creek 30 ET-POTENTIAL', 'Dry Creek 30 FLOW', 'Dry Creek 30 FLOW-BASE', 'Dry Creek 30 INFILTRATION', 'Dry Creek 30 PERC-SOIL', 'Dry Creek 30 SATURATION FRACTION', 'Warm Springs Dam Inflow FLOW']
# 2025-01-30 11:32:03,501: target_variables: ['LAKE SONOMA FLOW-RES IN CALC-VAL-SHIFT-SMOOTH']
# 2025-01-30 11:32:03,502: hourly: False
# 2025-01-30 11:32:03,502: number_of_basins: 1
# 2025-01-30 11:32:03,502: run_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113203
# 2025-01-30 11:32:03,503: train_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113203/train_data
# 2025-01-30 11:32:03,503: img_log_dir: /Users/mia/research/UCB-USACE-LSTMs/neuralhydrology/warm_springs_all/runs/testing_run_3001_113203/img_log
# 2025-01-30 11:32:03,506: ### Device cpu will be used for training
# 2025-01-30 11:32:03,507: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 lstmPhysicsDailyExtended.train()
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py:73, in train(self)
#      71 if self._num_ensemble_members == 1:
#      72     self._model = self._train_model()  # returns run directory of single model
# ---> 73     self._eval_model(self._model)
#      74 else:
#      75     # returns dict with predictions on test set and metrics
#      76     self.model = self._train_ensemble()
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py:137, in _train_model(self)
#     134     self._config.device = "cpu"
#     136 start_training(self._config)
# --> 137 path = self._config.run_dir
#     138 return path
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/training/train.py:19, in start_training(cfg)
#      17 else:
#      18     raise ValueError(f"Unknown head {cfg.head}.")
# ---> 19 trainer.initialize_training()
#      20 trainer.train_and_validate()
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py:147, in BaseTrainer.initialize_training(self)
#     144     self._scaler = load_scaler(self.cfg.base_run_dir)
#     146 # Initialize dataset before the model is loaded.
# --> 147 ds = self._get_dataset()
#     148 if len(ds) == 0:
#     149     raise ValueError("Dataset contains no samples.")
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py:80, in BaseTrainer._get_dataset(self)
#      79 def _get_dataset(self) -> BaseDataset:
# ---> 80     return get_dataset(cfg=self.cfg, period="train", is_train=True, scaler=self._scaler)
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/datasetzoo/__init__.py:89, in get_dataset(cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      86 else:
#      87     raise NotImplementedError(f"No dataset class implemented for dataset {cfg.dataset}")
# ---> 89 ds = Dataset(cfg=cfg,
#      90              is_train=is_train,
#      91              period=period,
#      92              basin=basin,
#      93              additional_features=additional_features,
#      94              id_to_int=id_to_int,
#      95              scaler=scaler)
#      96 return ds
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/datasetzoo/russianriver.py:56, in RussianRiver.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      47 def __init__(self,
#      48              cfg: Config,
#      49              is_train: bool,
#    (...)
#      54              scaler: Dict[str, Union[pd.Series, xarray.DataArray]] = {}):
#      55     # initialize parent class
# ---> 56     super(RussianRiver, self).__init__(cfg=cfg,
#      57                                           is_train=is_train,
#      58                                           period=period,
#      59                                           basin=basin,
#      60                                           additional_features=additional_features,
#      61                                           id_to_int=id_to_int,
#      62                                           scaler=scaler)
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/datasetzoo/basedataset.py:146, in BaseDataset.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#     143         self._create_id_to_int()
#     145 # load and preprocess data
# --> 146 self._load_data()
#     148 if self.is_train:
#     149     self._dump_scaler()
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/datasetzoo/basedataset.py:720, in BaseDataset._load_data(self)
#     716 def _load_data(self):
#     717     # load attributes first to sanity-check those features before doing the compute expensive time series loading
#     718     self._load_combined_attributes()
# --> 720     xr = self._load_or_create_xarray_dataset()
#     722     if self.cfg.loss.lower() in ['nse', 'weightednse']:
#     723         # get the std of the discharge for each basin, which is needed for the (weighted) NSE loss.
#     724         self._calculate_per_basin_std(xr)
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/datasetzoo/basedataset.py:336, in BaseDataset._load_or_create_xarray_dataset(self)
#     334     LOGGER.info("Loading basin data into xarray data set.")
#     335 for basin in tqdm(self.basins, disable=self._disable_pbar, file=sys.stdout):
# --> 336     df = self._load_basin_data(basin)
#     338     # add columns from dataframes passed as additional data files
#     339     df = pd.concat([df, *[d[basin] for d in self.additional_features]], axis=1)
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/datasetzoo/russianriver.py:80, in RussianRiver._load_basin_data(self, basin)
#      64 def _load_basin_data(self, basin: str) -> pd.DataFrame:
#      65     """Load basin time series data
#      66
#      67     This function is used to load the time series data (meteorological forcing, streamflow, etc.) and make available
#    (...)
#      78         Time-indexed DataFrame, containing the time series data (e.g., forcings + discharge).
#      79     """
# ---> 80     df = load_russian_river_data(self.cfg.data_dir, self.cfg.hourly) #daily or hourly df
#      81     if self.cfg.physics_informed:
#      82         physics_file = self.cfg.physics_data_file
#
# File ~/research/UCB-USACE-LSTMs/neuralhydrology/datasetzoo/russianriver.py:117, in load_russian_river_data(data_dir, hourly)
#     115 else:
#     116     file_path = data_dir / 'daily.csv'
# --> 117 df = pd.read_csv(file_path, low_memory=False)
#     118 cleaned_df = clean_df(df)
#     119 return cleaned_df
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/daily.csv'

# %%
#NOTE Right now the extend train only alters the train period to include the validation as well, so you should use test for 
# results because evaluating on the validation period would overlap with what the model was trained on
physics_metrics, physics_path = lstmPhysicsDailyExtended.results('test')
