# %% [markdown]
# ## Imports

# %%
import sys
import os
import pickle

library_path = os.path.join('..', '..', '..','UCB-USACE-LSTMs')
sys.path.insert(0, library_path)

from pathlib import Path
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation.metrics import *
from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble
from neuralhydrology.UCB_training.UCB_train import UCB_trainer
from neuralhydrology.UCB_training.UCB_train import clean_daily
from neuralhydrology.UCB_training.UCB_train import combinedPlot
from neuralhydrology.evaluation.metrics import calculate_all_metrics

# %% [markdown]
# ## Working directory

# %%
print("Current Working Directory:", os.getcwd())
print("Train Basin File Exists:", os.path.exists("calpella"))
# Out:
# Current Working Directory: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all
# Train Basin File Exists: True

# %% [markdown]
# ## Standard daily LSTM, train on training subset, evaluate on evaluation period (for hyperparameter search)

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("calpella_gage.yaml")
params = {
    "epochs":16,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
#defaults to daily so no need to specify hourly
lstmNoPhysicsDaily = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params)

# %%
lstmNoPhysicsDaily.train()
# Out:
# 2025-01-20 14:24:55,206: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455\output.log initialized.
# 2025-01-20 14:24:55,208: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455
# 2025-01-20 14:24:55,210: ### Run configurations for testing_run
# 2025-01-20 14:24:55,214: experiment_name: testing_run
# 2025-01-20 14:24:55,217: train_basin_file: calpella
# 2025-01-20 14:24:55,220: validation_basin_file: calpella
# 2025-01-20 14:24:55,223: test_basin_file: calpella
# 2025-01-20 14:24:55,227: train_start_date: 1994-10-01 00:00:00
# 2025-01-20 14:24:55,229: train_end_date: 2002-09-30 00:00:00
# 2025-01-20 14:24:55,233: validation_start_date: 2002-10-01 00:00:00
# 2025-01-20 14:24:55,236: validation_end_date: 2005-09-30 00:00:00
# 2025-01-20 14:24:55,238: test_start_date: 2005-10-01 00:00:00
# 2025-01-20 14:24:55,240: test_end_date: 2009-09-30 00:00:00
# 2025-01-20 14:24:55,244: device: cpu
# 2025-01-20 14:24:55,246: physics_informed: False
# 2025-01-20 14:24:55,247: physics_data_file: None
# 2025-01-20 14:24:55,249: validate_every: 5
# 2025-01-20 14:24:55,252: validate_n_random_basins: 1
# 2025-01-20 14:24:55,253: metrics: ['NSE', 'MSE']
# 2025-01-20 14:24:55,256: model: cudalstm
# 2025-01-20 14:24:55,257: head: regression
# 2025-01-20 14:24:55,259: output_activation: linear
# 2025-01-20 14:24:55,260: hidden_size: 128
# 2025-01-20 14:24:55,262: initial_forget_bias: 3
# 2025-01-20 14:24:55,264: output_dropout: 0.4
# 2025-01-20 14:24:55,265: optimizer: Adam
# 2025-01-20 14:24:55,266: loss: NSE
# 2025-01-20 14:24:55,268: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-20 14:24:55,269: batch_size: 256
# 2025-01-20 14:24:55,270: epochs: 16
# 2025-01-20 14:24:55,271: clip_gradient_norm: 1
# 2025-01-20 14:24:55,272: predict_last_n: 1
# 2025-01-20 14:24:55,274: seq_length: 90
# 2025-01-20 14:24:55,275: log_interval: 16
# 2025-01-20 14:24:55,276: log_tensorboard: True
# 2025-01-20 14:24:55,277: log_n_figures: 1
# 2025-01-20 14:24:55,278: save_weights_every: 16
# 2025-01-20 14:24:55,279: dataset: russian_river
# 2025-01-20 14:24:55,280: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-20 14:24:55,281: dynamic_inputs: ['EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'POTTER VALLEY CA FLOW USGS_ADJUSTED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA']
# 2025-01-20 14:24:55,282: target_variables: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:24:55,283: clip_targets_to_zero: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:24:55,284: hourly: False
# 2025-01-20 14:24:55,285: number_of_basins: 1
# 2025-01-20 14:24:55,286: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455
# 2025-01-20 14:24:55,287: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455\train_data
# 2025-01-20 14:24:55,288: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455\img_log
# 2025-01-20 14:24:55,299: ### Device cpu will be used for training
# 2025-01-20 14:24:55,302: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  3.65it/s]
# 2025-01-20 14:24:55,594: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 335.73it/s]
# 2025-01-20 14:24:55,632: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
# # Epoch 1: 100%|██████████| 11/11 [00:01<00:00,  7.94it/s, Loss: 0.0000]
# 2025-01-20 14:25:01,991: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 11/11 [00:01<00:00, 10.98it/s, Loss: 0.0000]
# 2025-01-20 14:25:03,000: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 11/11 [00:00<00:00, 11.22it/s, Loss: 0.0000]
# 2025-01-20 14:25:03,987: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 11/11 [00:00<00:00, 11.21it/s, Loss: 0.0000]
# 2025-01-20 14:25:04,977: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 11/11 [00:00<00:00, 11.08it/s, Loss: 0.0000]
# 2025-01-20 14:25:05,979: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# 2025-01-20 14:25:07,469: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.75208, MSE: 42471.07812
# # Epoch 6: 100%|██████████| 11/11 [00:01<00:00,  8.87it/s, Loss: 0.0000]
# 2025-01-20 14:25:08,718: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 11/11 [00:01<00:00, 10.29it/s, Loss: 0.0000]
# 2025-01-20 14:25:09,793: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 11/11 [00:01<00:00, 10.26it/s, Loss: 0.0000]
# 2025-01-20 14:25:10,874: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 11/11 [00:01<00:00, 10.43it/s, Loss: 0.0000]
# 2025-01-20 14:25:11,937: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 11/11 [00:01<00:00, 10.36it/s, Loss: 0.0000]
# 2025-01-20 14:25:13,006: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.40it/s]
# 2025-01-20 14:25:13,856: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.79937, MSE: 34369.75391
# # Epoch 11: 100%|██████████| 11/11 [00:01<00:00,  6.70it/s, Loss: 0.0000]
# 2025-01-20 14:25:15,513: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 11/11 [00:01<00:00, 10.18it/s, Loss: 0.0000]
# 2025-01-20 14:25:16,603: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 11/11 [00:01<00:00, 10.07it/s, Loss: 0.0000]
# 2025-01-20 14:25:17,702: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 11/11 [00:01<00:00, 10.00it/s, Loss: 0.0000]
# 2025-01-20 14:25:18,809: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 11/11 [00:01<00:00,  9.95it/s, Loss: 0.0000]
# 2025-01-20 14:25:19,922: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.65it/s]
# 2025-01-20 14:25:20,572: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.74195, MSE: 44207.31250
# # Epoch 16: 100%|██████████| 11/11 [00:01<00:00,  9.16it/s, Loss: 0.0000]
# 2025-01-20 14:25:21,785: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-20 14:25:21,868: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455\model_epoch016.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.80it/s]
# 2025-01-20 14:25:22,465: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455\validation\model_epoch016\validation_metrics.csv
# 2025-01-20 14:25:22,468: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455\validation\model_epoch016\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_2001_142455')

# %%
lstmNoPhysicsDaily.results()
# Out:
# Using basin: Calpella
# Using target variable: NR CALPELLA FLOW COE CPL
# Observed_key: NR CALPELLA FLOW COE CPL_obs
# Simulated_key: NR CALPELLA FLOW COE CPL_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142455\results_output_validation.csv
# ({'NSE': 0.7578212469816208,
#   'MSE': 41488.18359375,
#   'RMSE': 203.68648358138543,
#   'KGE': 0.7772419500500333,
#   'Alpha-NSE': 0.8219286377347167,
#   'Beta-KGE': 1.0408791303634644,
#   'Beta-NSE': 0.031274833863343614,
#   'Pearson-r': 0.8725612482043825,
#   'FHV': -15.596018731594086,
#   'FMS': -23.281440007729895,
#   'FLV': -2295.4380267442393,
#   'Peak-Timing': 0.6,
#   'Peak-MAPE': 59.77750301361085},
#  WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_2001_142455/results_output_validation.csv'))

# %% [markdown]
# ## Physics-informed LSTM, train on training subset, evaluate on evaluation period (for hyperparameter search)

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("calpella_gage.yaml")
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/Calpella_daily.csv")
params = {
    "epochs":16,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
features_with_physics = [
    #from daily
    "EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "EF RUSSIAN 20 PRECIP-INC SCREENED",
    "POTTER VALLEY CA FLOW USGS_ADJUSTED",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    #from new capella.csv
    'Capella Gage FLOW',
    'EF Russian 20 ET-POTENTIAL',
    'EF Russian 20 FLOW',
    'EF Russian 20 FLOW-BASE',
    'EF Russian 20 INFILTRATION',
    'EF Russian 20 PERC-SOIL',
    'EF Russian 20 SATURATION FRACTION',
#    'Lake Mendocino Storage',
    ]
lstmPhysicsDaily = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data, hourly=False)

# %%
lstmPhysicsDaily.train()
# Out:
# 2025-01-20 14:25:23,406: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523\output.log initialized.
# 2025-01-20 14:25:23,408: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523
# 2025-01-20 14:25:23,409: ### Run configurations for testing_run
# 2025-01-20 14:25:23,411: experiment_name: testing_run
# 2025-01-20 14:25:23,412: train_basin_file: calpella
# 2025-01-20 14:25:23,414: validation_basin_file: calpella
# 2025-01-20 14:25:23,415: test_basin_file: calpella
# 2025-01-20 14:25:23,417: train_start_date: 1994-10-01 00:00:00
# 2025-01-20 14:25:23,419: train_end_date: 2002-09-30 00:00:00
# 2025-01-20 14:25:23,420: validation_start_date: 2002-10-01 00:00:00
# 2025-01-20 14:25:23,421: validation_end_date: 2005-09-30 00:00:00
# 2025-01-20 14:25:23,422: test_start_date: 2005-10-01 00:00:00
# 2025-01-20 14:25:23,423: test_end_date: 2009-09-30 00:00:00
# 2025-01-20 14:25:23,425: device: cpu
# 2025-01-20 14:25:23,426: physics_informed: True
# 2025-01-20 14:25:23,427: physics_data_file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv
# 2025-01-20 14:25:23,428: validate_every: 5
# 2025-01-20 14:25:23,430: validate_n_random_basins: 1
# 2025-01-20 14:25:23,431: metrics: ['NSE', 'MSE']
# 2025-01-20 14:25:23,432: model: cudalstm
# 2025-01-20 14:25:23,434: head: regression
# 2025-01-20 14:25:23,435: output_activation: linear
# 2025-01-20 14:25:23,436: hidden_size: 128
# 2025-01-20 14:25:23,437: initial_forget_bias: 3
# 2025-01-20 14:25:23,438: output_dropout: 0.4
# 2025-01-20 14:25:23,439: optimizer: Adam
# 2025-01-20 14:25:23,440: loss: NSE
# 2025-01-20 14:25:23,441: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-20 14:25:23,443: batch_size: 256
# 2025-01-20 14:25:23,444: epochs: 16
# 2025-01-20 14:25:23,445: clip_gradient_norm: 1
# 2025-01-20 14:25:23,446: predict_last_n: 1
# 2025-01-20 14:25:23,448: seq_length: 90
# 2025-01-20 14:25:23,449: log_interval: 16
# 2025-01-20 14:25:23,450: log_tensorboard: True
# 2025-01-20 14:25:23,452: log_n_figures: 1
# 2025-01-20 14:25:23,453: save_weights_every: 16
# 2025-01-20 14:25:23,454: dataset: russian_river
# 2025-01-20 14:25:23,456: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-20 14:25:23,457: dynamic_inputs: ['EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'POTTER VALLEY CA FLOW USGS_ADJUSTED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'Capella Gage FLOW', 'EF Russian 20 ET-POTENTIAL', 'EF Russian 20 FLOW', 'EF Russian 20 FLOW-BASE', 'EF Russian 20 INFILTRATION', 'EF Russian 20 PERC-SOIL', 'EF Russian 20 SATURATION FRACTION']
# 2025-01-20 14:25:23,458: target_variables: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:25:23,459: clip_targets_to_zero: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:25:23,460: hourly: False
# 2025-01-20 14:25:23,460: number_of_basins: 1
# 2025-01-20 14:25:23,461: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523
# 2025-01-20 14:25:23,463: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523\train_data
# 2025-01-20 14:25:23,465: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523\img_log
# 2025-01-20 14:25:23,484: ### Device cpu will be used for training
# 2025-01-20 14:25:23,487: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-20 14:25:23,681: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv, hourly: False
# 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
# 2025-01-20 14:25:23,909: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 335.06it/s]
# 2025-01-20 14:25:23,928: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 26.43it/s]
# # Epoch 1: 100%|██████████| 11/11 [00:01<00:00,  8.74it/s, Loss: 0.0000]
# 2025-01-20 14:25:25,551: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 11/11 [00:01<00:00, 10.46it/s, Loss: 0.0000]
# 2025-01-20 14:25:26,612: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 11/11 [00:01<00:00, 10.30it/s, Loss: 0.0000]
# 2025-01-20 14:25:27,686: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 11/11 [00:01<00:00, 10.51it/s, Loss: 0.0000]
# 2025-01-20 14:25:28,742: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 11/11 [00:01<00:00,  9.86it/s, Loss: 0.0000]
# 2025-01-20 14:25:29,864: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-20 14:25:30,020: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.33it/s]
# 2025-01-20 14:25:30,740: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.82348, MSE: 30240.78906
# # Epoch 6: 100%|██████████| 11/11 [00:01<00:00,  8.86it/s, Loss: 0.0000]
# 2025-01-20 14:25:31,993: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 11/11 [00:01<00:00, 10.37it/s, Loss: 0.0000]
# 2025-01-20 14:25:33,061: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 11/11 [00:01<00:00, 10.53it/s, Loss: 0.0000]
# 2025-01-20 14:25:34,115: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 11/11 [00:01<00:00, 10.60it/s, Loss: 0.0000]
# 2025-01-20 14:25:35,160: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 11/11 [00:01<00:00, 10.59it/s, Loss: 0.0000]
# 2025-01-20 14:25:36,207: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.68it/s]
# 2025-01-20 14:25:36,847: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.78158, MSE: 37417.99219
# # Epoch 11: 100%|██████████| 11/11 [00:01<00:00,  9.69it/s, Loss: 0.0000]
# 2025-01-20 14:25:37,993: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 11/11 [00:01<00:00, 10.35it/s, Loss: 0.0000]
# 2025-01-20 14:25:39,063: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 11/11 [00:01<00:00, 10.53it/s, Loss: 0.0000]
# 2025-01-20 14:25:40,116: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 11/11 [00:01<00:00, 10.57it/s, Loss: 0.0000]
# 2025-01-20 14:25:41,164: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 11/11 [00:01<00:00, 10.58it/s, Loss: 0.0000]
# 2025-01-20 14:25:42,212: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  7.23it/s]
# 2025-01-20 14:25:42,760: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.83279, MSE: 28644.70898
# # Epoch 16: 100%|██████████| 11/11 [00:01<00:00, 10.38it/s, Loss: 0.0000]
# 2025-01-20 14:25:43,831: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-20 14:25:43,925: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523\model_epoch016.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-20 14:25:44,167: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]
# 2025-01-20 14:25:44,561: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523\validation\model_epoch016\validation_metrics.csv
# 2025-01-20 14:25:44,564: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523\validation\model_epoch016\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_2001_142523')

# %%
lstmPhysicsDaily.results()
# Out:
# Using basin: Calpella
# Using target variable: NR CALPELLA FLOW COE CPL
# Observed_key: NR CALPELLA FLOW COE CPL_obs
# Simulated_key: NR CALPELLA FLOW COE CPL_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142523\results_output_validation.csv
# ({'NSE': 0.8398010432720184,
#   'MSE': 27444.04296875,
#   'RMSE': 165.66243680674867,
#   'KGE': 0.8860054824671455,
#   'Alpha-NSE': 0.9759332813768421,
#   'Beta-KGE': 1.0775879621505737,
#   'Beta-NSE': 0.05935920982877215,
#   'Pearson-r': 0.9200271845463526,
#   'FHV': 0.9262194857001305,
#   'FMS': -10.450330460124903,
#   'FLV': 76.48087490354827,
#   'Peak-Timing': 0.2,
#   'Peak-MAPE': 28.640592098236084},
#  WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_2001_142523/results_output_validation.csv'))

# %% [markdown]
# ## Retrain LSTM on entire train period using best hyperparameters, evaluate on test period

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("calpella_gage.yaml")
params = {
    "epochs":32,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
#defaults to daily so no need to specify hourly
lstmNoPhysicsDailyExtended = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, hourly=False, extend_train_period=True)

# %%
lstmNoPhysicsDailyExtended.train()
# Out:
# 2025-01-20 14:25:45,420: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\output.log initialized.
# 2025-01-20 14:25:45,421: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545
# 2025-01-20 14:25:45,423: ### Run configurations for testing_run
# 2025-01-20 14:25:45,426: experiment_name: testing_run
# 2025-01-20 14:25:45,428: train_basin_file: calpella
# 2025-01-20 14:25:45,430: validation_basin_file: calpella
# 2025-01-20 14:25:45,432: test_basin_file: calpella
# 2025-01-20 14:25:45,434: train_start_date: 1994-10-01 00:00:00
# 2025-01-20 14:25:45,435: train_end_date: 2005-09-30 00:00:00
# 2025-01-20 14:25:45,436: validation_start_date: 2002-10-01 00:00:00
# 2025-01-20 14:25:45,438: validation_end_date: 2005-09-30 00:00:00
# 2025-01-20 14:25:45,439: test_start_date: 2005-10-01 00:00:00
# 2025-01-20 14:25:45,440: test_end_date: 2009-09-30 00:00:00
# 2025-01-20 14:25:45,442: device: cpu
# 2025-01-20 14:25:45,443: physics_informed: False
# 2025-01-20 14:25:45,444: physics_data_file: None
# 2025-01-20 14:25:45,447: validate_every: 5
# 2025-01-20 14:25:45,448: validate_n_random_basins: 1
# 2025-01-20 14:25:45,449: metrics: ['NSE', 'MSE']
# 2025-01-20 14:25:45,451: model: cudalstm
# 2025-01-20 14:25:45,452: head: regression
# 2025-01-20 14:25:45,453: output_activation: linear
# 2025-01-20 14:25:45,455: hidden_size: 128
# 2025-01-20 14:25:45,456: initial_forget_bias: 3
# 2025-01-20 14:25:45,457: output_dropout: 0.4
# 2025-01-20 14:25:45,458: optimizer: Adam
# 2025-01-20 14:25:45,459: loss: NSE
# 2025-01-20 14:25:45,461: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-20 14:25:45,462: batch_size: 256
# 2025-01-20 14:25:45,464: epochs: 32
# 2025-01-20 14:25:45,465: clip_gradient_norm: 1
# 2025-01-20 14:25:45,467: predict_last_n: 1
# 2025-01-20 14:25:45,470: seq_length: 90
# 2025-01-20 14:25:45,472: log_interval: 16
# 2025-01-20 14:25:45,475: log_tensorboard: True
# 2025-01-20 14:25:45,477: log_n_figures: 1
# 2025-01-20 14:25:45,479: save_weights_every: 32
# 2025-01-20 14:25:45,480: dataset: russian_river
# 2025-01-20 14:25:45,482: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-20 14:25:45,483: dynamic_inputs: ['EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'POTTER VALLEY CA FLOW USGS_ADJUSTED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA']
# 2025-01-20 14:25:45,485: target_variables: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:25:45,486: clip_targets_to_zero: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:25:45,488: hourly: False
# 2025-01-20 14:25:45,490: number_of_basins: 1
# 2025-01-20 14:25:45,492: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545
# 2025-01-20 14:25:45,494: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\train_data
# 2025-01-20 14:25:45,496: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\img_log
# 2025-01-20 14:25:45,509: ### Device cpu will be used for training
# 2025-01-20 14:25:45,512: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  6.12it/s]
# 2025-01-20 14:25:45,691: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 200.92it/s]
# 2025-01-20 14:25:45,720: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 16.39it/s]
# # Epoch 1: 100%|██████████| 15/15 [00:01<00:00,  9.08it/s, Loss: 0.0000]
# 2025-01-20 14:25:47,739: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 15/15 [00:01<00:00, 10.49it/s, Loss: 0.0000]
# 2025-01-20 14:25:49,176: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 15/15 [00:01<00:00, 10.40it/s, Loss: 0.0000]
# 2025-01-20 14:25:50,626: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 15/15 [00:01<00:00, 10.52it/s, Loss: 0.0000]
# 2025-01-20 14:25:52,060: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 15/15 [00:01<00:00, 10.68it/s, Loss: 0.0000]
# 2025-01-20 14:25:53,472: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.56it/s]
# 2025-01-20 14:25:54,286: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.77130, MSE: 39179.91797
# # Epoch 6: 100%|██████████| 15/15 [00:01<00:00,  9.44it/s, Loss: 0.0000]
# 2025-01-20 14:25:55,884: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 15/15 [00:01<00:00, 10.25it/s, Loss: 0.0000]
# 2025-01-20 14:25:57,357: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 15/15 [00:01<00:00, 10.17it/s, Loss: 0.0000]
# 2025-01-20 14:25:58,841: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 15/15 [00:01<00:00, 10.14it/s, Loss: 0.0000]
# 2025-01-20 14:26:00,328: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 15/15 [00:01<00:00, 10.37it/s, Loss: 0.0000]
# 2025-01-20 14:26:01,783: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  7.02it/s]
# 2025-01-20 14:26:02,452: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.76816, MSE: 39716.87109
# # Epoch 11: 100%|██████████| 15/15 [00:01<00:00,  9.49it/s, Loss: 0.0000]
# 2025-01-20 14:26:04,043: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 15/15 [00:01<00:00, 10.07it/s, Loss: 0.0000]
# 2025-01-20 14:26:05,541: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 15/15 [00:01<00:00, 10.28it/s, Loss: 0.0000]
# 2025-01-20 14:26:07,008: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 15/15 [00:01<00:00, 10.36it/s, Loss: 0.0000]
# 2025-01-20 14:26:08,463: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 15/15 [00:01<00:00, 10.34it/s, Loss: 0.0000]
# 2025-01-20 14:26:09,922: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.70it/s]
# 2025-01-20 14:26:10,508: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.83931, MSE: 27528.92383
# # Epoch 16: 100%|██████████| 15/15 [00:01<00:00, 10.37it/s, Loss: 0.0000]
# 2025-01-20 14:26:11,966: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 17: 100%|██████████| 15/15 [00:01<00:00, 10.49it/s, Loss: 0.0000]
# 2025-01-20 14:26:13,403: Epoch 17 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 18: 100%|██████████| 15/15 [00:01<00:00, 10.59it/s, Loss: 0.0000]
# 2025-01-20 14:26:14,828: Epoch 18 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 19: 100%|██████████| 15/15 [00:01<00:00, 10.51it/s, Loss: 0.0000]
# 2025-01-20 14:26:16,265: Epoch 19 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 20: 100%|██████████| 15/15 [00:01<00:00, 10.64it/s, Loss: 0.0000]
# 2025-01-20 14:26:17,684: Epoch 20 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.93it/s]
# 2025-01-20 14:26:18,285: Epoch 20 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.83041, MSE: 29053.21094
# # Epoch 21: 100%|██████████| 15/15 [00:01<00:00,  9.81it/s, Loss: 0.0000]
# 2025-01-20 14:26:19,827: Epoch 21 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 22: 100%|██████████| 15/15 [00:01<00:00, 10.39it/s, Loss: 0.0000]
# 2025-01-20 14:26:21,278: Epoch 22 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 23: 100%|██████████| 15/15 [00:01<00:00, 10.42it/s, Loss: 0.0000]
# 2025-01-20 14:26:22,725: Epoch 23 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 24: 100%|██████████| 15/15 [00:01<00:00, 10.37it/s, Loss: 0.0000]
# 2025-01-20 14:26:24,180: Epoch 24 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 25: 100%|██████████| 15/15 [00:01<00:00, 10.53it/s, Loss: 0.0000]
# 2025-01-20 14:26:25,612: Epoch 25 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  7.07it/s]
# 2025-01-20 14:26:26,244: Epoch 25 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.84147, MSE: 27158.27539
# # Epoch 26: 100%|██████████| 15/15 [00:01<00:00,  9.77it/s, Loss: 0.0000]
# 2025-01-20 14:26:27,789: Epoch 26 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 27: 100%|██████████| 15/15 [00:01<00:00, 10.65it/s, Loss: 0.0000]
# 2025-01-20 14:26:29,205: Epoch 27 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 28: 100%|██████████| 15/15 [00:01<00:00, 10.54it/s, Loss: 0.0000]
# 2025-01-20 14:26:30,636: Epoch 28 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 29: 100%|██████████| 15/15 [00:01<00:00, 10.55it/s, Loss: 0.0000]
# 2025-01-20 14:26:32,066: Epoch 29 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-20 14:26:32,068: Setting learning rate to 0.005
# # Epoch 30: 100%|██████████| 15/15 [00:01<00:00, 10.47it/s, Loss: 0.0000]
# 2025-01-20 14:26:33,507: Epoch 30 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  7.33it/s]
# 2025-01-20 14:26:34,077: Epoch 30 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.86489, MSE: 23146.00195
# # Epoch 31: 100%|██████████| 15/15 [00:01<00:00,  9.75it/s, Loss: 0.0000]
# 2025-01-20 14:26:35,626: Epoch 31 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 32: 100%|██████████| 15/15 [00:01<00:00, 10.35it/s, Loss: 0.0000]
# 2025-01-20 14:26:37,083: Epoch 32 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-20 14:26:37,167: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\model_epoch032.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
# 2025-01-20 14:26:37,589: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\validation\model_epoch032\validation_metrics.csv
# 2025-01-20 14:26:37,592: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\validation\model_epoch032\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_2001_142545')

# %%
lstm_result_metrics, lstm_result_path = lstmNoPhysicsDailyExtended.results('test')
# Out:
# 2025-01-20 14:26:37,646: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\model_epoch032.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
# 2025-01-20 14:26:38,091: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\test\model_epoch032\test_metrics.csv
# 2025-01-20 14:26:38,094: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\test\model_epoch032\test_results.p
# Using basin: Calpella
# Using target variable: NR CALPELLA FLOW COE CPL
# Observed_key: NR CALPELLA FLOW COE CPL_obs
# Simulated_key: NR CALPELLA FLOW COE CPL_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142545\results_output_test.csv

# %%
lstm_result_metrics
# Out:
# {'NSE': 0.8153587132692337,
#  'MSE': 47024.3984375,
#  'RMSE': 216.8510973859713,
#  'KGE': 0.7671332785865745,
#  'Alpha-NSE': 0.7850635791226984,
#  'Beta-KGE': 0.9837226271629333,
#  'Beta-NSE': -0.009562160726856285,
#  'Pearson-r': 0.9118847796585827,
#  'FHV': -20.24422287940979,
#  'FMS': -24.261627362292923,
#  'FLV': -1012.8648771704327,
#  'Peak-Timing': 0.5,
#  'Peak-MAPE': 44.25943851470947}

# %% [markdown]
# ## Retrain PI-LSTM on entire train period using best hyperparameters, evaluate on test period

# %%
path_to_csv = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/")
path_to_yaml = Path("calpella_gage.yaml")
path_to_physics_data = Path("F:/Dino/UCB-USACE-LSTMs/data/updated_russian_river_folder/Calpella_daily.csv")
params = {
    "epochs":32,
    "hidden_size": 128,
    "output_dropout": 0.4,
    "seq_length": 90,
}
features_with_physics = [
    #from daily
    "EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "EF RUSSIAN 20 PRECIP-INC SCREENED",
    "POTTER VALLEY CA FLOW USGS_ADJUSTED",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    #from new capella.csv
    'Capella Gage FLOW',
    'EF Russian 20 ET-POTENTIAL',
    'EF Russian 20 FLOW',
    'EF Russian 20 FLOW-BASE',
    'EF Russian 20 INFILTRATION',
    'EF Russian 20 PERC-SOIL',
    'EF Russian 20 SATURATION FRACTION',
#    'Lake Mendocino Storage',
    ]
#extend train period set to true
lstmPhysicsDailyExtended = UCB_trainer(path_to_csv, yaml_path= path_to_yaml, hyperparams= params, input_features= features_with_physics, physics_informed=True, physics_data_file=path_to_physics_data, hourly=False, extend_train_period=True)

# %%
lstmPhysicsDailyExtended.train()
# Out:
# 2025-01-20 14:26:38,952: Logging to F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\output.log initialized.
# 2025-01-20 14:26:38,954: ### Folder structure created at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638
# 2025-01-20 14:26:38,956: ### Run configurations for testing_run
# 2025-01-20 14:26:38,957: experiment_name: testing_run
# 2025-01-20 14:26:38,959: train_basin_file: calpella
# 2025-01-20 14:26:38,961: validation_basin_file: calpella
# 2025-01-20 14:26:38,963: test_basin_file: calpella
# 2025-01-20 14:26:38,964: train_start_date: 1994-10-01 00:00:00
# 2025-01-20 14:26:38,966: train_end_date: 2005-09-30 00:00:00
# 2025-01-20 14:26:38,967: validation_start_date: 2002-10-01 00:00:00
# 2025-01-20 14:26:38,969: validation_end_date: 2005-09-30 00:00:00
# 2025-01-20 14:26:38,971: test_start_date: 2005-10-01 00:00:00
# 2025-01-20 14:26:38,972: test_end_date: 2009-09-30 00:00:00
# 2025-01-20 14:26:38,976: device: cpu
# 2025-01-20 14:26:38,978: physics_informed: True
# 2025-01-20 14:26:38,979: physics_data_file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv
# 2025-01-20 14:26:38,980: validate_every: 5
# 2025-01-20 14:26:38,981: validate_n_random_basins: 1
# 2025-01-20 14:26:38,982: metrics: ['NSE', 'MSE']
# 2025-01-20 14:26:38,983: model: cudalstm
# 2025-01-20 14:26:38,984: head: regression
# 2025-01-20 14:26:38,985: output_activation: linear
# 2025-01-20 14:26:38,986: hidden_size: 128
# 2025-01-20 14:26:38,988: initial_forget_bias: 3
# 2025-01-20 14:26:38,989: output_dropout: 0.4
# 2025-01-20 14:26:38,991: optimizer: Adam
# 2025-01-20 14:26:38,992: loss: NSE
# 2025-01-20 14:26:38,994: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2025-01-20 14:26:38,995: batch_size: 256
# 2025-01-20 14:26:38,996: epochs: 32
# 2025-01-20 14:26:38,998: clip_gradient_norm: 1
# 2025-01-20 14:26:38,999: predict_last_n: 1
# 2025-01-20 14:26:39,000: seq_length: 90
# 2025-01-20 14:26:39,002: log_interval: 16
# 2025-01-20 14:26:39,003: log_tensorboard: True
# 2025-01-20 14:26:39,004: log_n_figures: 1
# 2025-01-20 14:26:39,006: save_weights_every: 32
# 2025-01-20 14:26:39,007: dataset: russian_river
# 2025-01-20 14:26:39,008: data_dir: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder
# 2025-01-20 14:26:39,010: dynamic_inputs: ['EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'POTTER VALLEY CA FLOW USGS_ADJUSTED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'Capella Gage FLOW', 'EF Russian 20 ET-POTENTIAL', 'EF Russian 20 FLOW', 'EF Russian 20 FLOW-BASE', 'EF Russian 20 INFILTRATION', 'EF Russian 20 PERC-SOIL', 'EF Russian 20 SATURATION FRACTION']
# 2025-01-20 14:26:39,011: target_variables: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:26:39,011: clip_targets_to_zero: ['NR CALPELLA FLOW COE CPL']
# 2025-01-20 14:26:39,013: hourly: False
# 2025-01-20 14:26:39,015: number_of_basins: 1
# 2025-01-20 14:26:39,016: run_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638
# 2025-01-20 14:26:39,017: train_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\train_data
# 2025-01-20 14:26:39,018: img_log_dir: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\img_log
# 2025-01-20 14:26:39,024: ### Device cpu will be used for training
# 2025-01-20 14:26:39,026: Loading basin data into xarray data set.
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-20 14:26:39,173: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv, hourly: False
# 100%|██████████| 1/1 [00:00<00:00,  3.50it/s]
# 2025-01-20 14:26:39,322: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 200.85it/s]
# 2025-01-20 14:26:39,341: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 14.99it/s]
# # Epoch 1: 100%|██████████| 15/15 [00:01<00:00, 10.26it/s, Loss: 0.0000]
# 2025-01-20 14:26:41,138: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 15/15 [00:01<00:00, 10.46it/s, Loss: 0.0000]
# 2025-01-20 14:26:42,580: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 15/15 [00:02<00:00,  7.19it/s, Loss: 0.0000]
# 2025-01-20 14:26:44,674: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 15/15 [00:01<00:00,  8.14it/s, Loss: 0.0000]
# 2025-01-20 14:26:46,523: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 15/15 [00:02<00:00,  7.21it/s, Loss: 0.0000]
# 2025-01-20 14:26:48,612: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-20 14:26:48,811: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.84it/s]
# 2025-01-20 14:26:49,675: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.85478, MSE: 24878.60938
# # Epoch 6: 100%|██████████| 15/15 [00:02<00:00,  6.07it/s, Loss: 0.0000]
# 2025-01-20 14:26:52,156: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 15/15 [00:02<00:00,  6.67it/s, Loss: 0.0000]
# 2025-01-20 14:26:54,413: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 15/15 [00:02<00:00,  6.63it/s, Loss: 0.0000]
# 2025-01-20 14:26:56,682: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 15/15 [00:02<00:00,  6.60it/s, Loss: 0.0000]
# 2025-01-20 14:26:58,963: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 15/15 [00:02<00:00,  6.61it/s, Loss: 0.0000]
# 2025-01-20 14:27:01,239: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  5.98it/s]
# 2025-01-20 14:27:01,847: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.88440, MSE: 19803.66602
# # Epoch 11: 100%|██████████| 15/15 [00:02<00:00,  5.90it/s, Loss: 0.0000]
# 2025-01-20 14:27:04,397: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 15/15 [00:02<00:00,  6.51it/s, Loss: 0.0000]
# 2025-01-20 14:27:06,709: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 15/15 [00:02<00:00,  6.53it/s, Loss: 0.0000]
# 2025-01-20 14:27:09,015: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 15/15 [00:02<00:00,  6.53it/s, Loss: 0.0000]
# 2025-01-20 14:27:11,320: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 15/15 [00:02<00:00,  6.66it/s, Loss: 0.0000]
# 2025-01-20 14:27:13,578: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.70it/s]
# 2025-01-20 14:27:14,223: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.88852, MSE: 19098.11914
# # Epoch 16: 100%|██████████| 15/15 [00:02<00:00,  6.31it/s, Loss: 0.0000]
# 2025-01-20 14:27:16,612: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 17: 100%|██████████| 15/15 [00:02<00:00,  7.13it/s, Loss: 0.0000]
# 2025-01-20 14:27:18,722: Epoch 17 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 18: 100%|██████████| 15/15 [00:02<00:00,  6.95it/s, Loss: 0.0000]
# 2025-01-20 14:27:20,889: Epoch 18 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 19: 100%|██████████| 15/15 [00:02<00:00,  7.05it/s, Loss: 0.0000]
# 2025-01-20 14:27:23,024: Epoch 19 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 20: 100%|██████████| 15/15 [00:02<00:00,  7.02it/s, Loss: 0.0000]
# 2025-01-20 14:27:25,170: Epoch 20 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.93it/s]
# 2025-01-20 14:27:25,799: Epoch 20 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.89230, MSE: 18450.19141
# # Epoch 21: 100%|██████████| 15/15 [00:02<00:00,  6.82it/s, Loss: 0.0000]
# 2025-01-20 14:27:28,004: Epoch 21 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 22: 100%|██████████| 15/15 [00:02<00:00,  7.49it/s, Loss: 0.0000]
# 2025-01-20 14:27:30,013: Epoch 22 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 23: 100%|██████████| 15/15 [00:02<00:00,  7.10it/s, Loss: 0.0000]
# 2025-01-20 14:27:32,134: Epoch 23 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 24: 100%|██████████| 15/15 [00:01<00:00,  7.57it/s, Loss: 0.0000]
# 2025-01-20 14:27:34,125: Epoch 24 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 25: 100%|██████████| 15/15 [00:02<00:00,  7.37it/s, Loss: 0.0000]
# 2025-01-20 14:27:36,166: Epoch 25 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  5.98it/s]
# 2025-01-20 14:27:36,750: Epoch 25 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.90736, MSE: 15869.86523
# # Epoch 26: 100%|██████████| 15/15 [00:01<00:00,  7.76it/s, Loss: 0.0000]
# 2025-01-20 14:27:38,696: Epoch 26 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 27: 100%|██████████| 15/15 [00:01<00:00,  7.95it/s, Loss: 0.0000]
# 2025-01-20 14:27:40,590: Epoch 27 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 28: 100%|██████████| 15/15 [00:01<00:00,  7.56it/s, Loss: 0.0000]
# 2025-01-20 14:27:42,581: Epoch 28 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 29: 100%|██████████| 15/15 [00:01<00:00,  7.97it/s, Loss: 0.0000]
# 2025-01-20 14:27:44,472: Epoch 29 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-20 14:27:44,473: Setting learning rate to 0.005
# # Epoch 30: 100%|██████████| 15/15 [00:01<00:00,  8.34it/s, Loss: 0.0000]
# 2025-01-20 14:27:46,281: Epoch 30 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  6.24it/s]
# 2025-01-20 14:27:46,895: Epoch 30 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.91593, MSE: 14402.00684
# # Epoch 31: 100%|██████████| 15/15 [00:02<00:00,  7.29it/s, Loss: 0.0000]
# 2025-01-20 14:27:48,963: Epoch 31 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 32: 100%|██████████| 15/15 [00:01<00:00,  7.98it/s, Loss: 0.0000]
# 2025-01-20 14:27:50,852: Epoch 32 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-01-20 14:27:50,955: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\model_epoch032.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-20 14:27:51,204: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.80it/s]
# 2025-01-20 14:27:51,548: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\validation\model_epoch032\validation_metrics.csv
# 2025-01-20 14:27:51,551: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\validation\model_epoch032\validation_results.p
# WindowsPath('F:/Dino/UCB-USACE-LSTMs/neuralhydrology/calpella_all/runs/testing_run_2001_142638')

# %%
physics_informed_result_metrics, physics_informed_result_path = lstmPhysicsDailyExtended.results('test')
# Out:
# 2025-01-20 14:27:51,637: Using the model weights from F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\model_epoch032.pt
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]2025-01-20 14:27:51,840: Loading data from file: F:\Dino\UCB-USACE-LSTMs\data\updated_russian_river_folder\Calpella_daily.csv, hourly: False
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# 2025-01-20 14:27:52,207: Stored metrics at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\test\model_epoch032\test_metrics.csv
# 2025-01-20 14:27:52,210: Stored results at F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\test\model_epoch032\test_results.p
# Using basin: Calpella
# Using target variable: NR CALPELLA FLOW COE CPL
# Observed_key: NR CALPELLA FLOW COE CPL_obs
# Simulated_key: NR CALPELLA FLOW COE CPL_sim
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# [INFO] CSV output saved at: F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\runs\testing_run_2001_142638\results_output_test.csv

# %%
physics_informed_result_metrics
# Out:
# {'NSE': 0.8362835645675659,
#  'MSE': 41695.265625,
#  'RMSE': 204.19418607051475,
#  'KGE': 0.8288891881461639,
#  'Alpha-NSE': 0.9071987965631952,
#  'Beta-KGE': 0.8825223445892334,
#  'Beta-NSE': -0.06901245168380346,
#  'Pearson-r': 0.9171395929701713,
#  'FHV': -4.285842925310135,
#  'FMS': -9.702462427703585,
#  'FLV': -56.864041204198756,
#  'Peak-Timing': 0.0,
#  'Peak-MAPE': 20.011286735534668}

# %% [markdown]
# ## Inspect results

# %%
    model1_df = pd.read_csv(lstm_result_path) #colums: Date, Observed, Predicted
    model1_df.head()
# Out:
#          Date  Observed  Predicted
# 0  2005-10-01  184.2500  150.53737
# 1  2005-10-02  178.0000  151.94781
# 2  2005-10-03  187.2500  155.99477
# 3  2005-10-04  188.0833  154.21475
# 4  2005-10-05  182.1250  157.91557

# %%
    model2_df = pd.read_csv(physics_informed_result_path) #colums: Date, Observed, Predicted
    model1_df.head()
# Out:
#          Date  Observed  Predicted
# 0  2005-10-01  184.2500  150.53737
# 1  2005-10-02  178.0000  151.94781
# 2  2005-10-03  187.2500  155.99477
# 3  2005-10-04  188.0833  154.21475
# 4  2005-10-05  182.1250  157.91557

# %%
    hms_df = clean_daily(pd.read_csv(path_to_physics_data))
    hms_df.head()
# Out:
# 0                Day      Time Capella Gage FLOW EF Russian 20 ET-POTENTIAL  \
# date
# 1994-10-02  1-Oct-94  24:00:00        481.916626                   0.066151
# 1994-10-03  2-Oct-94  24:00:00        422.200256                   0.110752
# 1994-10-04  3-Oct-94  24:00:00        401.010406                   0.097419
# 1994-10-05  4-Oct-94  24:00:00        350.536926                   0.026083
# 1994-10-06  5-Oct-94  24:00:00        325.131805                   0.053415
#
# 0          EF Russian 20 FLOW EF Russian 20 FLOW-BASE  \
# date
# 1994-10-02         385.320801              385.320801
# 1994-10-03         325.200256              325.200256
# 1994-10-04         301.072906              301.072906
# 1994-10-05         271.099426              271.099426
# 1994-10-06         237.319305              237.319305
#
# 0          EF Russian 20 INFILTRATION EF Russian 20 PERC-SOIL  \
# date
# 1994-10-02                          0                       0
# 1994-10-03                          0                       0
# 1994-10-04                          0                       0
# 1994-10-05                          0                       0
# 1994-10-06                          0                       0
#
# 0          EF Russian 20 SATURATION FRACTION
# date
# 1994-10-02                          0.696838
# 1994-10-03                          0.687917
# 1994-10-04                          0.677802
# 1994-10-05                          0.671157
# 1994-10-06                          0.670204

# %% [markdown]
#  ## Plot combined results

# %%
myplot, metrics_df = combinedPlot(lstm_results=lstm_result_path, lstmPhysics_results= physics_informed_result_path, HMS_results=path_to_physics_data, title='Calpella Basin Model Comparison', fName = "calpella_metrics.csv")
# Out:
#            date  Observed_Model1  Predicted_Model1  Observed_Model2  \
# 4018 2005-10-01         184.2500         150.53737         184.2500
# 4019 2005-10-02         178.0000         151.94781         178.0000
# 4020 2005-10-03         187.2500         155.99477         187.2500
# 4021 2005-10-04         188.0833         154.21475         188.0833
# 4022 2005-10-05         182.1250         157.91557         182.1250
#
#       Predicted_Model2  HMS_predicted
# 4018         111.57333     514.779114
# 4019         127.58107     454.221100
# 4020         138.15506     431.052094
# 4021         136.28680     401.099426
# 4022         135.07599     366.340118
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# F:\Dino\UCB-USACE-LSTMs\neuralhydrology\calpella_all\..\..\..\UCB-USACE-LSTMs\neuralhydrology\datautils\utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)

# %%
metrics_df
# Out:
#                       HMS          LSTM  Physics_Informed_LSTM
# NSE              0.699185      0.815490               0.836284
# MSE          76611.391217  46990.947411           41695.261805
# RMSE           276.787628    216.773955             204.194177
# KGE              0.746423      0.766971               0.828890
# Alpha-NSE        1.224704      0.784797               0.907199
# Beta-KGE         1.058860      0.984264               0.882522
# Beta-NSE         0.034578     -0.009244              -0.069012
# Pearson-r        0.898291      0.912008               0.917140
# FHV             25.593699    -20.244225              -4.285842
# FMS              0.630349    -24.261616              -9.702451
# FLV           -969.540579  -1012.864838             -56.864044
# Peak-Timing      0.000000      0.500000               0.000000
# Peak-MAPE       54.234115     44.259439              20.011286
