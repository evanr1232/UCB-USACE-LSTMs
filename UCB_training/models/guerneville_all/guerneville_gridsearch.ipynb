# %%
import sys
import os
import itertools
import pandas as pd
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all

# %%
library_path = os.path.join('..', '..', '..','..','UCB-USACE-LSTMs')
sys.path.insert(0, library_path)
print(sys.path)
# Out:
# ['../../../../UCB-USACE-LSTMs', '/Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all', '/Users/canruso/Desktop', '/Users/canruso/miniforge3/envs/ESDL_LSTM/lib/python310.zip', '/Users/canruso/miniforge3/envs/ESDL_LSTM/lib/python3.10', '/Users/canruso/miniforge3/envs/ESDL_LSTM/lib/python3.10/lib-dynload', '', '/Users/canruso/miniforge3/envs/ESDL_LSTM/lib/python3.10/site-packages', '/Users/canruso/miniforge3/envs/ESDL_LSTM/lib/python3.10/site-packages/setuptools/_vendor']

# %%
from pathlib import Path
from neuralhydrology.evaluation.metrics import *
from UCB_training.UCB_train import UCB_trainer
from UCB_training.UCB_utils import combinedPlot
from UCB_training.UCB_utils import fancyCombinedPlot

# %%
current_path = os.getcwd()
library_path = current_path.split('UCB-USACE-LSTMs')[0] + 'UCB-USACE-LSTMs'

target_path = os.path.join(library_path, 'UCB_training', 'models', 'guerneville_all')

if os.path.exists(target_path):
    os.chdir(target_path)
    print("Current Working Directory:", os.getcwd())
    print("Train Basin File Exists:", os.path.exists("guerneville")) 
else:
    print(f"Error: The target path '{target_path}' does not exist.")
# Out:
# Current Working Directory: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all
# Train Basin File Exists: True

# %%
path_to_csv = Path(library_path +'/russian_river_data')
path_to_yaml = Path("guerneville_gage_nlayer.yaml")
path_to_physics_data = Path(library_path + "/russian_river_data/Guerneville_daily.csv")

# %%
features_with_physics = [
    "BIG SULPHUR CR ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "DRY CREEK 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "GREEN VALLEY ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "LAGUNA ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "RUSSIAN 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "RUSSIAN 40 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "RUSSIAN 50 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "RUSSIAN 60 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "RUSSIAN 70 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "SANTA ROSA CR 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "SANTA ROSA CR 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "WF RUSSIAN ET-POTENTIAL RUN:BASIN AVERAGE 60 YR",
    "BIG SULPHUR CR PRECIP-INC SCREENED",
    "DRY CREEK 10 PRECIP-INC SCREENED",
    "EF RUSSIAN 20 PRECIP-INC SCREENED",
    "GREEN VALLEY PRECIP-INC SCREENED",
    "LAGUNA PRECIP-INC SCREENED",
    "RUSSIAN 20 PRECIP-INC SCREENED",
    "RUSSIAN 30 PRECIP-INC SCREENED",
    "RUSSIAN 40 PRECIP-INC SCREENED",
    "RUSSIAN 50 PRECIP-INC SCREENED",
    "RUSSIAN 60 PRECIP-INC SCREENED",
    "RUSSIAN 70 PRECIP-INC SCREENED",
    "SANTA ROSA CR 10 PRECIP-INC SCREENED",
    "SANTA ROSA CR 20 PRECIP-INC SCREENED",
    "WF RUSSIAN PRECIP-INC SCREENED",
    "UKIAH CA HUMIDITY USAF-NOAA",
    "UKIAH CA SOLAR RADIATION USAF-NOAA",
    "UKIAH CA TEMPERATURE USAF-NOAA",
    "UKIAH CA WINDSPEED USAF-NOAA",
    "SANTA ROSA CA HUMIDITY USAF-NOAA",
    "SANTA ROSA CA SOLAR RADIATION USAF-NOAA",
    "SANTA ROSA CA TEMPERATURE USAF-NOAA",
    "SANTA ROSA CA WINDSPEED USAF-NOAA",
    "UKIAH CA FLOW USGS-MERGED",
    "GEYSERVILLE CA FLOW USGS-MERGED",
    "Guerneville Gage FLOW",
    "Big Sulphur Cr ET-POTENTIAL",
    "Big Sulphur Cr FLOW",
    "Big Sulphur Cr FLOW-BASE",
    "Big Sulphur Cr INFILTRATION",
    "Big Sulphur Cr PERC-SOIL",
    "Big Sulphur Cr SATURATION FRACTION",
    "Dry Creek 10 ET-POTENTIAL",
    "Dry Creek 10 FLOW",
    "Dry Creek 10 FLOW-BASE",
    "Dry Creek 10 INFILTRATION",
    "Dry Creek 10 PERC-SOIL",
    "Dry Creek 10 SATURATION FRACTION",
    "Green Valley ET-POTENTIAL",
    "Green Valley FLOW",
    "Green Valley FLOW-BASE",
    "Green Valley INFILTRATION",
    "Green Valley PERC-SOIL",
    "Green Valley SATURATION FRACTION",
    "Laguna ET-POTENTIAL",
    "Laguna FLOW",
    "Laguna FLOW-BASE",
    "Laguna INFILTRATION",
    "Laguna PERC-SOIL",
    "Laguna SATURATION FRACTION",
    "Russian 20 ET-POTENTIAL",
    "Russian 20 FLOW",
    "Russian 20 FLOW-BASE",
    "Russian 20 INFILTRATION",
    "Russian 20 PERC-SOIL",
    "Russian 20 SATURATION FRACTION",
    "Russian 30 ET-POTENTIAL",
    "Russian 30 FLOW",
    "Russian 30 FLOW-BASE",
    "Russian 30 INFILTRATION",
    "Russian 30 PERC-SOIL",
    "Russian 30 SATURATION FRACTION",
    "Russian 40 ET-POTENTIAL",
    "Russian 40 FLOW",
    "Russian 40 FLOW-BASE",
    "Russian 40 INFILTRATION",
    "Russian 40 PERC-SOIL",
    "Russian 40 SATURATION FRACTION",
    "Russian 50 ET-POTENTIAL",
    "Russian 50 FLOW",
    "Russian 50 FLOW-BASE",
    "Russian 50 INFILTRATION",
    "Russian 50 PERC-SOIL",
    "Russian 50 SATURATION FRACTION",
    "Russian 60 ET-POTENTIAL",
    "Russian 60 FLOW",
    "Russian 60 FLOW-BASE",
    "Russian 60 INFILTRATION",
    "Russian 60 PERC-SOIL",
    "Russian 60 SATURATION FRACTION",
    "Russian 70 ET-POTENTIAL",
    "Russian 70 FLOW",
    "Russian 70 FLOW-BASE",
    "Russian 70 INFILTRATION",
    "Russian 70 PERC-SOIL",
    "Russian 70 SATURATION FRACTION",
    "Santa Rosa Cr 10 ET-POTENTIAL",
    "Santa Rosa Cr 10 FLOW",
    "Santa Rosa Cr 10 FLOW-BASE",
    "Santa Rosa Cr 10 INFILTRATION",
    "Santa Rosa Cr 10 PERC-SOIL",
    "Santa Rosa Cr 10 SATURATION FRACTION",
    "Santa Rosa Cr 20 ET-POTENTIAL",
    "Santa Rosa Cr 20 FLOW",
    "Santa Rosa Cr 20 FLOW-BASE",
    "Santa Rosa Cr 20 INFILTRATION",
    "Santa Rosa Cr 20 PERC-SOIL",
    "Santa Rosa Cr 20 SATURATION FRACTION",
    "WF Russian ET-POTENTIAL",
    "WF Russian FLOW",
    "WF Russian FLOW-BASE",
    "WF Russian INFILTRATION",
    "WF Russian PERC-SOIL",
    "WF Russian SATURATION FRACTION"
]

# %%
hyperparam_space = {
    "hidden_size": [128, 256],
    "seq_length": [90, 180],
    "num_layers": [1, 2],
    "epochs": [16, 32]
}
fixed_dropout = 0.4
search_results = []

# %%
approaches = [
    {
        "name": "NoPhysics",
        "physics_informed": False,
        "input_features": None,
        "physics_data_file": None
    },
    {
        "name": "Physics",
        "physics_informed": True,
        "input_features": features_with_physics,
        "physics_data_file": path_to_physics_data
    }
]

# %%
for approach in approaches:
    for (hs, seq, nl, ep) in itertools.product(
            hyperparam_space["hidden_size"],
            hyperparam_space["seq_length"],
            hyperparam_space["num_layers"],
            hyperparam_space["epochs"]
    ):
        current_hparams = {
            "hidden_size": hs,
            "seq_length": seq,
            "num_layers": nl,
            "epochs": ep,
            "output_dropout": fixed_dropout,
            "save_weights_every": ep
        }
        print(f"Approach: {approach['name']} | Hyperparams: {current_hparams}")
        trainer = UCB_trainer(
            path_to_csv_folder=path_to_csv,
            yaml_path=path_to_yaml,
            hyperparams=current_hparams,
            input_features=approach["input_features"],
            physics_informed=approach["physics_informed"],
            physics_data_file=approach["physics_data_file"],
            hourly=False,
            extend_train_period=False,
            gpu=-1
        )
        trainer.train()
        csv_path, metrics_dict = trainer.results()
        row_data = {
            "model_type": approach["name"],
            "hidden_size": hs,
            "seq_length": seq,
            "num_layers": nl,
            "epochs": ep,
            "output_dropout": fixed_dropout
        }
        for k, v in metrics_dict.items():
            row_data[k] = v
        search_results.append(row_data)
        print(f"{approach['name']} metrics: {metrics_dict}")
# Out:
# Approach: NoPhysics | Hyperparams: {'hidden_size': 128, 'seq_length': 90, 'num_layers': 1, 'epochs': 8, 'output_dropout': 0.4, 'save_weights_every': 8}
# 2025-02-12 19:10:38,588: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038/output.log initialized.
# 2025-02-12 19:10:38,588: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038
# 2025-02-12 19:10:38,589: ### Run configurations for testing_run
# 2025-02-12 19:10:38,589: experiment_name: testing_run
# 2025-02-12 19:10:38,589: train_basin_file: guerneville
# 2025-02-12 19:10:38,589: validation_basin_file: guerneville
# 2025-02-12 19:10:38,590: test_basin_file: guerneville
# 2025-02-12 19:10:38,590: train_start_date: 1994-10-01 00:00:00
# 2025-02-12 19:10:38,590: train_end_date: 2002-09-30 00:00:00
# 2025-02-12 19:10:38,591: validation_start_date: 2002-10-01 00:00:00
# 2025-02-12 19:10:38,591: validation_end_date: 2005-09-30 00:00:00
# 2025-02-12 19:10:38,591: test_start_date: 2005-10-01 00:00:00
# 2025-02-12 19:10:38,591: test_end_date: 2009-09-29 00:00:00
# 2025-02-12 19:10:38,592: device: cpu
# 2025-02-12 19:10:38,592: physics_informed: False
# 2025-02-12 19:10:38,592: physics_data_file: None
# 2025-02-12 19:10:38,592: validate_every: 5
# 2025-02-12 19:10:38,593: validate_n_random_basins: 1
# 2025-02-12 19:10:38,593: metrics: ['NSE', 'MSE']
# 2025-02-12 19:10:38,593: model: cudalstm
# 2025-02-12 19:10:38,593: head: regression
# 2025-02-12 19:10:38,594: output_activation: linear
# 2025-02-12 19:10:38,594: hidden_size: 128
# 2025-02-12 19:10:38,594: initial_forget_bias: 3
# 2025-02-12 19:10:38,594: output_dropout: 0.4
# 2025-02-12 19:10:38,595: num_layers: 1
# 2025-02-12 19:10:38,595: dev_mode: True
# 2025-02-12 19:10:38,595: optimizer: Adam
# 2025-02-12 19:10:38,595: loss: NSE
# 2025-02-12 19:10:38,596: learning_rate: {0: 0.01, 20: 0.005, 30: 0.001}
# 2025-02-12 19:10:38,596: batch_size: 256
# 2025-02-12 19:10:38,596: epochs: 8
# 2025-02-12 19:10:38,596: clip_gradient_norm: 1
# 2025-02-12 19:10:38,596: predict_last_n: 1
# 2025-02-12 19:10:38,597: seq_length: 90
# 2025-02-12 19:10:38,597: log_interval: 16
# 2025-02-12 19:10:38,597: log_tensorboard: True
# 2025-02-12 19:10:38,597: log_n_figures: 1
# 2025-02-12 19:10:38,598: save_weights_every: 8
# 2025-02-12 19:10:38,598: dataset: russian_river
# 2025-02-12 19:10:38,598: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data
# 2025-02-12 19:10:38,599: dynamic_inputs: ['BIG SULPHUR CR ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'GREEN VALLEY ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'LAGUNA ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 40 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 50 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 60 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 70 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'WF RUSSIAN ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'BIG SULPHUR CR PRECIP-INC SCREENED', 'DRY CREEK 10 PRECIP-INC SCREENED', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'GREEN VALLEY PRECIP-INC SCREENED', 'LAGUNA PRECIP-INC SCREENED', 'RUSSIAN 20 PRECIP-INC SCREENED', 'RUSSIAN 30 PRECIP-INC SCREENED', 'RUSSIAN 40 PRECIP-INC SCREENED', 'RUSSIAN 50 PRECIP-INC SCREENED', 'RUSSIAN 60 PRECIP-INC SCREENED', 'RUSSIAN 70 PRECIP-INC SCREENED', 'SANTA ROSA CR 10 PRECIP-INC SCREENED', 'SANTA ROSA CR 20 PRECIP-INC SCREENED', 'WF RUSSIAN PRECIP-INC SCREENED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'UKIAH CA FLOW USGS-MERGED', 'GEYSERVILLE CA FLOW USGS-MERGED']
# 2025-02-12 19:10:38,599: target_variables: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:10:38,599: clip_targets_to_zero: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:10:38,599: hourly: False
# 2025-02-12 19:10:38,600: number_of_basins: 1
# 2025-02-12 19:10:38,600: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038
# 2025-02-12 19:10:38,600: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038/train_data
# 2025-02-12 19:10:38,600: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038/img_log
# 2025-02-12 19:10:38,607: ### Device cpu will be used for training
# 2025-02-12 19:10:38,607: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  7.98it/s]
# 2025-02-12 19:10:38,756: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 532.20it/s]
# 2025-02-12 19:10:38,770: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# # Epoch 1: 100%|██████████| 11/11 [00:01<00:00,  8.13it/s, Loss: 0.0000]
# 2025-02-12 19:10:41,576: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 11/11 [00:01<00:00,  7.89it/s, Loss: 0.0000]
# 2025-02-12 19:10:42,973: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 11/11 [00:01<00:00,  8.61it/s, Loss: 0.0000]
# 2025-02-12 19:10:44,253: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 11/11 [00:01<00:00,  8.60it/s, Loss: 0.0000]
# 2025-02-12 19:10:45,535: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 11/11 [00:01<00:00,  8.73it/s, Loss: 0.0000]
# 2025-02-12 19:10:46,797: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]
# 2025-02-12 19:10:47,521: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.60849, MSE: 9692046.00000
# # Epoch 6: 100%|██████████| 11/11 [00:01<00:00,  8.97it/s, Loss: 0.0000]
# 2025-02-12 19:10:48,750: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 11/11 [00:01<00:00,  8.78it/s, Loss: 0.0000]
# 2025-02-12 19:10:50,006: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 11/11 [00:01<00:00,  8.33it/s, Loss: 0.0000]
# 2025-02-12 19:10:51,329: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-02-12 19:10:51,349: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038/model_epoch008.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
# 2025-02-12 19:10:51,731: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038/validation/model_epoch008/validation_metrics.csv
# 2025-02-12 19:10:51,732: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038/validation/model_epoch008/validation_results.p
# got predictions
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191038/results_output_validation.csv
# NoPhysics metrics: {'NSE': 0.6286357045173645, 'MSE': 9193372.0, 'RMSE': 3032.057387319706, 'KGE': 0.7318701581546503, 'Alpha-NSE': 0.8288197515995839, 'Beta-KGE': 1.0030394792556763, 'Beta-NSE': 0.001467000751140499, 'Pearson-r': 0.793646671431163, 'FHV': -25.857844948768616, 'FMS': 19.488708941626463, 'FLV': -1021.3596508227976, 'Peak-Timing': 1.2, 'Peak-MAPE': 56.15251064300537}
# Approach: NoPhysics | Hyperparams: {'hidden_size': 128, 'seq_length': 90, 'num_layers': 1, 'epochs': 16, 'output_dropout': 0.4, 'save_weights_every': 16}
# 2025-02-12 19:10:51,970: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051/output.log initialized.
# 2025-02-12 19:10:51,970: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051
# 2025-02-12 19:10:51,971: ### Run configurations for testing_run
# 2025-02-12 19:10:51,971: experiment_name: testing_run
# 2025-02-12 19:10:51,972: train_basin_file: guerneville
# 2025-02-12 19:10:51,972: validation_basin_file: guerneville
# 2025-02-12 19:10:51,972: test_basin_file: guerneville
# 2025-02-12 19:10:51,973: train_start_date: 1994-10-01 00:00:00
# 2025-02-12 19:10:51,973: train_end_date: 2002-09-30 00:00:00
# 2025-02-12 19:10:51,973: validation_start_date: 2002-10-01 00:00:00
# 2025-02-12 19:10:51,974: validation_end_date: 2005-09-30 00:00:00
# 2025-02-12 19:10:51,974: test_start_date: 2005-10-01 00:00:00
# 2025-02-12 19:10:51,975: test_end_date: 2009-09-29 00:00:00
# 2025-02-12 19:10:51,975: device: cpu
# 2025-02-12 19:10:51,975: physics_informed: False
# 2025-02-12 19:10:51,976: physics_data_file: None
# 2025-02-12 19:10:51,976: validate_every: 5
# 2025-02-12 19:10:51,976: validate_n_random_basins: 1
# 2025-02-12 19:10:51,977: metrics: ['NSE', 'MSE']
# 2025-02-12 19:10:51,977: model: cudalstm
# 2025-02-12 19:10:51,977: head: regression
# 2025-02-12 19:10:51,978: output_activation: linear
# 2025-02-12 19:10:51,978: hidden_size: 128
# 2025-02-12 19:10:51,978: initial_forget_bias: 3
# 2025-02-12 19:10:51,978: output_dropout: 0.4
# 2025-02-12 19:10:51,978: num_layers: 1
# 2025-02-12 19:10:51,979: dev_mode: True
# 2025-02-12 19:10:51,979: optimizer: Adam
# 2025-02-12 19:10:51,979: loss: NSE
# 2025-02-12 19:10:51,979: learning_rate: {0: 0.01, 20: 0.005, 30: 0.001}
# 2025-02-12 19:10:51,980: batch_size: 256
# 2025-02-12 19:10:51,980: epochs: 16
# 2025-02-12 19:10:51,980: clip_gradient_norm: 1
# 2025-02-12 19:10:51,980: predict_last_n: 1
# 2025-02-12 19:10:51,981: seq_length: 90
# 2025-02-12 19:10:51,981: log_interval: 16
# 2025-02-12 19:10:51,981: log_tensorboard: True
# 2025-02-12 19:10:51,981: log_n_figures: 1
# 2025-02-12 19:10:51,981: save_weights_every: 16
# 2025-02-12 19:10:51,982: dataset: russian_river
# 2025-02-12 19:10:51,982: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data
# 2025-02-12 19:10:51,982: dynamic_inputs: ['BIG SULPHUR CR ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'GREEN VALLEY ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'LAGUNA ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 40 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 50 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 60 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 70 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'WF RUSSIAN ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'BIG SULPHUR CR PRECIP-INC SCREENED', 'DRY CREEK 10 PRECIP-INC SCREENED', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'GREEN VALLEY PRECIP-INC SCREENED', 'LAGUNA PRECIP-INC SCREENED', 'RUSSIAN 20 PRECIP-INC SCREENED', 'RUSSIAN 30 PRECIP-INC SCREENED', 'RUSSIAN 40 PRECIP-INC SCREENED', 'RUSSIAN 50 PRECIP-INC SCREENED', 'RUSSIAN 60 PRECIP-INC SCREENED', 'RUSSIAN 70 PRECIP-INC SCREENED', 'SANTA ROSA CR 10 PRECIP-INC SCREENED', 'SANTA ROSA CR 20 PRECIP-INC SCREENED', 'WF RUSSIAN PRECIP-INC SCREENED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'UKIAH CA FLOW USGS-MERGED', 'GEYSERVILLE CA FLOW USGS-MERGED']
# 2025-02-12 19:10:51,982: target_variables: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:10:51,982: clip_targets_to_zero: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:10:51,983: hourly: False
# 2025-02-12 19:10:51,983: number_of_basins: 1
# 2025-02-12 19:10:51,983: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051
# 2025-02-12 19:10:51,983: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051/train_data
# 2025-02-12 19:10:51,984: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051/img_log
# 2025-02-12 19:10:51,989: ### Device cpu will be used for training
# 2025-02-12 19:10:51,989: Loading basin data into xarray data set.
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# 100%|██████████| 1/1 [00:00<00:00,  9.70it/s]
# 2025-02-12 19:10:52,097: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 992.03it/s]
# 2025-02-12 19:10:52,105: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 41.26it/s]
# # Epoch 1: 100%|██████████| 11/11 [00:01<00:00, 10.40it/s, Loss: 0.0000]
# 2025-02-12 19:10:53,324: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 11/11 [00:01<00:00,  8.14it/s, Loss: 0.0000]
# 2025-02-12 19:10:54,678: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 11/11 [00:01<00:00,  9.64it/s, Loss: 0.0000]
# 2025-02-12 19:10:55,823: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 11/11 [00:01<00:00,  8.91it/s, Loss: 0.0000]
# 2025-02-12 19:10:57,060: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 11/11 [00:01<00:00,  8.67it/s, Loss: 0.0000]
# 2025-02-12 19:10:58,332: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
# 2025-02-12 19:10:58,914: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.62122, MSE: 9376919.00000
# # Epoch 6: 100%|██████████| 11/11 [00:01<00:00,  9.01it/s, Loss: 0.0000]
# 2025-02-12 19:11:00,138: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 11/11 [00:01<00:00,  8.64it/s, Loss: 0.0000]
# 2025-02-12 19:11:01,414: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 11/11 [00:01<00:00,  8.59it/s, Loss: 0.0000]
# 2025-02-12 19:11:02,698: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 11/11 [00:01<00:00,  8.59it/s, Loss: 0.0000]
# 2025-02-12 19:11:03,982: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 11/11 [00:01<00:00,  8.65it/s, Loss: 0.0000]
# 2025-02-12 19:11:05,256: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.90it/s]
# 2025-02-12 19:11:05,711: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.67111, MSE: 8141945.50000
# # Epoch 11: 100%|██████████| 11/11 [00:01<00:00,  8.84it/s, Loss: 0.0000]
# 2025-02-12 19:11:06,959: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 11/11 [00:01<00:00,  8.67it/s, Loss: 0.0000]
# 2025-02-12 19:11:08,229: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 11/11 [00:01<00:00,  8.76it/s, Loss: 0.0000]
# 2025-02-12 19:11:09,488: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 11/11 [00:01<00:00,  8.75it/s, Loss: 0.0000]
# 2025-02-12 19:11:10,748: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 11/11 [00:01<00:00,  8.68it/s, Loss: 0.0000]
# 2025-02-12 19:11:12,017: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# 2025-02-12 19:11:12,465: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.69091, MSE: 7651721.50000
# # Epoch 16: 100%|██████████| 11/11 [00:01<00:00,  9.20it/s, Loss: 0.0000]
# 2025-02-12 19:11:13,664: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-02-12 19:11:13,686: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051/model_epoch016.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.69it/s]
# 2025-02-12 19:11:14,062: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051/validation/model_epoch016/validation_metrics.csv
# 2025-02-12 19:11:14,063: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051/validation/model_epoch016/validation_results.p
# got predictions
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191051/results_output_validation.csv
# NoPhysics metrics: {'NSE': 0.6657054424285889, 'MSE': 8275686.0, 'RMSE': 2876.7492070043227, 'KGE': 0.769965306518856, 'Alpha-NSE': 0.9082250375324907, 'Beta-KGE': 0.8864233493804932, 'Beta-NSE': -0.05481858494708159, 'Pearson-r': 0.8222539426510236, 'FHV': -11.035173386335373, 'FMS': 4.0601429754270075, 'FLV': -663.2292636418343, 'Peak-Timing': 1.2, 'Peak-MAPE': 55.53871154785156}
# Approach: Physics | Hyperparams: {'hidden_size': 128, 'seq_length': 90, 'num_layers': 1, 'epochs': 8, 'output_dropout': 0.4, 'save_weights_every': 8}
# 2025-02-12 19:11:14,294: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114/output.log initialized.
# 2025-02-12 19:11:14,295: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114
# 2025-02-12 19:11:14,295: ### Run configurations for testing_run
# 2025-02-12 19:11:14,296: experiment_name: testing_run
# 2025-02-12 19:11:14,296: train_basin_file: guerneville
# 2025-02-12 19:11:14,297: validation_basin_file: guerneville
# 2025-02-12 19:11:14,297: test_basin_file: guerneville
# 2025-02-12 19:11:14,298: train_start_date: 1994-10-01 00:00:00
# 2025-02-12 19:11:14,298: train_end_date: 2002-09-30 00:00:00
# 2025-02-12 19:11:14,299: validation_start_date: 2002-10-01 00:00:00
# 2025-02-12 19:11:14,299: validation_end_date: 2005-09-30 00:00:00
# 2025-02-12 19:11:14,299: test_start_date: 2005-10-01 00:00:00
# 2025-02-12 19:11:14,300: test_end_date: 2009-09-29 00:00:00
# 2025-02-12 19:11:14,300: device: cpu
# 2025-02-12 19:11:14,300: physics_informed: True
# 2025-02-12 19:11:14,300: physics_data_file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv
# 2025-02-12 19:11:14,301: validate_every: 5
# 2025-02-12 19:11:14,301: validate_n_random_basins: 1
# 2025-02-12 19:11:14,301: metrics: ['NSE', 'MSE']
# 2025-02-12 19:11:14,302: model: cudalstm
# 2025-02-12 19:11:14,302: head: regression
# 2025-02-12 19:11:14,302: output_activation: linear
# 2025-02-12 19:11:14,303: hidden_size: 128
# 2025-02-12 19:11:14,303: initial_forget_bias: 3
# 2025-02-12 19:11:14,303: output_dropout: 0.4
# 2025-02-12 19:11:14,303: num_layers: 1
# 2025-02-12 19:11:14,304: dev_mode: True
# 2025-02-12 19:11:14,304: optimizer: Adam
# 2025-02-12 19:11:14,304: loss: NSE
# 2025-02-12 19:11:14,304: learning_rate: {0: 0.01, 20: 0.005, 30: 0.001}
# 2025-02-12 19:11:14,304: batch_size: 256
# 2025-02-12 19:11:14,305: epochs: 8
# 2025-02-12 19:11:14,305: clip_gradient_norm: 1
# 2025-02-12 19:11:14,305: predict_last_n: 1
# 2025-02-12 19:11:14,305: seq_length: 90
# 2025-02-12 19:11:14,306: log_interval: 16
# 2025-02-12 19:11:14,306: log_tensorboard: True
# 2025-02-12 19:11:14,306: log_n_figures: 1
# 2025-02-12 19:11:14,306: save_weights_every: 8
# 2025-02-12 19:11:14,307: dataset: russian_river
# 2025-02-12 19:11:14,307: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data
# 2025-02-12 19:11:14,307: dynamic_inputs: ['BIG SULPHUR CR ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'GREEN VALLEY ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'LAGUNA ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 40 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 50 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 60 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 70 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'WF RUSSIAN ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'BIG SULPHUR CR PRECIP-INC SCREENED', 'DRY CREEK 10 PRECIP-INC SCREENED', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'GREEN VALLEY PRECIP-INC SCREENED', 'LAGUNA PRECIP-INC SCREENED', 'RUSSIAN 20 PRECIP-INC SCREENED', 'RUSSIAN 30 PRECIP-INC SCREENED', 'RUSSIAN 40 PRECIP-INC SCREENED', 'RUSSIAN 50 PRECIP-INC SCREENED', 'RUSSIAN 60 PRECIP-INC SCREENED', 'RUSSIAN 70 PRECIP-INC SCREENED', 'SANTA ROSA CR 10 PRECIP-INC SCREENED', 'SANTA ROSA CR 20 PRECIP-INC SCREENED', 'WF RUSSIAN PRECIP-INC SCREENED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'UKIAH CA FLOW USGS-MERGED', 'GEYSERVILLE CA FLOW USGS-MERGED', 'Guerneville Gage FLOW', 'Big Sulphur Cr ET-POTENTIAL', 'Big Sulphur Cr FLOW', 'Big Sulphur Cr FLOW-BASE', 'Big Sulphur Cr INFILTRATION', 'Big Sulphur Cr PERC-SOIL', 'Big Sulphur Cr SATURATION FRACTION', 'Dry Creek 10 ET-POTENTIAL', 'Dry Creek 10 FLOW', 'Dry Creek 10 FLOW-BASE', 'Dry Creek 10 INFILTRATION', 'Dry Creek 10 PERC-SOIL', 'Dry Creek 10 SATURATION FRACTION', 'Green Valley ET-POTENTIAL', 'Green Valley FLOW', 'Green Valley FLOW-BASE', 'Green Valley INFILTRATION', 'Green Valley PERC-SOIL', 'Green Valley SATURATION FRACTION', 'Laguna ET-POTENTIAL', 'Laguna FLOW', 'Laguna FLOW-BASE', 'Laguna INFILTRATION', 'Laguna PERC-SOIL', 'Laguna SATURATION FRACTION', 'Russian 20 ET-POTENTIAL', 'Russian 20 FLOW', 'Russian 20 FLOW-BASE', 'Russian 20 INFILTRATION', 'Russian 20 PERC-SOIL', 'Russian 20 SATURATION FRACTION', 'Russian 30 ET-POTENTIAL', 'Russian 30 FLOW', 'Russian 30 FLOW-BASE', 'Russian 30 INFILTRATION', 'Russian 30 PERC-SOIL', 'Russian 30 SATURATION FRACTION', 'Russian 40 ET-POTENTIAL', 'Russian 40 FLOW', 'Russian 40 FLOW-BASE', 'Russian 40 INFILTRATION', 'Russian 40 PERC-SOIL', 'Russian 40 SATURATION FRACTION', 'Russian 50 ET-POTENTIAL', 'Russian 50 FLOW', 'Russian 50 FLOW-BASE', 'Russian 50 INFILTRATION', 'Russian 50 PERC-SOIL', 'Russian 50 SATURATION FRACTION', 'Russian 60 ET-POTENTIAL', 'Russian 60 FLOW', 'Russian 60 FLOW-BASE', 'Russian 60 INFILTRATION', 'Russian 60 PERC-SOIL', 'Russian 60 SATURATION FRACTION', 'Russian 70 ET-POTENTIAL', 'Russian 70 FLOW', 'Russian 70 FLOW-BASE', 'Russian 70 INFILTRATION', 'Russian 70 PERC-SOIL', 'Russian 70 SATURATION FRACTION', 'Santa Rosa Cr 10 ET-POTENTIAL', 'Santa Rosa Cr 10 FLOW', 'Santa Rosa Cr 10 FLOW-BASE', 'Santa Rosa Cr 10 INFILTRATION', 'Santa Rosa Cr 10 PERC-SOIL', 'Santa Rosa Cr 10 SATURATION FRACTION', 'Santa Rosa Cr 20 ET-POTENTIAL', 'Santa Rosa Cr 20 FLOW', 'Santa Rosa Cr 20 FLOW-BASE', 'Santa Rosa Cr 20 INFILTRATION', 'Santa Rosa Cr 20 PERC-SOIL', 'Santa Rosa Cr 20 SATURATION FRACTION', 'WF Russian ET-POTENTIAL', 'WF Russian FLOW', 'WF Russian FLOW-BASE', 'WF Russian INFILTRATION', 'WF Russian PERC-SOIL', 'WF Russian SATURATION FRACTION']
# 2025-02-12 19:11:14,307: target_variables: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:11:14,308: clip_targets_to_zero: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:11:14,308: hourly: False
# 2025-02-12 19:11:14,308: number_of_basins: 1
# 2025-02-12 19:11:14,308: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114
# 2025-02-12 19:11:14,308: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114/train_data
# 2025-02-12 19:11:14,309: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114/img_log
# 2025-02-12 19:11:14,313: ### Device cpu will be used for training
# 2025-02-12 19:11:14,313: Loading basin data into xarray data set.
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#   0%|          | 0/1 [00:00<?, ?it/s]2025-02-12 19:11:14,396: Loading data from file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv, hourly: False
# 100%|██████████| 1/1 [00:00<00:00,  3.46it/s]
# 2025-02-12 19:11:14,617: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 508.65it/s]
# 2025-02-12 19:11:14,635: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.66it/s]
# # Epoch 1: 100%|██████████| 11/11 [00:01<00:00,  7.98it/s, Loss: 0.0000]
# 2025-02-12 19:11:16,461: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 11/11 [00:01<00:00,  8.27it/s, Loss: 0.0000]
# 2025-02-12 19:11:17,793: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 11/11 [00:01<00:00,  8.16it/s, Loss: 0.0000]
# 2025-02-12 19:11:19,144: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 11/11 [00:01<00:00,  8.17it/s, Loss: 0.0000]
# 2025-02-12 19:11:20,493: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 11/11 [00:01<00:00,  8.23it/s, Loss: 0.0000]
# 2025-02-12 19:11:21,832: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-02-12 19:11:21,928: Loading data from file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# 2025-02-12 19:11:22,612: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.70838, MSE: 7219325.50000
# # Epoch 6: 100%|██████████| 11/11 [00:01<00:00,  9.40it/s, Loss: 0.0000]
# 2025-02-12 19:11:23,785: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 11/11 [00:01<00:00,  8.58it/s, Loss: 0.0000]
# 2025-02-12 19:11:25,069: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 11/11 [00:01<00:00,  9.12it/s, Loss: 0.0000]
# 2025-02-12 19:11:26,277: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-02-12 19:11:26,321: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114/model_epoch008.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-02-12 19:11:26,414: Loading data from file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# 2025-02-12 19:11:26,933: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114/validation/model_epoch008/validation_metrics.csv
# 2025-02-12 19:11:26,934: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114/validation/model_epoch008/validation_results.p
# got predictions
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191114/results_output_validation.csv
# Physics metrics: {'NSE': 0.7372132241725922, 'MSE': 6505462.5, 'RMSE': 2550.5808162063795, 'KGE': 0.8252805568543196, 'Alpha-NSE': 0.8986315582249689, 'Beta-KGE': 1.0230451822280884, 'Beta-NSE': 0.011122895182435678, 'Pearson-r': 0.8595712194693945, 'FHV': -15.79691767692566, 'FMS': 1.5382076067747708, 'FLV': -1452.9468846102088, 'Peak-Timing': 0.6, 'Peak-MAPE': 35.58822154998779}
# Approach: Physics | Hyperparams: {'hidden_size': 128, 'seq_length': 90, 'num_layers': 1, 'epochs': 16, 'output_dropout': 0.4, 'save_weights_every': 16}
# 2025-02-12 19:11:27,176: Logging to /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127/output.log initialized.
# 2025-02-12 19:11:27,176: ### Folder structure created at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127
# 2025-02-12 19:11:27,176: ### Run configurations for testing_run
# 2025-02-12 19:11:27,177: experiment_name: testing_run
# 2025-02-12 19:11:27,177: train_basin_file: guerneville
# 2025-02-12 19:11:27,177: validation_basin_file: guerneville
# 2025-02-12 19:11:27,177: test_basin_file: guerneville
# 2025-02-12 19:11:27,178: train_start_date: 1994-10-01 00:00:00
# 2025-02-12 19:11:27,178: train_end_date: 2002-09-30 00:00:00
# 2025-02-12 19:11:27,178: validation_start_date: 2002-10-01 00:00:00
# 2025-02-12 19:11:27,178: validation_end_date: 2005-09-30 00:00:00
# 2025-02-12 19:11:27,179: test_start_date: 2005-10-01 00:00:00
# 2025-02-12 19:11:27,179: test_end_date: 2009-09-29 00:00:00
# 2025-02-12 19:11:27,179: device: cpu
# 2025-02-12 19:11:27,179: physics_informed: True
# 2025-02-12 19:11:27,180: physics_data_file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv
# 2025-02-12 19:11:27,180: validate_every: 5
# 2025-02-12 19:11:27,180: validate_n_random_basins: 1
# 2025-02-12 19:11:27,181: metrics: ['NSE', 'MSE']
# 2025-02-12 19:11:27,181: model: cudalstm
# 2025-02-12 19:11:27,181: head: regression
# 2025-02-12 19:11:27,181: output_activation: linear
# 2025-02-12 19:11:27,181: hidden_size: 128
# 2025-02-12 19:11:27,182: initial_forget_bias: 3
# 2025-02-12 19:11:27,182: output_dropout: 0.4
# 2025-02-12 19:11:27,182: num_layers: 1
# 2025-02-12 19:11:27,182: dev_mode: True
# 2025-02-12 19:11:27,183: optimizer: Adam
# 2025-02-12 19:11:27,183: loss: NSE
# 2025-02-12 19:11:27,183: learning_rate: {0: 0.01, 20: 0.005, 30: 0.001}
# 2025-02-12 19:11:27,183: batch_size: 256
# 2025-02-12 19:11:27,184: epochs: 16
# 2025-02-12 19:11:27,184: clip_gradient_norm: 1
# 2025-02-12 19:11:27,184: predict_last_n: 1
# 2025-02-12 19:11:27,184: seq_length: 90
# 2025-02-12 19:11:27,185: log_interval: 16
# 2025-02-12 19:11:27,185: log_tensorboard: True
# 2025-02-12 19:11:27,185: log_n_figures: 1
# 2025-02-12 19:11:27,185: save_weights_every: 16
# 2025-02-12 19:11:27,186: dataset: russian_river
# 2025-02-12 19:11:27,186: data_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data
# 2025-02-12 19:11:27,186: dynamic_inputs: ['BIG SULPHUR CR ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'DRY CREEK 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'EF RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'GREEN VALLEY ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'LAGUNA ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 30 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 40 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 50 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 60 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'RUSSIAN 70 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 10 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'SANTA ROSA CR 20 ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'WF RUSSIAN ET-POTENTIAL RUN:BASIN AVERAGE 60 YR', 'BIG SULPHUR CR PRECIP-INC SCREENED', 'DRY CREEK 10 PRECIP-INC SCREENED', 'EF RUSSIAN 20 PRECIP-INC SCREENED', 'GREEN VALLEY PRECIP-INC SCREENED', 'LAGUNA PRECIP-INC SCREENED', 'RUSSIAN 20 PRECIP-INC SCREENED', 'RUSSIAN 30 PRECIP-INC SCREENED', 'RUSSIAN 40 PRECIP-INC SCREENED', 'RUSSIAN 50 PRECIP-INC SCREENED', 'RUSSIAN 60 PRECIP-INC SCREENED', 'RUSSIAN 70 PRECIP-INC SCREENED', 'SANTA ROSA CR 10 PRECIP-INC SCREENED', 'SANTA ROSA CR 20 PRECIP-INC SCREENED', 'WF RUSSIAN PRECIP-INC SCREENED', 'UKIAH CA HUMIDITY USAF-NOAA', 'UKIAH CA SOLAR RADIATION USAF-NOAA', 'UKIAH CA TEMPERATURE USAF-NOAA', 'UKIAH CA WINDSPEED USAF-NOAA', 'SANTA ROSA CA HUMIDITY USAF-NOAA', 'SANTA ROSA CA SOLAR RADIATION USAF-NOAA', 'SANTA ROSA CA TEMPERATURE USAF-NOAA', 'SANTA ROSA CA WINDSPEED USAF-NOAA', 'UKIAH CA FLOW USGS-MERGED', 'GEYSERVILLE CA FLOW USGS-MERGED', 'Guerneville Gage FLOW', 'Big Sulphur Cr ET-POTENTIAL', 'Big Sulphur Cr FLOW', 'Big Sulphur Cr FLOW-BASE', 'Big Sulphur Cr INFILTRATION', 'Big Sulphur Cr PERC-SOIL', 'Big Sulphur Cr SATURATION FRACTION', 'Dry Creek 10 ET-POTENTIAL', 'Dry Creek 10 FLOW', 'Dry Creek 10 FLOW-BASE', 'Dry Creek 10 INFILTRATION', 'Dry Creek 10 PERC-SOIL', 'Dry Creek 10 SATURATION FRACTION', 'Green Valley ET-POTENTIAL', 'Green Valley FLOW', 'Green Valley FLOW-BASE', 'Green Valley INFILTRATION', 'Green Valley PERC-SOIL', 'Green Valley SATURATION FRACTION', 'Laguna ET-POTENTIAL', 'Laguna FLOW', 'Laguna FLOW-BASE', 'Laguna INFILTRATION', 'Laguna PERC-SOIL', 'Laguna SATURATION FRACTION', 'Russian 20 ET-POTENTIAL', 'Russian 20 FLOW', 'Russian 20 FLOW-BASE', 'Russian 20 INFILTRATION', 'Russian 20 PERC-SOIL', 'Russian 20 SATURATION FRACTION', 'Russian 30 ET-POTENTIAL', 'Russian 30 FLOW', 'Russian 30 FLOW-BASE', 'Russian 30 INFILTRATION', 'Russian 30 PERC-SOIL', 'Russian 30 SATURATION FRACTION', 'Russian 40 ET-POTENTIAL', 'Russian 40 FLOW', 'Russian 40 FLOW-BASE', 'Russian 40 INFILTRATION', 'Russian 40 PERC-SOIL', 'Russian 40 SATURATION FRACTION', 'Russian 50 ET-POTENTIAL', 'Russian 50 FLOW', 'Russian 50 FLOW-BASE', 'Russian 50 INFILTRATION', 'Russian 50 PERC-SOIL', 'Russian 50 SATURATION FRACTION', 'Russian 60 ET-POTENTIAL', 'Russian 60 FLOW', 'Russian 60 FLOW-BASE', 'Russian 60 INFILTRATION', 'Russian 60 PERC-SOIL', 'Russian 60 SATURATION FRACTION', 'Russian 70 ET-POTENTIAL', 'Russian 70 FLOW', 'Russian 70 FLOW-BASE', 'Russian 70 INFILTRATION', 'Russian 70 PERC-SOIL', 'Russian 70 SATURATION FRACTION', 'Santa Rosa Cr 10 ET-POTENTIAL', 'Santa Rosa Cr 10 FLOW', 'Santa Rosa Cr 10 FLOW-BASE', 'Santa Rosa Cr 10 INFILTRATION', 'Santa Rosa Cr 10 PERC-SOIL', 'Santa Rosa Cr 10 SATURATION FRACTION', 'Santa Rosa Cr 20 ET-POTENTIAL', 'Santa Rosa Cr 20 FLOW', 'Santa Rosa Cr 20 FLOW-BASE', 'Santa Rosa Cr 20 INFILTRATION', 'Santa Rosa Cr 20 PERC-SOIL', 'Santa Rosa Cr 20 SATURATION FRACTION', 'WF Russian ET-POTENTIAL', 'WF Russian FLOW', 'WF Russian FLOW-BASE', 'WF Russian INFILTRATION', 'WF Russian PERC-SOIL', 'WF Russian SATURATION FRACTION']
# 2025-02-12 19:11:27,186: target_variables: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:11:27,187: clip_targets_to_zero: ['NR GUERNEVILLE FLOW COE GRN']
# 2025-02-12 19:11:27,187: hourly: False
# 2025-02-12 19:11:27,187: number_of_basins: 1
# 2025-02-12 19:11:27,187: run_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127
# 2025-02-12 19:11:27,188: train_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127/train_data
# 2025-02-12 19:11:27,188: img_log_dir: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127/img_log
# 2025-02-12 19:11:27,191: ### Device cpu will be used for training
# 2025-02-12 19:11:27,192: Loading basin data into xarray data set.
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#   0%|          | 0/1 [00:00<?, ?it/s]2025-02-12 19:11:27,272: Loading data from file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv, hourly: False
# 100%|██████████| 1/1 [00:00<00:00,  3.36it/s]
# 2025-02-12 19:11:27,503: Calculating target variable stds per basin
# 100%|██████████| 1/1 [00:00<00:00, 506.37it/s]
# 2025-02-12 19:11:27,521: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 17.43it/s]
# # Epoch 1: 100%|██████████| 11/11 [00:01<00:00,  8.01it/s, Loss: 0.0000]
# 2025-02-12 19:11:29,134: Epoch 1 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 2: 100%|██████████| 11/11 [00:01<00:00,  8.24it/s, Loss: 0.0000]
# 2025-02-12 19:11:30,472: Epoch 2 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 3: 100%|██████████| 11/11 [00:01<00:00,  8.13it/s, Loss: 0.0000]
# 2025-02-12 19:11:31,827: Epoch 3 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 4: 100%|██████████| 11/11 [00:01<00:00,  7.94it/s, Loss: 0.0000]
# 2025-02-12 19:11:33,216: Epoch 4 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 5: 100%|██████████| 11/11 [00:01<00:00,  8.23it/s, Loss: 0.0000]
# 2025-02-12 19:11:34,556: Epoch 5 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-02-12 19:11:34,649: Loading data from file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]
# 2025-02-12 19:11:35,364: Epoch 5 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.68901, MSE: 7698850.00000
# # Epoch 6: 100%|██████████| 11/11 [00:01<00:00,  8.68it/s, Loss: 0.0000]
# 2025-02-12 19:11:36,634: Epoch 6 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 7: 100%|██████████| 11/11 [00:01<00:00,  8.27it/s, Loss: 0.0000]
# 2025-02-12 19:11:37,967: Epoch 7 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 8: 100%|██████████| 11/11 [00:01<00:00,  8.53it/s, Loss: 0.0000]
# 2025-02-12 19:11:39,258: Epoch 8 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 9: 100%|██████████| 11/11 [00:01<00:00,  8.69it/s, Loss: 0.0000]
# 2025-02-12 19:11:40,527: Epoch 9 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 10: 100%|██████████| 11/11 [00:01<00:00,  8.76it/s, Loss: 0.0000]
# 2025-02-12 19:11:41,785: Epoch 10 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.02it/s]
# 2025-02-12 19:11:42,232: Epoch 10 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.73521, MSE: 6555157.50000
# # Epoch 11: 100%|██████████| 11/11 [00:01<00:00,  8.81it/s, Loss: 0.0000]
# 2025-02-12 19:11:43,484: Epoch 11 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 12: 100%|██████████| 11/11 [00:01<00:00,  8.76it/s, Loss: 0.0000]
# 2025-02-12 19:11:44,743: Epoch 12 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 13: 100%|██████████| 11/11 [00:01<00:00,  8.82it/s, Loss: 0.0000]
# 2025-02-12 19:11:45,993: Epoch 13 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 14: 100%|██████████| 11/11 [00:01<00:00,  8.74it/s, Loss: 0.0000]
# 2025-02-12 19:11:47,254: Epoch 14 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Epoch 15: 100%|██████████| 11/11 [00:01<00:00,  8.53it/s, Loss: 0.0000]
# 2025-02-12 19:11:48,545: Epoch 15 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.97it/s]
# 2025-02-12 19:11:48,994: Epoch 15 average validation loss: 0.00000 -- Median validation metrics: avg_loss: 0.00000, NSE: 0.73145, MSE: 6648212.50000
# # Epoch 16: 100%|██████████| 11/11 [00:01<00:00,  8.88it/s, Loss: 0.0000]
# 2025-02-12 19:11:50,236: Epoch 16 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-02-12 19:11:50,280: Using the model weights from /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127/model_epoch016.pt
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Validation:   0%|          | 0/1 [00:00<?, ?it/s]2025-02-12 19:11:50,370: Loading data from file: /Users/canruso/Desktop/UCB-USACE-LSTMs/russian_river_data/Guerneville_daily.csv, hourly: False
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]
# 2025-02-12 19:11:50,912: Stored metrics at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127/validation/model_epoch016/validation_metrics.csv
# 2025-02-12 19:11:50,913: Stored results at /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127/validation/model_epoch016/validation_results.p
# got predictions
# [INFO] CSV output saved at: /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/runs/testing_run_1202_191127/results_output_validation.csv
# Physics metrics: {'NSE': 0.7435036301612854, 'MSE': 6349740.0, 'RMSE': 2519.8690442163856, 'KGE': 0.8620332095341794, 'Alpha-NSE': 0.9628092222859677, 'Beta-KGE': 1.0101503133773804, 'Beta-NSE': 0.004899096531269682, 'Pearson-r': 0.8675286730541056, 'FHV': -6.68594017624855, 'FMS': 15.137560350829876, 'FLV': -868.3305829504886, 'Peak-Timing': 0.2, 'Peak-MAPE': 31.144495010375977}
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:339: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/canruso/Desktop/UCB-USACE-LSTMs/UCB_training/models/guerneville_all/../../../../UCB-USACE-LSTMs/neuralhydrology/datautils/utils.py:382: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)

# %%
df_results = pd.DataFrame(search_results)
df_results.sort_values(by="NSE", ascending=False, inplace=True)
df_results.reset_index(drop=True, inplace=True)
df_results
# Out:
#   model_type  hidden_size  seq_length  num_layers  epochs  output_dropout  \
# 0    Physics          128          90           1      16             0.4
# 1    Physics          128          90           1       8             0.4
# 2  NoPhysics          128          90           1      16             0.4
# 3  NoPhysics          128          90           1       8             0.4
#
#         NSE        MSE         RMSE       KGE  Alpha-NSE  Beta-KGE  Beta-NSE  \
# 0  0.743504  6349740.0  2519.869044  0.862033   0.962809  1.010150  0.004899
# 1  0.737213  6505462.5  2550.580816  0.825281   0.898632  1.023045  0.011123
# 2  0.665705  8275686.0  2876.749207  0.769965   0.908225  0.886423 -0.054819
# 3  0.628636  9193372.0  3032.057387  0.731870   0.828820  1.003039  0.001467
#
#    Pearson-r        FHV        FMS          FLV  Peak-Timing  Peak-MAPE
# 0   0.867529  -6.685940  15.137560  -868.330583          0.2  31.144495
# 1   0.859571 -15.796918   1.538208 -1452.946885          0.6  35.588222
# 2   0.822254 -11.035173   4.060143  -663.229264          1.2  55.538712
# 3   0.793647 -25.857845  19.488709 -1021.359651          1.2  56.152511
